# %%
pip install pandas matplotlib scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\quoct\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\quoct\anaconda3\lib\site-packages (3.7.2)
# Requirement already satisfied: scikit-learn in c:\users\quoct\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\quoct\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\quoct\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\quoct\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\quoct\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\quoct\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\quoct\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\quoct\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\quoct\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\quoct\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\quoct\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\quoct\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\quoct\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\quoct\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\quoct\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\quoct\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
# Load the dataset
df = pd.read_csv('adidas.csv')

# %%
# Select the 'Close' column and handle missing values
df = df[['Close']].dropna().reset_index(drop=True)

# %% [markdown]
# # Train-test(7-3)

# %%
# Split the data into training and testing sets
train_size = int(0.7 * len(df))
test_size = int(0.3 * len(df))
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
# Prepare training data
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Close'])

# %%
# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Prepare testing data
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Close'])
# Predict stock prices on the test set
y_pred = model.predict(x_test)

# Create an index for the next 30 days
last_index = df.index[-1]
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(x_next_30_days)

# %%
# Evaluate model performance using metrics
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(np.mean((y_pred - y_test)**2))
mape = mean_absolute_percentage_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# Print metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Percentage Error (MAPE):', mape)
print('Mean Absolute Error (MAE):', mae)
# Plot the predictions graph
plt.title('Linear Regression - Stock Price Prediction')
plt.plot(train_data.index, train_data['Close'], label='Train')
plt.plot(test_data.index, test_data['Close'], label='Test')
plt.plot(test_data.index, y_pred, label='Predictions')
plt.plot(range(last_index+1, last_index+31), y_next_30_days, label='Next 30 Days')
plt.legend()
plt.show()
# Out:
# Mean Squared Error (MSE): 4707.2635139134045
# Root Mean Squared Error (RMSE): 68.60950017244991
# Mean Absolute Percentage Error (MAPE): 0.8692560367879688
# Mean Absolute Error (MAE): 67.28478065276609

# %%
y_next_30_days
# Out:
# array([151.40145386, 151.40722568, 151.4129975 , 151.41876933,
#        151.42454115, 151.43031298, 151.4360848 , 151.44185662,
#        151.44762845, 151.45340027, 151.4591721 , 151.46494392,
#        151.47071574, 151.47648757, 151.48225939, 151.48803122,
#        151.49380304, 151.49957486, 151.50534669, 151.51111851,
#        151.51689034, 151.52266216, 151.52843398, 151.53420581,
#        151.53997763, 151.54574946, 151.55152128, 151.5572931 ,
#        151.56306493, 151.56883675])

# %% [markdown]
# # Train-test(8-2)

# %%
# Split the data into training and testing sets
train_size = int(0.8 * len(df))
test_size = int(0.2 * len(df))
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
# Prepare training data
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Close'])

# %%
# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Prepare testing data
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Close'])
# Predict stock prices on the test set
y_pred = model.predict(x_test)

# Create an index for the next 30 days
last_index = df.index[-1]
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(x_next_30_days)

# %%
# Evaluate model performance using metrics
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(np.mean((y_pred - y_test)**2))
mape = mean_absolute_percentage_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# Print metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Percentage Error (MAPE):', mape)
print('Mean Absolute Error (MAE):', mae)
# Plot the predictions graph
plt.title('Linear Regression - Stock Price Prediction')
plt.plot(train_data.index, train_data['Close'], label='Train')
plt.plot(test_data.index, test_data['Close'], label='Test')
plt.plot(test_data.index, y_pred, label='Predictions')
plt.plot(range(last_index+1, last_index+31), y_next_30_days, label='Next 30 Days')
plt.legend()
plt.show()
# Out:
# Mean Squared Error (MSE): 478.9994949746648
# Root Mean Squared Error (RMSE): 21.886057090637976
# Mean Absolute Percentage Error (MAPE): 0.22469784914844682
# Mean Absolute Error (MAE): 18.691256626613967

# %% [markdown]
# # Train-test(9-1)

# %%
# Split the data into training and testing sets
train_size = int(0.9 * len(df))
test_size = int(0.1 * len(df))
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]
# Prepare training data
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Close'])

# %%
# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Prepare testing data
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Close'])
# Predict stock prices on the test set
y_pred = model.predict(x_test)

# Create an index for the next 30 days
last_index = df.index[-1]
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

# Predict the closing prices for the next 30 days
y_next_30_days = model.predict(x_next_30_days)

# %%
# Evaluate model performance using metrics
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(np.mean((y_pred - y_test)**2))
mape = mean_absolute_percentage_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# Print metrics
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Percentage Error (MAPE):', mape)
print('Mean Absolute Error (MAE):', mae)
# Plot the predictions graph
plt.title('Linear Regression - Stock Price Prediction')
plt.plot(train_data.index, train_data['Close'], label='Train')
plt.plot(test_data.index, test_data['Close'], label='Test')
plt.plot(test_data.index, y_pred, label='Predictions')
plt.plot(range(last_index+1, last_index+31), y_next_30_days, label='Next 30 Days')
plt.legend()
plt.show()
# Out:
# Mean Squared Error (MSE): 58.50467536129646
# Root Mean Squared Error (RMSE): 7.648834902212
# Mean Absolute Percentage Error (MAPE): 0.05835207519091654
# Mean Absolute Error (MAE): 5.732038578297139
