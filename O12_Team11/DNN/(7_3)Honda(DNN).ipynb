# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.losses import Huber
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
# Load data
df = pd.read_csv('Honda.csv', delimiter=';')

# Convert 'Date' to datetime
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
df['Price'] = df['Price'].str.replace(',', '.').astype(float)

# %%
# Choose 'Price' as the dependent variable (output)
y = df['Price'].values

# Use only the 'Price' column as the independent variable (input)
X = df['Price'].values.reshape(-1, 1)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=False)

# Standardize the data
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1, 1)).reshape(-1)
y_test_scaled = scaler_y.transform(y_test.reshape(-1, 1)).reshape(-1)

# %%
# Build the DNN model
model = Sequential()
model.add(Dense(64, input_dim=1, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='linear'))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train_scaled, y_train_scaled, epochs=50, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/50
# 26/26 [==============================] - 4s 57ms/step - loss: 0.6475 - val_loss: 0.1406
# Epoch 2/50
# 26/26 [==============================] - 2s 69ms/step - loss: 0.1327 - val_loss: 0.0043
# Epoch 3/50
# 26/26 [==============================] - 1s 22ms/step - loss: 0.0473 - val_loss: 0.0026
# Epoch 4/50
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0498 - val_loss: 0.0020
# Epoch 5/50
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0403 - val_loss: 9.9115e-04
# Epoch 6/50
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0375 - val_loss: 8.8648e-04
# Epoch 7/50
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0401 - val_loss: 0.0013
# Epoch 8/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0339 - val_loss: 4.9807e-04
# Epoch 9/50
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0327 - val_loss: 8.0758e-04
# Epoch 10/50
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0338 - val_loss: 1.2078e-04
# Epoch 11/50
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0300 - val_loss: 1.0241e-04
# Epoch 12/50
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0275 - val_loss: 7.5151e-04
# Epoch 13/50
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0292 - val_loss: 0.0021
# Epoch 14/50
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0324 - val_loss: 3.0260e-04
# Epoch 15/50
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0305 - val_loss: 4.0744e-05
# Epoch 16/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0265 - val_loss: 7.2452e-05
# Epoch 17/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0290 - val_loss: 0.0021
# Epoch 18/50
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0265 - val_loss: 6.0312e-04
# Epoch 19/50
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0289 - val_loss: 8.6462e-05
# Epoch 20/50
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0271 - val_loss: 1.9019e-04
# Epoch 21/50
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0274 - val_loss: 0.0012
# Epoch 22/50
# 26/26 [==============================] - 1s 26ms/step - loss: 0.0308 - val_loss: 7.0785e-06
# Epoch 23/50
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0284 - val_loss: 0.0054
# Epoch 24/50
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0258 - val_loss: 0.0051
# Epoch 25/50
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0296 - val_loss: 2.3484e-04
# Epoch 26/50
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0248 - val_loss: 6.2904e-04
# Epoch 27/50
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0278 - val_loss: 0.0017
# Epoch 28/50
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0271 - val_loss: 3.2284e-04
# Epoch 29/50
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0253 - val_loss: 5.2065e-04
# Epoch 30/50
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0212 - val_loss: 8.4180e-04
# Epoch 31/50
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0297 - val_loss: 0.0054
# Epoch 32/50
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0256 - val_loss: 0.0010
# Epoch 33/50
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0307 - val_loss: 1.0035e-04
# Epoch 34/50
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0254 - val_loss: 0.0018
# Epoch 35/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0256 - val_loss: 6.0270e-04
# Epoch 36/50
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0274 - val_loss: 8.7388e-05
# Epoch 37/50
# 26/26 [==============================] - 0s 12ms/step - loss: 0.0234 - val_loss: 0.0033
# Epoch 38/50
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0276 - val_loss: 0.0016
# Epoch 39/50
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0282 - val_loss: 0.0023
# Epoch 40/50
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0258 - val_loss: 0.0014
# Epoch 41/50
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0274 - val_loss: 8.3238e-04
# Epoch 42/50
# 26/26 [==============================] - 1s 28ms/step - loss: 0.0270 - val_loss: 0.0012
# Epoch 43/50
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0254 - val_loss: 9.8745e-04
# Epoch 44/50
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0309 - val_loss: 0.0013
# Epoch 45/50
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0251 - val_loss: 3.5899e-05
# Epoch 46/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0275 - val_loss: 5.6720e-04
# Epoch 47/50
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0273 - val_loss: 0.0031
# Epoch 48/50
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0296 - val_loss: 5.8122e-04
# Epoch 49/50
# 26/26 [==============================] - 1s 25ms/step - loss: 0.0246 - val_loss: 0.0037
# Epoch 50/50
# 26/26 [==============================] - 1s 24ms/step - loss: 0.0301 - val_loss: 4.3687e-06

# %%
# Predict on the test set
y_test_pred_scaled = model.predict(X_test_scaled)
y_test_pred = scaler_y.inverse_transform(y_test_pred_scaled.reshape(-1, 1)).reshape(-1)

# Evaluate the model
mae_test = mean_absolute_error(y_test, y_test_pred)
rmse_test = np.sqrt(mean_squared_error(y_test, y_test_pred))

# Metrics
print("RMSE:", rmse_test)

# MAPE Calculation
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape_test = mean_absolute_percentage_error(y_test, y_test_pred)
print("MAPE:", mape_test)
print("MAE:", mae_test)

# Huber Loss Calculation
huber_loss = Huber()(y_test, y_test_pred).numpy()
print("Huber Loss:", huber_loss)
# Out:
# 14/14 [==============================] - 1s 7ms/step
# RMSE: 0.3349890714219156
# MAPE: 0.022093489176704506
# MAE: 0.2724439988442512
# Huber Loss: 0.05610752

# %%
# Predict the next 30 days
last_data_point = X_test_scaled[-1].reshape(1, -1)
forecasted_scaled = []

for _ in range(30):
    next_day_pred_scaled = model.predict(last_data_point)
    forecasted_scaled.append(next_day_pred_scaled[0, 0])

    # Update the last data point for the next prediction
    last_data_point = np.roll(last_data_point, -1)
    last_data_point[0, -1] = next_day_pred_scaled[0, 0]

# Convert the forecasted values back to the original scale
forecasted = scaler_y.inverse_transform(np.array(forecasted_scaled).reshape(-1, 1)).reshape(-1)

# Display the forecasted prices for the next 30 days
print("Forecasted Prices for the Next 30 Days:")
print(forecasted)
# Out:
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 203ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# Forecasted Prices for the Next 30 Days:
# [1395.7047 1395.9094 1396.1144 1396.3196 1396.5249 1396.7303 1396.9359
#  1397.1416 1397.3475 1397.5536 1397.7599 1397.9663 1398.1729 1398.3795
#  1398.5864 1398.7935 1399.0006 1399.208  1399.4155 1399.6232 1399.8309
#  1400.039  1400.2471 1400.4553 1400.6638 1400.8724 1401.0812 1401.29
#  1401.4991 1401.7085]

# %%
# Plotting the forecasted prices
plt.figure(figsize=(12, 6))
# Dữ liệu train
plt.plot(df['Date'].iloc[:len(y_train)], y_train, label='Train', color='blue')
plt.plot(df['Date'].iloc[len(y_train):len(y_train) + len(y_test)], y_test, label='Test', color='green')
plt.plot(df['Date'].iloc[len(y_train):len(y_train) + len(y_test)], y_test_pred, label='Test Predicted', color='orange')

next_30_days_index = pd.date_range(df['Date'].iloc[-1], periods=31, freq='D')[1:]
plt.plot(next_30_days_index, forecasted, label='Next 30 Days Forecast', color='red')

plt.title('Stock Price Prediction - DNN Model with 30-Day Forecast')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
