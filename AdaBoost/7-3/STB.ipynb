# %%
#import the library 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error, mean_squared_log_error
from sklearn.tree import DecisionTreeRegressor
import warnings

warnings.filterwarnings('ignore')

# %%
#read data
df = pd.read_csv("../../STB.csv")
df
# Out:
#             Date    Price     Open     High      Low    Vol. Change %
# 0       1/2/2018  13400.0  12850.0  13500.0  12700.0  16.33M    4.28%
# 1       1/3/2018  13350.0  13500.0  13600.0  13250.0  15.70M   -0.37%
# 2       1/4/2018  13600.0  13350.0  13850.0  13350.0  26.49M    1.87%
# 3       1/5/2018  13600.0  13700.0  13800.0  13450.0  17.26M    0.00%
# 4       1/8/2018  14550.0  13700.0  14550.0  13700.0  33.85M    6.99%
# ...          ...      ...      ...      ...      ...     ...      ...
# 1487  12/15/2023  27100.0  27100.0  27450.0  27050.0  12.86M    0.00%
# 1488  12/18/2023  26300.0  27100.0  27200.0  26300.0  21.73M   -2.95%
# 1489  12/19/2023  26600.0  26300.0  26600.0  25850.0  18.26M    1.14%
# 1490  12/20/2023  26950.0  26700.0  26950.0  26450.0   8.22M    1.32%
# 1491  12/21/2023  26600.0  26750.0  26850.0  26500.0  10.02M   -1.30%
#
# [1492 rows x 7 columns]

# %%
#Choose the independent, dependent variables
y = df[["Price"]] # predictor 
X= df[["High"]] #independent variable
plt.plot(X)
plt.plot(y)
plt.show()

# %%
# Split the data into training, testing sets by 7:3
train_size = int(0.7 * len(df))
test_size = len(df) - train_size

y_train = y[:train_size]
X_train = X[:train_size]
y_test = y[train_size:]
X_test = X[train_size:]

# %%
# params = {
#     'n_estimators': [50, 100, 200],
#     'learning_rate': [0.01, 0.1, 0.2],
#     'loss': ['linear', 'square', 'exponential'],
#     'estimator': [None, DecisionTreeRegressor(max_depth=3), DecisionTreeRegressor(max_depth=5)],
#     'random_state': [42],
# }

# # Create an AdaBoostRegressor instance
# abr = AdaBoostRegressor()

# # Create a GridSearchCV instance
# model = GridSearchCV(
#     estimator=abr,
#     param_grid=params,
#     scoring='neg_mean_squared_error',
#     verbose=1
# )

# # Fit the model
# model.fit(X_train, y_train)

# # Print the best parameters and lowest RMSE
# print("Best parameters:", model.best_params_)
# print("Lowest RMSE:", (-model.best_score_) ** 0.5)

# %%
#Create model with hyperparameter
model = AdaBoostRegressor(
    base_estimator=DecisionTreeRegressor(max_depth=5),
    n_estimators=200,
    learning_rate=0.1,
    loss='square',
    random_state=42
)
model.fit(X_train, y_train)
# Out:
# AdaBoostRegressor(base_estimator=DecisionTreeRegressor(max_depth=5),
#                   learning_rate=0.1, loss='square', n_estimators=200,
#                   random_state=42)

# %%
#make predictions for test data
y_pred = model.predict(X_test)
y_pred = y_pred.reshape(-1,1)

# %%
#calculate some metrics
mape = mean_absolute_percentage_error(y_test, y_pred) * 100
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(np.mean((y_pred - y_test)**2))
msle = mean_squared_log_error(y_test, y_pred)
print("MAPE:", mape)
print("MAE: ",  mae)
print("RMSE:", rmse)
print("MSLE: ", msle)
# Out:
# MAPE: 1.7796773120979628
# MAE:  444.5362022359354
# RMSE: 572.4968151082224
# MSLE:  0.000528040220419575

# %%
#vẽ mô hình
plt.figure(figsize=(12, 5))
plt.plot(y_train, label='Train data', color = 'b')
plt.plot(y_test, label='Test data')
plt.plot(X_test.index, y_pred, label='Predict test data')
plt.ylabel('Close Price (VND)')
plt.legend()
plt.show()

# %%
#Take the last data from the test
last_row = df.tail(1)
last_data = (last_row['High']).values.reshape(-1,1)
last_data
# Out:
# array([[26850.]])

# %%
#Make prediction for next 30 days
x_next_30_day = []

for i in range(30):
    x_pred_next = model.predict(last_data)
    x_next_30_day.append(x_pred_next)
    last_data = (x_pred_next).reshape(-1,1)

print("Ket qua du doan XGBoost ", x_next_30_day)
# Out:
# Ket qua du doan XGBoost  [array([26500.]), array([26330.55555556]), array([26296.42857143]), array([25807.14285714]), array([25666.66666667]), array([24683.33333333]), array([24255.55555556]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5]), array([24237.5])]

# %%
#vẽ mô hình
plt.figure(figsize=(12, 5))
plt.plot(y_train, label='Train data', color = 'b')
plt.plot(y_test, label='Test data')
plt.plot(range(len(df), len(df)+30),x_next_30_day, label='Predict')
plt.plot(X_test.index, y_pred, label='Predict test data')
plt.ylabel('Close Price (VND)')
plt.legend()
plt.show()

# %%
# Vẽ biểu đồ
plt.plot(x_next_30_day, marker='o', color='b', label='Predicted Next 30 Days')

# Đặt tiêu đề và nhãn
plt.title('Predicted Values for the Next 30 Days')
plt.xlabel('Date')
plt.ylabel('Predicted Value')
plt.xticks(rotation=45) # Rotate x-axis labels for better readability
plt.legend()

# Hiển thị biểu đồ
plt.show()
