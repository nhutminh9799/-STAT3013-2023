# %%
# 1. Các thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder,StandardScaler,PowerTransformer, MinMaxScaler, RobustScaler
from sklearn.model_selection import KFold, cross_val_predict, train_test_split,GridSearchCV,cross_val_score

from sklearn.linear_model import LinearRegression, Lasso, Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_squared_error

# %%
# 2. Đọc file dữ liệu
df = pd.read_csv('CTG.csv')
df['Date'] = pd.to_datetime(df['Date'])
train_dates= pd.to_datetime(df['Date'])
df.head()
len(df)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6092\853177287.py:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# 1751

# %%
# Xem data 
df
# Out:
#            Date  Price   Open   High    Low
# 0    2016-01-20  11656  11931  11931  11656
# 1    2016-01-21  11311  11587  11725  11242
# 2    2016-01-22  11104  11311  11380  10897
# 3    2016-01-25  11862  11380  11862  11380
# 4    2016-01-26  12000  11725  12000  11587
# ...         ...    ...    ...    ...    ...
# 1746 2023-01-13  29100  29100  29200  28400
# 1747 2023-01-16  30000  29100  30000  28900
# 1748 2023-01-17  30600  30100  30650  30100
# 1749 2023-01-18  30750  30600  30850  30400
# 1750 2023-01-19  31100  30700  31100  30150
#
# [1751 rows x 5 columns]

# %%
# Split data into training (80%) and test (20%)
train_data, test_data = train_test_split(df, test_size=0.2, shuffle=False)

# %%
# Drop the 'Date' column from both X_train and X_test
X_train = train_data.drop(['Price', 'Date'], axis=1)
y_train = train_data['Price']

X_test = test_data.drop(['Price', 'Date'], axis=1)
y_test = test_data['Price']

model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# %%
n_days_for_prediction= 30
cols = list(df)[1:4]
predict_period_dates = pd.date_range(list(train_dates)[-1], periods=n_days_for_prediction).tolist()
print(predict_period_dates)

predict_period_dates_index = pd.RangeIndex(start=len(df),stop=len(df)+30,step=1)

#Make prediction
prediction1 = model.predict(X_test[-n_days_for_prediction:])
df_for_training = df[cols].astype(float)
print(prediction1)
# Out:
# [Timestamp('2023-01-19 00:00:00', freq='D'), Timestamp('2023-01-20 00:00:00', freq='D'), Timestamp('2023-01-21 00:00:00', freq='D'), Timestamp('2023-01-22 00:00:00', freq='D'), Timestamp('2023-01-23 00:00:00', freq='D'), Timestamp('2023-01-24 00:00:00', freq='D'), Timestamp('2023-01-25 00:00:00', freq='D'), Timestamp('2023-01-26 00:00:00', freq='D'), Timestamp('2023-01-27 00:00:00', freq='D'), Timestamp('2023-01-28 00:00:00', freq='D'), Timestamp('2023-01-29 00:00:00', freq='D'), Timestamp('2023-01-30 00:00:00', freq='D'), Timestamp('2023-01-31 00:00:00', freq='D'), Timestamp('2023-02-01 00:00:00', freq='D'), Timestamp('2023-02-02 00:00:00', freq='D'), Timestamp('2023-02-03 00:00:00', freq='D'), Timestamp('2023-02-04 00:00:00', freq='D'), Timestamp('2023-02-05 00:00:00', freq='D'), Timestamp('2023-02-06 00:00:00', freq='D'), Timestamp('2023-02-07 00:00:00', freq='D'), Timestamp('2023-02-08 00:00:00', freq='D'), Timestamp('2023-02-09 00:00:00', freq='D'), Timestamp('2023-02-10 00:00:00', freq='D'), Timestamp('2023-02-11 00:00:00', freq='D'), Timestamp('2023-02-12 00:00:00', freq='D'), Timestamp('2023-02-13 00:00:00', freq='D'), Timestamp('2023-02-14 00:00:00', freq='D'), Timestamp('2023-02-15 00:00:00', freq='D'), Timestamp('2023-02-16 00:00:00', freq='D'), Timestamp('2023-02-17 00:00:00', freq='D')]
# [28496.80903259 27329.83815937 27651.80912814 27850.7066946
#  27920.75267428 28138.13216086 28118.57004051 27994.85330167
#  27088.05764057 27105.28864998 27999.25534985 27660.01162983
#  26260.59066108 26519.80866212 26809.39452883 27217.64577017
#  27033.08226984 27766.71579112 28631.88539009 28442.65966788
#  28710.39404516 28979.50830179 28592.5069552  29009.82246661
#  28828.19765141 28538.01019001 29646.25296035 30506.11102141
#  30578.91899622 30518.55084029]

# %%
# 6. Vẽ hình
plt.figure(figsize=(10, 6))
plt.plot(test_data.index, test_data['Price'], linestyle='-', color='r', label='Test Data (Actual)')
plt.plot(train_data.index, train_data['Price'], linestyle='-', color='b', label='Training Data (Actual)')
plt.plot(test_data.index, y_pred, linestyle='-', color='orange', label='Test Data (Predicted)')
plt.plot(predict_period_dates_index, prediction1, linestyle='-', color='g', label='Predict for 60 next days')
plt.title('Stock Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
len(prediction1)
# Out:
# 30

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
# 7. Đánh giá độ chính xác test
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
test_mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
test_mae = mean_absolute_error(y_test, y_pred)

print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 286.7502987793635
# Testing MAPE: 0.7600195362820549
# Testing MAE: 212.5495457748961
