# %%
pip install filterpy
# Out:
# Requirement already satisfied: filterpy in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (1.4.5)
# Requirement already satisfied: numpy in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from filterpy) (1.25.2)
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from filterpy) (3.6.2)
# Requirement already satisfied: scipy in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from filterpy) (1.11.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->filterpy) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->filterpy) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->filterpy) (9.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->filterpy) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->filterpy) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->filterpy) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->filterpy) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->filterpy) (1.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->filterpy) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\admin\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\admin\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\admin\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\admin\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\admin\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\admin\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -lotly (c:\users\admin\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from filterpy.kalman import KalmanFilter

# %%
# Load dữ liệu từ file CSV
df = pd.read_csv("C:\\Users\\ADMIN\\Downloads\\VCBB.csv", header=0, parse_dates=[0], index_col=0)
df = df[['Price']]
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_19140\4001148701.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df = pd.read_csv("C:\\Users\\ADMIN\\Downloads\\VCBhuy.csv", header=0, parse_dates=[0], index_col=0)

# %%
df = df.dropna()
df = df.reset_index(drop=True)
train_size = int(0.7 * len(df))
test_size = int(0.3 * len(df))
train_data = df[:train_size]
test_data = df[train_size:train_size+test_size]

# %%
kf = KalmanFilter(dim_x=2, dim_z=1)
kf.F = np.array([[1, 1], [0, 1]])  # ma trận trạng thái
kf.H = np.array([[1, 0]])          # ma trận quan sát
kf.Q = np.array([[0.001, 0], [0, 0.001]])  # ma trận nhiễu quá trình
kf.R = np.array([[0.1]])           # ma trận nhiễu quan sát
kf.P *= 1000

# %%
filtered_train_state_means = []
for price in train_data['Price'].values:
    kf.predict()
    kf.update(np.array([[price]]))
    filtered_train_state_means.append(kf.x[0][0])

# %%
filtered_test_state_means = []
predictions = []
for price in test_data['Price'].values:
    kf.predict()
    kf.update(np.array([[price]]))
    filtered_test_state_means.append(kf.x[0][0])
    predictions.append(kf.x[0][0])

predictions_30_days = []
for _ in range(30):
    kf.predict()
    predictions_30_days.append(kf.x[0][0])

# %%
test_rmse = np.sqrt(np.mean((predictions - test_data['Price'].values)**2))
test_mape = np.mean(np.abs((predictions - test_data['Price'].values) / test_data['Price'].values)) * 100
test_mae = np.mean(np.abs(predictions - test_data['Price'].values))
print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 1182.1446476105489
# Testing MAPE: 1.13592318817281
# Testing MAE: 888.3819530750299

# %%
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(test_data.index, predictions)

# Use the last index of the test data to start the 30-day prediction plot
plt.plot(range(test_data.index[-1] + 1, test_data.index[-1] + 31), predictions_30_days)

plt.legend(['Train', 'Test', 'Predictions', 'Next30Day'])
plt.show()
