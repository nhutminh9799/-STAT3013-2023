# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.metrics import MeanAbsolutePercentageError
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, GlobalAveragePooling1D, GlobalMaxPooling1D

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error

from sklearn.utils import check_array

from scikeras.wrappers import KerasClassifier, KerasRegressor

from sklearn.model_selection import GridSearchCV

# %%
# Đọc dữ liệu từ tệp CSV
data = pd.read_csv(r'D:\BID.csv')

# %%
# Xử lý dữ liệu
prices = data['Price']

# %%
# Chuẩn hóa dữ liệu
scaler = MinMaxScaler()
scaled_prices = scaler.fit_transform(prices.values.reshape(-1, 1))

# %%
# Chia dữ liệu thành tập train test
np.random.seed(42)

train_size = int(len(scaled_prices) * 0.9)
test_size = int(len(scaled_prices) * 0.1)

train_data = scaled_prices[:train_size]
test_data = scaled_prices[train_size:train_size+test_size]

# %%
# Chia dữ liệu thành các mẫu chuỗi thời gian
def create_time_series(data, time_steps):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i+time_steps])
        y.append(data[i+time_steps])
    return np.array(X), np.array(y)

# %%
time_steps = 30  # Số ngày quan sát trước để dự đoán ngày tiếp theo #sửa 30 thành 10
X_train, y_train = create_time_series(train_data, time_steps)
X_test, y_test = create_time_series(test_data, time_steps)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# define FCN model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(time_steps, 1)))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))

model.add(GlobalMaxPooling1D())
model.add(Dense(64, activation='relu'))
model.add(Dense(1))

# %%
# Biên dịch mô hình
model.compile(optimizer='adam', loss='mean_squared_error')

# Huấn luyện mô hình
model.fit(X_train, y_train, epochs=100, batch_size=64)

# Đánh giá mô hình trên tập kiểm tra
loss = model.evaluate(X_test, y_test)
print('Loss trên tập kiểm tra:', loss)
# Out:
# Epoch 1/100
# 35/35 [==============================] - 1s 4ms/step - loss: 0.0385
# Epoch 2/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 3/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 4/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0029
# Epoch 5/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 6/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0029
# Epoch 7/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0028
# Epoch 8/100
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0027
# Epoch 9/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 10/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0027
# Epoch 11/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 12/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 13/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 14/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 15/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0023
# Epoch 16/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 17/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 18/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 19/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 20/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 21/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 22/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 23/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 24/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 25/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 26/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0021
# Epoch 27/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0017
# Epoch 28/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 29/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0016
# Epoch 30/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 31/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 32/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0014
# Epoch 33/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0015
# Epoch 34/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0013
# Epoch 35/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 36/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 37/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 38/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 39/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 40/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 41/100
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 42/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 43/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 44/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 45/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 46/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 47/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 48/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 49/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 50/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 51/100
# 35/35 [==============================] - 0s 4ms/step - loss: 9.7264e-04
# Epoch 52/100
# 35/35 [==============================] - 0s 4ms/step - loss: 9.3260e-04
# Epoch 53/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.2653e-04
# Epoch 54/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 55/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.7290e-04
# Epoch 56/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 57/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 58/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 59/100
# 35/35 [==============================] - 0s 3ms/step - loss: 8.8349e-04
# Epoch 60/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.6383e-04
# Epoch 61/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.6718e-04
# Epoch 62/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.7741e-04
# Epoch 63/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.1948e-04
# Epoch 64/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.1895e-04
# Epoch 65/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 66/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 67/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.7605e-04
# Epoch 68/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.8288e-04
# Epoch 69/100
# 35/35 [==============================] - 0s 3ms/step - loss: 8.6348e-04
# Epoch 70/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 71/100
# 35/35 [==============================] - 0s 3ms/step - loss: 8.8475e-04
# Epoch 72/100
# 35/35 [==============================] - 0s 3ms/step - loss: 8.7301e-04
# Epoch 73/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 74/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.4466e-04
# Epoch 75/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 76/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 77/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 78/100
# 35/35 [==============================] - 0s 3ms/step - loss: 8.9457e-04
# Epoch 79/100
# 35/35 [==============================] - 0s 3ms/step - loss: 8.2669e-04
# Epoch 80/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.4480e-04
# Epoch 81/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.3965e-04
# Epoch 82/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.3039e-04
# Epoch 83/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.2290e-04
# Epoch 84/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.8999e-04
# Epoch 85/100
# 35/35 [==============================] - 0s 3ms/step - loss: 8.3348e-04
# Epoch 86/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.1056e-04
# Epoch 87/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 88/100
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 89/100
# 35/35 [==============================] - 0s 3ms/step - loss: 8.6341e-04
# Epoch 90/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.2146e-04
# Epoch 91/100
# 35/35 [==============================] - 0s 3ms/step - loss: 7.7583e-04
# Epoch 92/100
# 35/35 [==============================] - 0s 4ms/step - loss: 8.3601e-04
# Epoch 93/100
# 35/35 [==============================] - 0s 3ms/step - loss: 7.9912e-04
# Epoch 94/100
# 35/35 [==============================] - 0s 3ms/step - loss: 8.0111e-04
# Epoch 95/100
# 35/35 [==============================] - 0s 3ms/step - loss: 9.9839e-04
# Epoch 96/100
# 35/35 [==============================] - 0s 3ms/step - loss: 7.7389e-04
# Epoch 97/100
# 35/35 [==============================] - 0s 3ms/step - loss: 8.2173e-04
# Epoch 98/100
# 35/35 [==============================] - 0s 4ms/step - loss: 8.4871e-04
# Epoch 99/100
# 35/35 [==============================] - 0s 4ms/step - loss: 8.7071e-04
# Epoch 100/100
# 35/35 [==============================] - 0s 4ms/step - loss: 7.5143e-04
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0073
# Loss trên tập kiểm tra: 0.007321999408304691

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

# Tạo biến train, test
train = prices[:train_size]
test = prices[train_size:train_size+test_size]

y_test_pred = model.predict(X_test)
y_test_pred = scaler.inverse_transform(y_test_pred)

n_past = 1
n_days_for_prediction= 30

#create an array of 30 integers starting from last index
predict_period_dates = np.array(range(len(data) + 1,len(data) + 31)).reshape(-1, 1)

print(predict_period_dates)

#Make prediction
prediction1 = model.predict(X_test[-n_days_for_prediction:])

prediction_copies1 = np.repeat(prediction1, prices.shape[0], axis=-1)
predicted_prices = scaler.inverse_transform(prediction_copies1)[:,0]
print(predicted_prices)
# Out:
# 7/7 [==============================] - 0s 2ms/step
# [[2472]
#  [2473]
#  [2474]
#  [2475]
#  [2476]
#  [2477]
#  [2478]
#  [2479]
#  [2480]
#  [2481]
#  [2482]
#  [2483]
#  [2484]
#  [2485]
#  [2486]
#  [2487]
#  [2488]
#  [2489]
#  [2490]
#  [2491]
#  [2492]
#  [2493]
#  [2494]
#  [2495]
#  [2496]
#  [2497]
#  [2498]
#  [2499]
#  [2500]
#  [2501]]
# 1/1 [==============================] - 0s 28ms/step
# [38483.55  39068.258 39866.176 39799.38  39911.816 40337.24  40705.3
#  40729.402 40704.645 40871.684 40879.777 40898.812 41222.67  41286.527
#  39255.473 37028.832 34796.375 34796.375 34796.375 34796.375 34796.375
#  34796.375 35110.426 35210.797 35203.44  35203.44  35203.44  35203.44
#  35203.44  35203.44 ]

# %%
# Tạo biểu đồ train, test và dự đoán 30 ngày tiếp theo
plt.figure(figsize=(10, 6))
plt.plot(train, label='Train')
plt.plot(range(train_size, train_size + len(test)), test, label='Test')

plt.plot(range(train_size + time_steps,train_size + test_size), y_test_pred, 'g', label='Test Predicted')

plt.plot(predict_period_dates, predicted_prices, 'r', label='Next 30 days')

plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, mean_squared_log_error

# Dự đoán giá trong quá trình testing
y_test_predicted = model.predict(X_test)

# Đưa các dự đoán về lại tỷ lệ ban đầu
y_test_predicted = scaler.inverse_transform(y_test_predicted)

y_test1 = scaler.inverse_transform(y_test)


# Tính MAE cho testing
mae_test = mean_absolute_error(y_test1, y_test_predicted)

# Tính MAPE cho testing
mape_test = mean_absolute_percentage_error(y_test1, y_test_predicted)

# Tính RMSE cho testing
rmse_test = mean_squared_error(y_test1, y_test_predicted, squared=False)

# Tính MSLE cho testing
msle_test = mean_squared_log_error(y_test1, y_test_predicted, squared=False)
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %%
mape_test *= 100


print('---------TEST----------')
print("MAPE:", round(mape_test,3))
print("MAE:", round(mae_test,3))
print("RMSE:", round(rmse_test,3))
print("MSLE:", round(msle_test,3))
print('-------------------')
# Out:
# ---------TEST----------
# MAPE: 7.233
# MAE: 3223.921
# RMSE: 3516.326
# MSLE: 0.083
# -------------------
