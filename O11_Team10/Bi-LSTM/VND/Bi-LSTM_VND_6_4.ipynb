# %%
# load các thư viện cần thiết
import math
from vnstock import *
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM, Bidirectional
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import KFold, cross_val_predict, train_test_split,GridSearchCV,cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder,StandardScaler,PowerTransformer, MinMaxScaler, RobustScaler

# %%
#2. Fetch data and visualize
# VND
VND = stock_historical_data(symbol = "VND", start_date="2017-06-01", end_date="2023-12-15", resolution="1D", type = "stock", beautify=True, decor=True, source = "DNSE")
from matplotlib import pyplot
print("Observations: ",len(VND['Close']))
train_dates = VND.index
df = VND["Close"]
df.plot()
# Out:
# Observations:  1630
# <Axes: xlabel='Time'>

# %%
# Split data into training (60%) and test (40%)
np.random.seed(28)
train, test = train_test_split(df, test_size=0.4, shuffle=False)

# %%
# Chuẩn hóa dữ liệu
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(df.values.reshape(-1, 1))

train_data =  scaler.fit_transform(train.values.reshape(-1, 1))
test_data = scaler.fit_transform(test.values.reshape(-1, 1))

# %%
# Chia dữ liệu thành các mẫu chuỗi thời gian
def create_time_series(data, time_steps):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i+time_steps])
        y.append(data[i+time_steps])
    return np.array(X), np.array(y)

# %%
time_steps = 30  # Số ngày quan sát trước để dự đoán ngày tiếp theo
X_train, y_train = create_time_series(train_data, time_steps)
X_test, y_test = create_time_series(test_data, time_steps)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Tạo model lstm cho việc training
# BILSTM
model = Sequential()
model.add(Bidirectional(LSTM(64, activation='relu', return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Bidirectional(LSTM(32, activation='relu', return_sequences=False)))
model.add(Dropout(0.2))
model.add(Dense(y_train.shape[1]))
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_4 (Bidirecti  (None, 30, 128)           33792
#  onal)
#
#  bidirectional_5 (Bidirecti  (None, 64)                41216
#  onal)
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 75073 (293.25 KB)
# Trainable params: 75073 (293.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fit the model
history = model.fit(X_train, y_train, epochs=50, batch_size=10, validation_split=0.1, verbose=1)
# Out:
# Epoch 1/50
# 86/86 [==============================] - 5s 19ms/step - loss: 0.0063 - val_loss: 0.0093
# Epoch 2/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0019 - val_loss: 0.0064
# Epoch 3/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0015 - val_loss: 0.0172
# Epoch 4/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0016 - val_loss: 0.0259
# Epoch 5/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0018 - val_loss: 0.0107
# Epoch 6/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0012 - val_loss: 0.0093
# Epoch 7/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0012 - val_loss: 0.0061
# Epoch 8/50
# 86/86 [==============================] - 1s 13ms/step - loss: 0.0011 - val_loss: 0.0082
# Epoch 9/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0011 - val_loss: 0.0036
# Epoch 10/50
# 86/86 [==============================] - 1s 13ms/step - loss: 8.0058e-04 - val_loss: 0.0091
# Epoch 11/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0013 - val_loss: 0.0069
# Epoch 12/50
# 86/86 [==============================] - 1s 14ms/step - loss: 0.0010 - val_loss: 0.0059
# Epoch 13/50
# 86/86 [==============================] - 1s 14ms/step - loss: 7.7441e-04 - val_loss: 0.0042
# Epoch 14/50
# 86/86 [==============================] - 1s 14ms/step - loss: 8.4370e-04 - val_loss: 0.0036
# Epoch 15/50
# 86/86 [==============================] - 1s 13ms/step - loss: 6.8087e-04 - val_loss: 0.0030
# Epoch 16/50
# 86/86 [==============================] - 1s 12ms/step - loss: 8.3617e-04 - val_loss: 0.0064
# Epoch 17/50
# 86/86 [==============================] - 1s 12ms/step - loss: 7.7186e-04 - val_loss: 0.0069
# Epoch 18/50
# 86/86 [==============================] - 1s 13ms/step - loss: 7.1812e-04 - val_loss: 0.0045
# Epoch 19/50
# 86/86 [==============================] - 1s 13ms/step - loss: 6.7428e-04 - val_loss: 0.0022
# Epoch 20/50
# 86/86 [==============================] - 1s 12ms/step - loss: 7.6815e-04 - val_loss: 0.0040
# Epoch 21/50
# 86/86 [==============================] - 1s 13ms/step - loss: 6.8973e-04 - val_loss: 0.0061
# Epoch 22/50
# 86/86 [==============================] - 1s 12ms/step - loss: 7.0466e-04 - val_loss: 0.0022
# Epoch 23/50
# 86/86 [==============================] - 1s 12ms/step - loss: 7.1940e-04 - val_loss: 0.0036
# Epoch 24/50
# 86/86 [==============================] - 1s 12ms/step - loss: 6.3643e-04 - val_loss: 0.0022
# Epoch 25/50
# 86/86 [==============================] - 1s 12ms/step - loss: 6.2809e-04 - val_loss: 0.0072
# Epoch 26/50
# 86/86 [==============================] - 1s 12ms/step - loss: 6.7712e-04 - val_loss: 0.0017
# Epoch 27/50
# 86/86 [==============================] - 1s 13ms/step - loss: 6.0808e-04 - val_loss: 0.0049
# Epoch 28/50
# 86/86 [==============================] - 1s 13ms/step - loss: 7.2942e-04 - val_loss: 0.0066
# Epoch 29/50
# 86/86 [==============================] - 1s 13ms/step - loss: 5.8352e-04 - val_loss: 0.0048
# Epoch 30/50
# 86/86 [==============================] - 1s 13ms/step - loss: 6.2474e-04 - val_loss: 0.0067
# Epoch 31/50
# 86/86 [==============================] - 1s 12ms/step - loss: 7.5139e-04 - val_loss: 0.0065
# Epoch 32/50
# 86/86 [==============================] - 1s 12ms/step - loss: 6.5677e-04 - val_loss: 0.0032
# Epoch 33/50
# 86/86 [==============================] - 1s 12ms/step - loss: 5.5835e-04 - val_loss: 0.0059
# Epoch 34/50
# 86/86 [==============================] - 1s 12ms/step - loss: 5.1256e-04 - val_loss: 0.0049
# Epoch 35/50
# 86/86 [==============================] - 1s 13ms/step - loss: 5.3751e-04 - val_loss: 0.0035
# Epoch 36/50
# 86/86 [==============================] - 1s 14ms/step - loss: 5.7664e-04 - val_loss: 0.0016
# Epoch 37/50
# 86/86 [==============================] - 1s 13ms/step - loss: 6.9337e-04 - val_loss: 0.0022
# Epoch 38/50
# 86/86 [==============================] - 1s 13ms/step - loss: 6.1962e-04 - val_loss: 0.0045
# Epoch 39/50
# 86/86 [==============================] - 1s 14ms/step - loss: 5.7577e-04 - val_loss: 0.0030
# Epoch 40/50
# 86/86 [==============================] - 1s 14ms/step - loss: 6.3598e-04 - val_loss: 0.0047
# Epoch 41/50
# 86/86 [==============================] - 1s 13ms/step - loss: 6.2531e-04 - val_loss: 0.0018
# Epoch 42/50
# 86/86 [==============================] - 1s 14ms/step - loss: 5.2342e-04 - val_loss: 0.0036
# Epoch 43/50
# 86/86 [==============================] - 1s 14ms/step - loss: 6.2083e-04 - val_loss: 0.0024
# Epoch 44/50
# 86/86 [==============================] - 1s 13ms/step - loss: 6.0765e-04 - val_loss: 0.0067
# Epoch 45/50
# 86/86 [==============================] - 1s 13ms/step - loss: 5.7356e-04 - val_loss: 0.0030
# Epoch 46/50
# 86/86 [==============================] - 1s 13ms/step - loss: 5.4314e-04 - val_loss: 0.0047
# Epoch 47/50
# 86/86 [==============================] - 1s 13ms/step - loss: 4.3775e-04 - val_loss: 0.0027
# Epoch 48/50
# 86/86 [==============================] - 1s 13ms/step - loss: 5.5462e-04 - val_loss: 0.0018
# Epoch 49/50
# 86/86 [==============================] - 1s 13ms/step - loss: 5.1214e-04 - val_loss: 0.0073
# Epoch 50/50
# 86/86 [==============================] - 1s 13ms/step - loss: 5.7804e-04 - val_loss: 0.0015

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, mean_squared_log_error

# Dự đoán giá trong quá trình testing
y_test_predicted = model.predict(X_test)

# Đưa các dự đoán về lại tỷ lệ ban đầu
y_test_predicted1 = scaler.inverse_transform(y_test_predicted)

y_test1 = scaler.inverse_transform(y_test)


# Tính MAE cho testing
mae_test = mean_absolute_error(y_test1, y_test_predicted1)

# Tính MAPE cho testing
mape_test = mean_absolute_percentage_error(y_test1, y_test_predicted1) * 100

# Tính RMSE cho testing
rmse_test = mean_squared_error(y_test1, y_test_predicted1, squared=False)

# Tính MSLE cho testing
msle_test = mean_squared_log_error(y_test1, y_test_predicted1, squared=False)
# Out:
# 20/20 [==============================] - 0s 5ms/step

# %%
print('---------TEST----------')
print("MAPE:", round(mape_test,3))
print("MAE:", round(mae_test,3))
print("RMSE:", round(rmse_test,3))
print("MSLE:", round(msle_test,3))
print('-------------------')
# Out:
# ---------TEST----------
# MAPE: 3.19
# MAE: 648.202
# RMSE: 867.141
# MSLE: 0.042
# -------------------

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

y_test_pred = scaler.inverse_transform(y_test_predicted)

n_past = 1
n_days_for_prediction= 60

#create an array of next 60 dates starting from last date in dataset
predict_period_dates = pd.date_range(list(train_dates)[-n_past], periods=n_days_for_prediction).tolist()

# print(predict_period_dates)

#Make prediction
prediction = model.predict(X_test[-n_days_for_prediction:])

prediction_copies = np.repeat(prediction, df.shape[0], axis=-1)
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]
# Out:
# 2/2 [==============================] - 0s 13ms/step

# %%
# Tạo biểu đồ train, test và dự đoán 60 ngày tiếp theo
plt.figure(figsize=(10, 6))
plt.plot(train.index, train.values, linestyle='-', color='b', label='Training Data')
plt.plot(test.index,test.values, linestyle='-',  color='r', label='Test Data')
predict_date = test.index;
plt.plot(predict_date[30:],  y_test_pred, label='Predict', linestyle='-',  color='orange')
# # Plot predicted values
plt.plot( predict_period_dates, y_pred_future, label='Predict next 60 days in the future', linestyle='-',  color='g')

plt.title('VND - Actual vs Predicted Stock Price Over Time')
plt.xlabel('Time')
plt.ylabel('Close')
plt.legend()
plt.show()
