# %%
# !pip install EMD-signal
# !pip install vnstock
# Out:
# Collecting EMD-signal
#   Downloading EMD_signal-1.5.2-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 359.8 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from EMD-signal) (1.23.5)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.10/dist-packages (from EMD-signal) (1.11.4)
# Collecting pathos>=0.2.1 (from EMD-signal)
#   Downloading pathos-0.3.1-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 2.7 MB/s eta 0:00:00
# Collecting tqdm==4.64.* (from EMD-signal)
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 5.3 MB/s eta 0:00:00
# Collecting ppft>=1.7.6.7 (from pathos>=0.2.1->EMD-signal)
#   Downloading ppft-1.7.6.7-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 6.1 MB/s eta 0:00:00
# Collecting dill>=0.3.7 (from pathos>=0.2.1->EMD-signal)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 4.7 MB/s eta 0:00:00
# Collecting pox>=0.3.3 (from pathos>=0.2.1->EMD-signal)
#   Downloading pox-0.3.3-py3-none-any.whl (29 kB)
# Collecting multiprocess>=0.70.15 (from pathos>=0.2.1->EMD-signal)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.6 MB/s eta 0:00:00
# Installing collected packages: tqdm, ppft, pox, dill, multiprocess, pathos, EMD-signal
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.1
#     Uninstalling tqdm-4.66.1:
#       Successfully uninstalled tqdm-4.66.1
# Successfully installed EMD-signal-1.5.2 dill-0.3.7 multiprocess-0.70.15 pathos-0.3.1 pox-0.3.3 ppft-1.7.6.7 tqdm-4.64.1
# Collecting vnstock
#   Downloading vnstock-0.2.8.7-py3-none-any.whl (36 kB)
# Installing collected packages: vnstock
# Successfully installed vnstock-0.2.8.7

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import PyEMD as pe
from vnstock import *

# %%
# Import data
VIB = stock_historical_data(symbol = "VIB", start_date="2017-06-01", end_date="2023-12-15", resolution="1D", type = "stock", beautify=True, decor=True, source = "DNSE")
from matplotlib import pyplot
print("Observations: ",len(VIB['Close']))
print(pd.DataFrame(VIB.head(6)))
train_dates = VIB.index
plt.figure(figsize=(12, 5))
VIB["Close"].plot()
# Out:
# Observations:  1634
#             Open  High   Low  Close  Volume Ticker
# Time
# 2017-06-02  3410  3440  3290   3320    2580    VIB
# 2017-06-05  3320  3410  3290   3290   39900    VIB
# 2017-06-06  3310  3320  3290   3320   53340    VIB
# 2017-06-07  3420  3420  3310   3340   69855    VIB
# 2017-06-08  3310  3310  3290   3310   50310    VIB
# 2017-06-09  3290  3310  3290   3290   43100    VIB
# <Axes: xlabel='Time'>

# %%
VIB = VIB.reset_index(drop = True)
df = VIB['Close']
df
# Out:
# 0        3320
# 1        3290
# 2        3320
# 3        3340
# 4        3310
#         ...
# 1629    19200
# 1630    19200
# 1631    19050
# 1632    18900
# 1633    18800
# Name: Close, Length: 1634, dtype: int64

# %%
## (A) CEEMDAN
#### 1. Thêm white noise vào chuỗi gốc s(t) thành chuỗi s1(t)
#### 2. Decompose chuỗi s1(t) bằng EMD ra các chuỗi IMF1 và Residue1
#### 3. Trung bình các chuỗi IMF1(t) thành mIMF1(t)
#### 4. r1(t) = s1(t) - mIMF1(t)
#### 5. Chuỗi mới s2(t) = r1(t) + coef*EMD(noise)
#### 6. Làm lại từ 1->5 đến khi chuỗi residue dừng

# %%
from PyEMD import EMD, CEEMDAN

# %%
ceemdan = CEEMDAN(range_thr=0.001, total_power_thr=0.01)
cIMFs = ceemdan.ceemdan(S=np.array(df.values), T= np.array(df.index))

# %%
pd.DataFrame(cIMFs.T, columns = ["IMF"+str(i+1) for i in range(cIMFs.shape[0])])
# Out:
#            IMF1        IMF2        IMF3        IMF4        IMF5         IMF6  \
# 0      7.847065   -1.126708   21.089443  -45.350323   32.738824   147.051417
# 1    -20.063613   -4.622290   25.676844  -48.883028   33.874758   147.330068
# 2      7.279301   -2.303176   28.262256  -51.684376   35.197410   147.379220
# 3     15.738495   11.287671   27.338684  -53.579014   36.721862   147.194039
# 4     -7.288164    9.792259   21.592833  -54.299619   38.457228   146.769922
# ...         ...         ...         ...         ...         ...          ...
# 1629 -56.177388  154.913286  309.417331 -250.105349 -811.842898  2783.208519
# 1630  43.044346   98.205168  273.846549 -267.328627 -794.568395  2778.648933
# 1631   7.222069   40.485094  217.945736 -275.966370 -779.319347  2773.795822
# 1632 -22.202343  -18.131661  150.755865 -276.500453 -766.212324  2768.649961
# 1633 -51.095583  -29.770234   80.866888 -269.578381 -755.198266  2763.212125
#
#              IMF7          IMF8
# 0    -1182.156058   4339.906339
# 1    -1182.297302   4338.984563
# 2    -1182.199500   4338.068865
# 3    -1181.860944   4337.159206
# 4    -1181.280019   4336.255559
# ...           ...           ...
# 1629 -4202.185234  21272.771733
# 1630 -4197.995971  21266.147997
# 1631 -4193.621103  21259.458098
# 1632 -4189.061077  21252.702033
# 1633 -4184.316346  21245.879797
#
# [1634 rows x 8 columns]

# %%
N = cIMFs.shape[0]+1
# Plot results
plt.subplot(N,1,1)
plt.plot(df.index, df.values, 'r')
plt.title("Input signal")
plt.xlabel("Time")

for n, imf in enumerate(cIMFs):
  plt.subplot(N,1,n+2)
  plt.plot(df.index, imf, 'g')
  plt.title("IMF "+str(n+1), x=1.2, y = 0)
  plt.xlabel("Time")
  plt.show()

# %%
# Tính residue
scIMF = cIMFs.sum(axis = 0).reshape(-1, 1)
residue = (np.array(df)-cIMFs.sum(axis = 0)).reshape(-1,1)

print("sIMF:", scIMF.shape)
print("Residue:", residue.shape)
# Out:
# sIMF: (1634, 1)
# Residue: (1634, 1)

# %%
plt.figure(figsize=(12,5))
plt.plot(range(0,len(df)), residue)
plt.plot(range(0,len(df)), scIMF)
plt.plot(range(0,len(df)), scIMF+residue)
plt.plot(df)
plt.legend(["Residual", "cIMF", "Ensembled series", "Original series"])

plt.show()

# %% [markdown]
# # (B) LSTM
# ## 0. Prepocessing

# %%
# load các thư viện cần thiết
import math
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import seaborn as sns
from sklearn.model_selection import KFold, cross_val_predict, train_test_split,GridSearchCV,cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder,StandardScaler,PowerTransformer, MinMaxScaler, RobustScaler

# %%
# Scale data to 0-1
scaler = StandardScaler()
def Scaling (data):
    IMFscale = scaler.fit_transform(np.array(data))

    return IMFscale
IMFscale = Scaling(cIMFs)
#train_scaled = scaler.inverse_transform(train_scaled)
#pd.DataFrame(train_scaled, columns=["IMF"+str(i+1) for i in range(cIMFs.shape[0])])

# %%
IMFscale_t = IMFscale.T
IMFscale_t.shape
# Out:
# (1634, 8)

# %%
print(IMFscale_t.shape)
# Chia train test
train_size = int(0.8*IMFscale_t.shape[0])
test_size = int(0.2*IMFscale_t.shape[0])
train_data = IMFscale_t[:train_size]
test_data = IMFscale_t[train_size:]

print("Train: ", train_data.shape)
print("Test: ", test_data.shape)

# Plotting both training and test data on the same chart
plt.figure(figsize=(12,5))

plt.plot(range(train_size), train_data, linestyle='-', color='b')
plt.plot(range(train_size -1,  train_size+test_size), test_data, linestyle='-',  color='r')

plt.title('VIB - Stock Close Over Time')
plt.xlabel('Time')
plt.ylabel('Close')
plt.show()
# Out:
# (1634, 8)
# Train:  (1307, 8)
# Test:  (327, 8)

# %%
train_data[:,0].shape
# Out:
# (1307,)

# %%
# IMFscale_t
trainX = []
trainY = []

n_past = 60
n_future = 1

for i in range(n_past, len(train_data) - n_future + 1):
    past_sequence = train_data[i - n_past:i, :]  # Exclude the first column ("Close") for trainX
    future_sequence = train_data[i + n_future - 1: i + n_future, :]  # Use the "Close" column for trainY

    trainX.append(past_sequence)
    trainY.append(future_sequence)

trainX, trainY = np.array(trainX), np.array(trainY)
trainY = trainY.reshape(trainY.shape[0], trainY.shape[2])

print("X train: ", trainX.shape)
print("Y train: ", trainY.shape)
# Out:
# X train:  (1247, 60, 8)
# Y train:  (1247, 8)

# %%
testX = []
testY = []

for i in range(n_past, len(test_data) - n_future + 1):
    past_sequence = test_data[i - n_past:i, :]  # Exclude the first column ("Close") for trainX
    future_sequence = test_data[i + n_future - 1: i + n_future, :]  # Use the "Close" column for trainY

    testX.append(past_sequence)
    testY.append(future_sequence)

testX, testY = np.array(testX), np.array(testY)
testY = testY.reshape(testY.shape[0], testY.shape[2])

print("X test: ", testX.shape)
print("Y test: ", testY.shape)
# Out:
# X test:  (267, 60, 8)
# Y test:  (267, 8)

# %%
# Plotting both training and test data on the same chart
plt.figure(figsize=(12,5))

plt.plot(range(train_size), train_data, linestyle='-', color='b', label='Training Data')
plt.plot(range(train_size-n_past), trainX[:,0,0], linestyle='-', label='Training Data X')
plt.plot(range(n_past,train_size), trainY[:,0], linestyle='-', label='Training Data Y')
plt.plot(range(train_size, train_size+test_size+1), test_data, linestyle='-',  color='r', label='Test Data')
plt.plot(range(train_size, train_size+test_size-n_past+1), testX[:,0,0], linestyle='-',  label='Test Data X')
plt.plot(range(train_size+n_past, train_size+test_size+1), testY[:,0], linestyle='-', label='Test Data Y')


plt.title('VIB - Stock Close Over Time')
plt.xlabel('Time')
plt.ylabel('Close')

plt.show()

# %%
trainY[:].shape
trainX[:,:,i].reshape(trainX.shape[0], trainX.shape[1], 1)
# Out:
# (1247, 60, 1)

# %%
## 1. Train model
# Tạo model lstm cho việc training
model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], 1), return_sequences=True))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mape')
model.summary()

def createModel():
  model = Sequential()
  model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], 1), return_sequences=True))
  model.add(LSTM(32, activation='relu', return_sequences=False))
  model.add(Dropout(0.2))
  model.add(Dense(1))
  model.compile(optimizer='adam', loss='mape')
  model.summary()
  return model

# %%
# fit the model
history = []
models = []
for i in range(8):
  mod = createModel()
  his = mod.fit(trainX[:,:,i].reshape(trainX.shape[0], trainX.shape[1], 1),
                  trainY[:,i],
                  epochs=80, batch_size=24, validation_split=0.2, verbose = 1)
  history.append(his)
  models.append(mod)
#history = model.fit(trainX, trainY, epochs=100, batch_size=10, validation_split=0.1, verbose=1)
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_28 (LSTM)              (None, 60, 64)            16896
#
#  lstm_29 (LSTM)              (None, 32)                12416
#
#  dropout_14 (Dropout)        (None, 32)                0
#
#  dense_14 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 29345 (114.63 KB)
# Trainable params: 29345 (114.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 57/57 [==============================] - 11s 85ms/step - loss: 40.2364 - val_loss: 14.0734
# Epoch 2/50
# 57/57 [==============================] - 3s 45ms/step - loss: 18.2086 - val_loss: 11.7370
# Epoch 3/50
# 57/57 [==============================] - 3s 54ms/step - loss: 17.0017 - val_loss: 13.8781
# Epoch 4/50
# 57/57 [==============================] - 3s 55ms/step - loss: 15.4276 - val_loss: 11.4749
# Epoch 5/50
# 57/57 [==============================] - 2s 43ms/step - loss: 15.1606 - val_loss: 11.6635
# Epoch 6/50
# 57/57 [==============================] - 2s 43ms/step - loss: 13.4022 - val_loss: 10.9226
# Epoch 7/50
# 57/57 [==============================] - 2s 42ms/step - loss: 13.0671 - val_loss: 11.3094
# Epoch 8/50
# 57/57 [==============================] - 3s 58ms/step - loss: 12.4098 - val_loss: 10.6642
# Epoch 9/50
# 57/57 [==============================] - 3s 54ms/step - loss: 12.3383 - val_loss: 10.6003
# Epoch 10/50
# 57/57 [==============================] - 3s 60ms/step - loss: 11.4570 - val_loss: 10.4734
# Epoch 11/50
# 57/57 [==============================] - 3s 57ms/step - loss: 11.2189 - val_loss: 10.3393
# Epoch 12/50
# 57/57 [==============================] - 3s 52ms/step - loss: 10.6336 - val_loss: 10.4950
# Epoch 13/50
# 57/57 [==============================] - 5s 82ms/step - loss: 10.5833 - val_loss: 13.4175
# Epoch 14/50
# 57/57 [==============================] - 3s 47ms/step - loss: 10.2897 - val_loss: 10.5002
# Epoch 15/50
# 57/57 [==============================] - 4s 70ms/step - loss: 10.3072 - val_loss: 11.4923
# Epoch 16/50
# 57/57 [==============================] - 5s 92ms/step - loss: 9.8028 - val_loss: 11.2747
# Epoch 17/50
# 57/57 [==============================] - 3s 52ms/step - loss: 10.0513 - val_loss: 10.3171
# Epoch 18/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.4463 - val_loss: 10.2128
# Epoch 19/50
# 57/57 [==============================] - 3s 46ms/step - loss: 9.4020 - val_loss: 10.1362
# Epoch 20/50
# 57/57 [==============================] - 5s 92ms/step - loss: 9.4052 - val_loss: 10.2587
# Epoch 21/50
# 57/57 [==============================] - 5s 89ms/step - loss: 9.6480 - val_loss: 10.0522
# Epoch 22/50
# 57/57 [==============================] - 5s 85ms/step - loss: 9.1472 - val_loss: 10.8041
# Epoch 23/50
# 57/57 [==============================] - 5s 91ms/step - loss: 9.6667 - val_loss: 10.2804
# Epoch 24/50
# 57/57 [==============================] - 5s 84ms/step - loss: 9.5743 - val_loss: 10.0285
# Epoch 25/50
# 57/57 [==============================] - 3s 49ms/step - loss: 9.6834 - val_loss: 10.4072
# Epoch 26/50
# 57/57 [==============================] - 6s 100ms/step - loss: 9.5649 - val_loss: 10.8275
# Epoch 27/50
# 57/57 [==============================] - 5s 85ms/step - loss: 9.3326 - val_loss: 10.4862
# Epoch 28/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.2627 - val_loss: 10.0680
# Epoch 29/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.2448 - val_loss: 10.0492
# Epoch 30/50
# 57/57 [==============================] - 4s 63ms/step - loss: 9.3703 - val_loss: 10.4048
# Epoch 31/50
# 57/57 [==============================] - 3s 49ms/step - loss: 8.9718 - val_loss: 10.1292
# Epoch 32/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.2730 - val_loss: 11.0848
# Epoch 33/50
# 57/57 [==============================] - 3s 44ms/step - loss: 9.1178 - val_loss: 10.0264
# Epoch 34/50
# 57/57 [==============================] - 2s 43ms/step - loss: 8.9395 - val_loss: 10.4737
# Epoch 35/50
# 57/57 [==============================] - 4s 65ms/step - loss: 8.9554 - val_loss: 10.1213
# Epoch 36/50
# 57/57 [==============================] - 3s 46ms/step - loss: 8.9945 - val_loss: 9.9148
# Epoch 37/50
# 57/57 [==============================] - 2s 42ms/step - loss: 8.8891 - val_loss: 9.8432
# Epoch 38/50
# 57/57 [==============================] - 3s 44ms/step - loss: 9.0174 - val_loss: 10.0108
# Epoch 39/50
# 57/57 [==============================] - 2s 43ms/step - loss: 8.6447 - val_loss: 10.3418
# Epoch 40/50
# 57/57 [==============================] - 4s 68ms/step - loss: 8.9503 - val_loss: 10.0820
# Epoch 41/50
# 57/57 [==============================] - 3s 44ms/step - loss: 9.1854 - val_loss: 9.8180
# Epoch 42/50
# 57/57 [==============================] - 2s 43ms/step - loss: 8.7332 - val_loss: 9.7490
# Epoch 43/50
# 57/57 [==============================] - 2s 43ms/step - loss: 8.3622 - val_loss: 9.9450
# Epoch 44/50
# 57/57 [==============================] - 2s 43ms/step - loss: 8.4734 - val_loss: 10.1974
# Epoch 45/50
# 57/57 [==============================] - 4s 70ms/step - loss: 8.3304 - val_loss: 9.9175
# Epoch 46/50
# 57/57 [==============================] - 2s 42ms/step - loss: 8.7429 - val_loss: 10.0084
# Epoch 47/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.0550 - val_loss: 9.6832
# Epoch 48/50
# 57/57 [==============================] - 3s 44ms/step - loss: 8.7603 - val_loss: 9.6679
# Epoch 49/50
# 57/57 [==============================] - 2s 43ms/step - loss: 8.5730 - val_loss: 9.6171
# Epoch 50/50
# 57/57 [==============================] - 4s 70ms/step - loss: 8.4978 - val_loss: 9.6275
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_30 (LSTM)              (None, 60, 64)            16896
#
#  lstm_31 (LSTM)              (None, 32)                12416
#
#  dropout_15 (Dropout)        (None, 32)                0
#
#  dense_15 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 29345 (114.63 KB)
# Trainable params: 29345 (114.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 57/57 [==============================] - 26s 54ms/step - loss: 27.5718 - val_loss: 10.2121
# Epoch 2/50
# 57/57 [==============================] - 2s 43ms/step - loss: 16.8409 - val_loss: 11.6835
# Epoch 3/50
# 57/57 [==============================] - 2s 43ms/step - loss: 16.0696 - val_loss: 11.2244
# Epoch 4/50
# 57/57 [==============================] - 3s 55ms/step - loss: 15.1642 - val_loss: 10.7645
# Epoch 5/50
# 57/57 [==============================] - 3s 59ms/step - loss: 14.4196 - val_loss: 10.2997
# Epoch 6/50
# 57/57 [==============================] - 3s 44ms/step - loss: 13.4936 - val_loss: 10.0538
# Epoch 7/50
# 57/57 [==============================] - 3s 45ms/step - loss: 12.3961 - val_loss: 10.1145
# Epoch 8/50
# 57/57 [==============================] - 2s 42ms/step - loss: 12.5346 - val_loss: 10.0726
# Epoch 9/50
# 57/57 [==============================] - 3s 59ms/step - loss: 11.4970 - val_loss: 9.9199
# Epoch 10/50
# 57/57 [==============================] - 3s 53ms/step - loss: 11.5617 - val_loss: 10.0128
# Epoch 11/50
# 57/57 [==============================] - 2s 44ms/step - loss: 10.9866 - val_loss: 10.0887
# Epoch 12/50
# 57/57 [==============================] - 3s 44ms/step - loss: 10.7186 - val_loss: 10.3412
# Epoch 13/50
# 57/57 [==============================] - 2s 43ms/step - loss: 10.5169 - val_loss: 9.7932
# Epoch 14/50
# 57/57 [==============================] - 4s 66ms/step - loss: 10.0560 - val_loss: 10.4899
# Epoch 15/50
# 57/57 [==============================] - 3s 47ms/step - loss: 10.5070 - val_loss: 9.9903
# Epoch 16/50
# 57/57 [==============================] - 2s 43ms/step - loss: 10.5419 - val_loss: 9.9556
# Epoch 17/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.6954 - val_loss: 9.9403
# Epoch 18/50
# 57/57 [==============================] - 2s 43ms/step - loss: 10.0598 - val_loss: 9.7746
# Epoch 19/50
# 57/57 [==============================] - 4s 68ms/step - loss: 9.9033 - val_loss: 9.8245
# Epoch 20/50
# 57/57 [==============================] - 2s 43ms/step - loss: 10.8026 - val_loss: 10.2647
# Epoch 21/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.9541 - val_loss: 9.9544
# Epoch 22/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.5033 - val_loss: 9.8004
# Epoch 23/50
# 57/57 [==============================] - 2s 44ms/step - loss: 9.6608 - val_loss: 9.7882
# Epoch 24/50
# 57/57 [==============================] - 4s 70ms/step - loss: 9.7938 - val_loss: 9.6602
# Epoch 25/50
# 57/57 [==============================] - 2s 44ms/step - loss: 9.4621 - val_loss: 9.7341
# Epoch 26/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.5717 - val_loss: 9.5778
# Epoch 27/50
# 57/57 [==============================] - 2s 43ms/step - loss: 10.1640 - val_loss: 10.9861
# Epoch 28/50
# 57/57 [==============================] - 3s 44ms/step - loss: 10.4840 - val_loss: 9.6934
# Epoch 29/50
# 57/57 [==============================] - 4s 68ms/step - loss: 9.4656 - val_loss: 9.8915
# Epoch 30/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.8658 - val_loss: 9.6576
# Epoch 31/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.7395 - val_loss: 12.8412
# Epoch 32/50
# 57/57 [==============================] - 2s 42ms/step - loss: 10.6093 - val_loss: 9.8204
# Epoch 33/50
# 57/57 [==============================] - 3s 48ms/step - loss: 9.6711 - val_loss: 9.6511
# Epoch 34/50
# 57/57 [==============================] - 4s 64ms/step - loss: 9.9607 - val_loss: 9.5814
# Epoch 35/50
# 57/57 [==============================] - 2s 42ms/step - loss: 9.5888 - val_loss: 9.8503
# Epoch 36/50
# 57/57 [==============================] - 3s 44ms/step - loss: 9.9116 - val_loss: 9.5910
# Epoch 37/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.2785 - val_loss: 9.5500
# Epoch 38/50
# 57/57 [==============================] - 3s 52ms/step - loss: 9.4417 - val_loss: 9.6178
# Epoch 39/50
# 57/57 [==============================] - 4s 61ms/step - loss: 9.5306 - val_loss: 11.3831
# Epoch 40/50
# 57/57 [==============================] - 3s 45ms/step - loss: 10.2500 - val_loss: 9.8928
# Epoch 41/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.6351 - val_loss: 9.7833
# Epoch 42/50
# 57/57 [==============================] - 2s 44ms/step - loss: 9.4159 - val_loss: 9.4763
# Epoch 43/50
# 57/57 [==============================] - 3s 56ms/step - loss: 9.3839 - val_loss: 9.8717
# Epoch 44/50
# 57/57 [==============================] - 3s 57ms/step - loss: 9.4240 - val_loss: 9.5558
# Epoch 45/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.5928 - val_loss: 9.9087
# Epoch 46/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.2359 - val_loss: 10.2726
# Epoch 47/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.9491 - val_loss: 9.5592
# Epoch 48/50
# 57/57 [==============================] - 3s 60ms/step - loss: 9.2789 - val_loss: 9.8284
# Epoch 49/50
# 57/57 [==============================] - 3s 52ms/step - loss: 9.1162 - val_loss: 9.6884
# Epoch 50/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.6882 - val_loss: 9.4310
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_32 (LSTM)              (None, 60, 64)            16896
#
#  lstm_33 (LSTM)              (None, 32)                12416
#
#  dropout_16 (Dropout)        (None, 32)                0
#
#  dense_16 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 29345 (114.63 KB)
# Trainable params: 29345 (114.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 57/57 [==============================] - 7s 79ms/step - loss: 28.4803 - val_loss: 25.9619
# Epoch 2/50
# 57/57 [==============================] - 2s 43ms/step - loss: 18.0517 - val_loss: 25.8040
# Epoch 3/50
# 57/57 [==============================] - 3s 44ms/step - loss: 18.4597 - val_loss: 25.9417
# Epoch 4/50
# 57/57 [==============================] - 2s 43ms/step - loss: 16.9454 - val_loss: 25.6817
# Epoch 5/50
# 57/57 [==============================] - 3s 51ms/step - loss: 16.2218 - val_loss: 26.5125
# Epoch 6/50
# 57/57 [==============================] - 4s 63ms/step - loss: 15.9051 - val_loss: 24.8010
# Epoch 7/50
# 57/57 [==============================] - 2s 43ms/step - loss: 15.1202 - val_loss: 24.4365
# Epoch 8/50
# 57/57 [==============================] - 2s 43ms/step - loss: 14.6563 - val_loss: 23.9888
# Epoch 9/50
# 57/57 [==============================] - 2s 43ms/step - loss: 14.5475 - val_loss: 23.6192
# Epoch 10/50
# 57/57 [==============================] - 3s 53ms/step - loss: 14.2766 - val_loss: 23.2313
# Epoch 11/50
# 57/57 [==============================] - 3s 59ms/step - loss: 13.3843 - val_loss: 22.7011
# Epoch 12/50
# 57/57 [==============================] - 2s 43ms/step - loss: 13.3640 - val_loss: 22.7132
# Epoch 13/50
# 57/57 [==============================] - 3s 45ms/step - loss: 12.9363 - val_loss: 21.0497
# Epoch 14/50
# 57/57 [==============================] - 2s 43ms/step - loss: 12.5288 - val_loss: 20.3532
# Epoch 15/50
# 57/57 [==============================] - 3s 60ms/step - loss: 12.2846 - val_loss: 19.2391
# Epoch 16/50
# 57/57 [==============================] - 3s 55ms/step - loss: 11.2099 - val_loss: 17.6118
# Epoch 17/50
# 57/57 [==============================] - 3s 45ms/step - loss: 10.8587 - val_loss: 16.0983
# Epoch 18/50
# 57/57 [==============================] - 2s 44ms/step - loss: 10.2623 - val_loss: 14.9578
# Epoch 19/50
# 57/57 [==============================] - 3s 44ms/step - loss: 10.2794 - val_loss: 14.6139
# Epoch 20/50
# 57/57 [==============================] - 4s 64ms/step - loss: 9.7063 - val_loss: 14.6403
# Epoch 21/50
# 57/57 [==============================] - 3s 49ms/step - loss: 9.2673 - val_loss: 13.3392
# Epoch 22/50
# 57/57 [==============================] - 3s 45ms/step - loss: 9.4143 - val_loss: 13.6219
# Epoch 23/50
# 57/57 [==============================] - 3s 44ms/step - loss: 8.5172 - val_loss: 12.8764
# Epoch 24/50
# 57/57 [==============================] - 2s 43ms/step - loss: 8.6598 - val_loss: 12.5903
# Epoch 25/50
# 57/57 [==============================] - 4s 69ms/step - loss: 8.3767 - val_loss: 13.1922
# Epoch 26/50
# 57/57 [==============================] - 3s 46ms/step - loss: 8.4833 - val_loss: 12.6475
# Epoch 27/50
# 57/57 [==============================] - 2s 43ms/step - loss: 8.0858 - val_loss: 11.7753
# Epoch 28/50
# 57/57 [==============================] - 2s 44ms/step - loss: 8.4419 - val_loss: 11.4742
# Epoch 29/50
# 57/57 [==============================] - 2s 43ms/step - loss: 7.6724 - val_loss: 11.0254
# Epoch 30/50
# 57/57 [==============================] - 4s 72ms/step - loss: 8.0923 - val_loss: 11.0455
# Epoch 31/50
# 57/57 [==============================] - 2s 44ms/step - loss: 7.5804 - val_loss: 12.2934
# Epoch 32/50
# 57/57 [==============================] - 2s 44ms/step - loss: 7.7586 - val_loss: 10.4763
# Epoch 33/50
# 57/57 [==============================] - 2s 43ms/step - loss: 7.6398 - val_loss: 11.4484
# Epoch 34/50
# 57/57 [==============================] - 3s 46ms/step - loss: 7.9932 - val_loss: 10.3605
# Epoch 35/50
# 57/57 [==============================] - 4s 68ms/step - loss: 7.5904 - val_loss: 12.1663
# Epoch 36/50
# 57/57 [==============================] - 2s 43ms/step - loss: 7.6019 - val_loss: 10.0930
# Epoch 37/50
# 57/57 [==============================] - 3s 45ms/step - loss: 7.4089 - val_loss: 9.9329
# Epoch 38/50
# 57/57 [==============================] - 2s 43ms/step - loss: 7.3723 - val_loss: 11.4437
# Epoch 39/50
# 57/57 [==============================] - 3s 52ms/step - loss: 7.5536 - val_loss: 10.2629
# Epoch 40/50
# 57/57 [==============================] - 4s 63ms/step - loss: 7.3803 - val_loss: 9.5030
# Epoch 41/50
# 57/57 [==============================] - 3s 45ms/step - loss: 7.1022 - val_loss: 9.6001
# Epoch 42/50
# 57/57 [==============================] - 2s 43ms/step - loss: 7.1827 - val_loss: 9.0224
# Epoch 43/50
# 57/57 [==============================] - 3s 45ms/step - loss: 7.3050 - val_loss: 9.5221
# Epoch 44/50
# 57/57 [==============================] - 3s 58ms/step - loss: 7.2212 - val_loss: 8.9887
# Epoch 45/50
# 57/57 [==============================] - 3s 55ms/step - loss: 7.1087 - val_loss: 9.7834
# Epoch 46/50
# 57/57 [==============================] - 2s 43ms/step - loss: 7.4214 - val_loss: 9.3592
# Epoch 47/50
# 57/57 [==============================] - 2s 44ms/step - loss: 7.2906 - val_loss: 8.6715
# Epoch 48/50
# 57/57 [==============================] - 2s 43ms/step - loss: 7.1426 - val_loss: 10.8437
# Epoch 49/50
# 57/57 [==============================] - 4s 63ms/step - loss: 7.0213 - val_loss: 8.8283
# Epoch 50/50
# 57/57 [==============================] - 3s 50ms/step - loss: 6.9850 - val_loss: 9.5950
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_34 (LSTM)              (None, 60, 64)            16896
#
#  lstm_35 (LSTM)              (None, 32)                12416
#
#  dropout_17 (Dropout)        (None, 32)                0
#
#  dense_17 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 29345 (114.63 KB)
# Trainable params: 29345 (114.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 57/57 [==============================] - 6s 52ms/step - loss: 42.0505 - val_loss: 1897.0231
# Epoch 2/50
# 57/57 [==============================] - 3s 52ms/step - loss: 24.6189 - val_loss: 1779.2035
# Epoch 3/50
# 57/57 [==============================] - 4s 62ms/step - loss: 21.6207 - val_loss: 1673.8214
# Epoch 4/50
# 57/57 [==============================] - 3s 45ms/step - loss: 20.1171 - val_loss: 1724.5217
# Epoch 5/50
# 57/57 [==============================] - 3s 45ms/step - loss: 19.3543 - val_loss: 1250.5527
# Epoch 6/50
# 57/57 [==============================] - 3s 45ms/step - loss: 18.3507 - val_loss: 1295.5077
# Epoch 7/50
# 57/57 [==============================] - 4s 62ms/step - loss: 15.7380 - val_loss: 1261.0724
# Epoch 8/50
# 57/57 [==============================] - 3s 55ms/step - loss: 13.5984 - val_loss: 1273.2753
# Epoch 9/50
# 57/57 [==============================] - 3s 46ms/step - loss: 12.3280 - val_loss: 1234.7616
# Epoch 10/50
# 57/57 [==============================] - 3s 45ms/step - loss: 11.7407 - val_loss: 1147.4215
# Epoch 11/50
# 57/57 [==============================] - 3s 45ms/step - loss: 11.6864 - val_loss: 1249.9744
# Epoch 12/50
# 57/57 [==============================] - 4s 71ms/step - loss: 10.7050 - val_loss: 1273.3124
# Epoch 13/50
# 57/57 [==============================] - 3s 44ms/step - loss: 10.5099 - val_loss: 1269.9880
# Epoch 14/50
# 57/57 [==============================] - 2s 43ms/step - loss: 10.2149 - val_loss: 1346.8198
# Epoch 15/50
# 57/57 [==============================] - 2s 43ms/step - loss: 9.6033 - val_loss: 1364.8613
# Epoch 16/50
# 57/57 [==============================] - 2s 44ms/step - loss: 9.2179 - val_loss: 1373.9309
# Epoch 17/50
# 57/57 [==============================] - 4s 72ms/step - loss: 9.6198 - val_loss: 1387.9772
# Epoch 18/50
# 57/57 [==============================] - 3s 44ms/step - loss: 10.2093 - val_loss: 1429.5771
# Epoch 19/50
# 57/57 [==============================] - 3s 45ms/step - loss: 8.8469 - val_loss: 1411.4221
# Epoch 20/50
# 57/57 [==============================] - 2s 44ms/step - loss: 8.8778 - val_loss: 1430.9752
# Epoch 21/50
# 57/57 [==============================] - 3s 49ms/step - loss: 8.4392 - val_loss: 1398.7058
# Epoch 22/50
# 57/57 [==============================] - 4s 67ms/step - loss: 8.6289 - val_loss: 1424.1075
# Epoch 23/50
# 57/57 [==============================] - 3s 44ms/step - loss: 8.6264 - val_loss: 1441.8196
# Epoch 24/50
# 57/57 [==============================] - 2s 44ms/step - loss: 8.6441 - val_loss: 1413.5238
# Epoch 25/50
# 57/57 [==============================] - 3s 45ms/step - loss: 8.6875 - val_loss: 1461.1115
# Epoch 26/50
# 57/57 [==============================] - 3s 57ms/step - loss: 8.5705 - val_loss: 1435.4128
# Epoch 27/50
# 57/57 [==============================] - 3s 59ms/step - loss: 8.3022 - val_loss: 1445.0618
# Epoch 28/50
# 57/57 [==============================] - 3s 44ms/step - loss: 8.1401 - val_loss: 1436.2753
# Epoch 29/50
# 57/57 [==============================] - 3s 45ms/step - loss: 8.2197 - val_loss: 1438.0480
# Epoch 30/50
# 57/57 [==============================] - 3s 46ms/step - loss: 7.9578 - val_loss: 1426.4904
# Epoch 31/50
# 57/57 [==============================] - 4s 67ms/step - loss: 8.3144 - val_loss: 1404.2761
# Epoch 32/50
# 57/57 [==============================] - 3s 50ms/step - loss: 8.0792 - val_loss: 1409.9410
# Epoch 33/50
# 57/57 [==============================] - 3s 45ms/step - loss: 7.9931 - val_loss: 1418.9648
# Epoch 34/50
# 57/57 [==============================] - 3s 46ms/step - loss: 7.9789 - val_loss: 1410.4932
# Epoch 35/50
# 57/57 [==============================] - 3s 45ms/step - loss: 8.1297 - val_loss: 1426.9084
# Epoch 36/50
# 57/57 [==============================] - 4s 72ms/step - loss: 8.1536 - val_loss: 1421.9692
# Epoch 37/50
# 57/57 [==============================] - 3s 44ms/step - loss: 7.5561 - val_loss: 1420.4598
# Epoch 38/50
# 57/57 [==============================] - 2s 44ms/step - loss: 7.8391 - val_loss: 1414.9059
# Epoch 39/50
# 57/57 [==============================] - 3s 45ms/step - loss: 7.9219 - val_loss: 1430.9275
# Epoch 40/50
# 57/57 [==============================] - 3s 47ms/step - loss: 8.2130 - val_loss: 1436.6420
# Epoch 41/50
# 57/57 [==============================] - 4s 67ms/step - loss: 8.0764 - val_loss: 1458.9473
# Epoch 42/50
# 57/57 [==============================] - 3s 45ms/step - loss: 8.2656 - val_loss: 1439.9996
# Epoch 43/50
# 57/57 [==============================] - 2s 44ms/step - loss: 7.9244 - val_loss: 1424.1255
# Epoch 44/50
# 57/57 [==============================] - 2s 44ms/step - loss: 7.6417 - val_loss: 1424.9900
# Epoch 45/50
# 57/57 [==============================] - 3s 53ms/step - loss: 7.6651 - val_loss: 1418.8308
# Epoch 46/50
# 57/57 [==============================] - 4s 62ms/step - loss: 7.8326 - val_loss: 1414.8398
# Epoch 47/50
# 57/57 [==============================] - 3s 45ms/step - loss: 8.0006 - val_loss: 1428.8352
# Epoch 48/50
# 57/57 [==============================] - 3s 44ms/step - loss: 7.6075 - val_loss: 1410.8391
# Epoch 49/50
# 57/57 [==============================] - 3s 44ms/step - loss: 7.7455 - val_loss: 1421.5720
# Epoch 50/50
# 57/57 [==============================] - 3s 60ms/step - loss: 7.7831 - val_loss: 1423.3741
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_36 (LSTM)              (None, 60, 64)            16896
#
#  lstm_37 (LSTM)              (None, 32)                12416
#
#  dropout_18 (Dropout)        (None, 32)                0
#
#  dense_18 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 29345 (114.63 KB)
# Trainable params: 29345 (114.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 57/57 [==============================] - 7s 52ms/step - loss: 57.1898 - val_loss: 38.6387
# Epoch 2/50
# 57/57 [==============================] - 3s 45ms/step - loss: 32.4902 - val_loss: 24.9793
# Epoch 3/50
# 57/57 [==============================] - 2s 44ms/step - loss: 32.9802 - val_loss: 17.1086
# Epoch 4/50
# 57/57 [==============================] - 3s 54ms/step - loss: 28.0720 - val_loss: 21.6433
# Epoch 5/50
# 57/57 [==============================] - 3s 60ms/step - loss: 26.5525 - val_loss: 28.2875
# Epoch 6/50
# 57/57 [==============================] - 2s 44ms/step - loss: 22.2202 - val_loss: 34.5813
# Epoch 7/50
# 57/57 [==============================] - 2s 44ms/step - loss: 23.6738 - val_loss: 28.2555
# Epoch 8/50
# 57/57 [==============================] - 2s 43ms/step - loss: 26.0312 - val_loss: 23.2479
# Epoch 9/50
# 57/57 [==============================] - 3s 61ms/step - loss: 25.1197 - val_loss: 61.0190
# Epoch 10/50
# 57/57 [==============================] - 3s 55ms/step - loss: 22.4584 - val_loss: 24.0632
# Epoch 11/50
# 57/57 [==============================] - 3s 45ms/step - loss: 19.3716 - val_loss: 28.7138
# Epoch 12/50
# 57/57 [==============================] - 3s 45ms/step - loss: 20.8561 - val_loss: 18.0191
# Epoch 13/50
# 57/57 [==============================] - 3s 46ms/step - loss: 23.3526 - val_loss: 25.7147
# Epoch 14/50
# 57/57 [==============================] - 4s 69ms/step - loss: 21.1495 - val_loss: 26.2618
# Epoch 15/50
# 57/57 [==============================] - 3s 46ms/step - loss: 20.3568 - val_loss: 34.4282
# Epoch 16/50
# 57/57 [==============================] - 3s 44ms/step - loss: 19.6863 - val_loss: 53.8183
# Epoch 17/50
# 57/57 [==============================] - 3s 45ms/step - loss: 19.2308 - val_loss: 16.1371
# Epoch 18/50
# 57/57 [==============================] - 2s 43ms/step - loss: 19.9604 - val_loss: 58.8944
# Epoch 19/50
# 57/57 [==============================] - 4s 72ms/step - loss: 20.7450 - val_loss: 49.0429
# Epoch 20/50
# 57/57 [==============================] - 2s 44ms/step - loss: 20.4185 - val_loss: 29.4858
# Epoch 21/50
# 57/57 [==============================] - 3s 44ms/step - loss: 17.8161 - val_loss: 34.0411
# Epoch 22/50
# 57/57 [==============================] - 2s 43ms/step - loss: 18.0841 - val_loss: 59.1491
# Epoch 23/50
# 57/57 [==============================] - 3s 47ms/step - loss: 18.8509 - val_loss: 39.8426
# Epoch 24/50
# 57/57 [==============================] - 4s 67ms/step - loss: 22.4173 - val_loss: 22.8633
# Epoch 25/50
# 57/57 [==============================] - 3s 44ms/step - loss: 18.9342 - val_loss: 20.3971
# Epoch 26/50
# 57/57 [==============================] - 3s 44ms/step - loss: 18.6221 - val_loss: 57.8489
# Epoch 27/50
# 57/57 [==============================] - 3s 44ms/step - loss: 21.7887 - val_loss: 17.1307
# Epoch 28/50
# 57/57 [==============================] - 3s 52ms/step - loss: 19.6235 - val_loss: 31.1037
# Epoch 29/50
# 57/57 [==============================] - 4s 63ms/step - loss: 24.8609 - val_loss: 32.9398
# Epoch 30/50
# 57/57 [==============================] - 3s 44ms/step - loss: 18.8225 - val_loss: 23.8280
# Epoch 31/50
# 57/57 [==============================] - 2s 43ms/step - loss: 18.2478 - val_loss: 29.2717
# Epoch 32/50
# 57/57 [==============================] - 2s 43ms/step - loss: 18.0543 - val_loss: 27.9026
# Epoch 33/50
# 57/57 [==============================] - 3s 59ms/step - loss: 18.9039 - val_loss: 41.1459
# Epoch 34/50
# 57/57 [==============================] - 3s 58ms/step - loss: 18.2959 - val_loss: 17.8717
# Epoch 35/50
# 57/57 [==============================] - 2s 43ms/step - loss: 17.8067 - val_loss: 25.0404
# Epoch 36/50
# 57/57 [==============================] - 2s 43ms/step - loss: 16.3039 - val_loss: 25.4073
# Epoch 37/50
# 57/57 [==============================] - 2s 43ms/step - loss: 17.7308 - val_loss: 33.1545
# Epoch 38/50
# 57/57 [==============================] - 4s 64ms/step - loss: 22.3563 - val_loss: 45.8239
# Epoch 39/50
# 57/57 [==============================] - 3s 52ms/step - loss: 17.8425 - val_loss: 25.8153
# Epoch 40/50
# 57/57 [==============================] - 3s 44ms/step - loss: 17.7827 - val_loss: 31.0545
# Epoch 41/50
# 57/57 [==============================] - 3s 44ms/step - loss: 17.2212 - val_loss: 16.8967
# Epoch 42/50
# 57/57 [==============================] - 2s 44ms/step - loss: 16.7178 - val_loss: 18.3166
# Epoch 43/50
# 57/57 [==============================] - 4s 71ms/step - loss: 17.1620 - val_loss: 14.9252
# Epoch 44/50
# 57/57 [==============================] - 3s 44ms/step - loss: 16.3708 - val_loss: 27.9798
# Epoch 45/50
# 57/57 [==============================] - 3s 44ms/step - loss: 18.0059 - val_loss: 19.1198
# Epoch 46/50
# 57/57 [==============================] - 3s 50ms/step - loss: 17.1095 - val_loss: 20.5101
# Epoch 47/50
# 57/57 [==============================] - 3s 47ms/step - loss: 15.9119 - val_loss: 35.5702
# Epoch 48/50
# 57/57 [==============================] - 4s 69ms/step - loss: 17.4697 - val_loss: 22.0095
# Epoch 49/50
# 57/57 [==============================] - 3s 44ms/step - loss: 16.0820 - val_loss: 20.1739
# Epoch 50/50
# 57/57 [==============================] - 2s 43ms/step - loss: 18.6086 - val_loss: 32.8874
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_38 (LSTM)              (None, 60, 64)            16896
#
#  lstm_39 (LSTM)              (None, 32)                12416
#
#  dropout_19 (Dropout)        (None, 32)                0
#
#  dense_19 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 29345 (114.63 KB)
# Trainable params: 29345 (114.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 57/57 [==============================] - 7s 71ms/step - loss: 68.4384 - val_loss: 31.6572
# Epoch 2/50
# 57/57 [==============================] - 3s 51ms/step - loss: 41.4380 - val_loss: 24.6921
# Epoch 3/50
# 57/57 [==============================] - 3s 45ms/step - loss: 30.4937 - val_loss: 7.4225
# Epoch 4/50
# 57/57 [==============================] - 3s 45ms/step - loss: 36.0767 - val_loss: 5.9317
# Epoch 5/50
# 57/57 [==============================] - 3s 45ms/step - loss: 37.5139 - val_loss: 14.2369
# Epoch 6/50
# 57/57 [==============================] - 4s 72ms/step - loss: 32.5572 - val_loss: 22.5615
# Epoch 7/50
# 57/57 [==============================] - 3s 46ms/step - loss: 29.8908 - val_loss: 7.4372
# Epoch 8/50
# 57/57 [==============================] - 3s 45ms/step - loss: 28.2214 - val_loss: 6.9449
# Epoch 9/50
# 57/57 [==============================] - 3s 45ms/step - loss: 29.3018 - val_loss: 7.7882
# Epoch 10/50
# 57/57 [==============================] - 3s 50ms/step - loss: 27.2832 - val_loss: 5.5481
# Epoch 11/50
# 57/57 [==============================] - 4s 67ms/step - loss: 23.6448 - val_loss: 5.7207
# Epoch 12/50
# 57/57 [==============================] - 3s 46ms/step - loss: 25.4378 - val_loss: 4.3444
# Epoch 13/50
# 57/57 [==============================] - 3s 46ms/step - loss: 24.0135 - val_loss: 4.3369
# Epoch 14/50
# 57/57 [==============================] - 3s 45ms/step - loss: 23.9742 - val_loss: 12.4901
# Epoch 15/50
# 57/57 [==============================] - 3s 58ms/step - loss: 23.9596 - val_loss: 4.8453
# Epoch 16/50
# 57/57 [==============================] - 3s 59ms/step - loss: 24.8894 - val_loss: 5.2358
# Epoch 17/50
# 57/57 [==============================] - 3s 45ms/step - loss: 21.9723 - val_loss: 4.7891
# Epoch 18/50
# 57/57 [==============================] - 3s 46ms/step - loss: 24.5573 - val_loss: 6.6066
# Epoch 19/50
# 57/57 [==============================] - 3s 44ms/step - loss: 23.9016 - val_loss: 4.4591
# Epoch 20/50
# 57/57 [==============================] - 4s 67ms/step - loss: 26.9670 - val_loss: 4.7147
# Epoch 21/50
# 57/57 [==============================] - 3s 50ms/step - loss: 22.1785 - val_loss: 4.0963
# Epoch 22/50
# 57/57 [==============================] - 2s 44ms/step - loss: 19.8372 - val_loss: 7.2457
# Epoch 23/50
# 57/57 [==============================] - 3s 44ms/step - loss: 20.6981 - val_loss: 4.3073
# Epoch 24/50
# 57/57 [==============================] - 3s 45ms/step - loss: 22.0526 - val_loss: 5.0172
# Epoch 25/50
# 57/57 [==============================] - 4s 75ms/step - loss: 21.4588 - val_loss: 6.3262
# Epoch 26/50
# 57/57 [==============================] - 3s 46ms/step - loss: 22.1231 - val_loss: 12.0702
# Epoch 27/50
# 57/57 [==============================] - 3s 45ms/step - loss: 23.6844 - val_loss: 7.1666
# Epoch 28/50
# 57/57 [==============================] - 3s 46ms/step - loss: 22.2234 - val_loss: 6.3671
# Epoch 29/50
# 57/57 [==============================] - 3s 57ms/step - loss: 20.0201 - val_loss: 8.5397
# Epoch 30/50
# 57/57 [==============================] - 5s 85ms/step - loss: 21.9702 - val_loss: 4.5098
# Epoch 31/50
# 57/57 [==============================] - 5s 95ms/step - loss: 22.2555 - val_loss: 3.9071
# Epoch 32/50
# 57/57 [==============================] - 4s 71ms/step - loss: 21.1104 - val_loss: 5.5297
# Epoch 33/50
# 57/57 [==============================] - 3s 59ms/step - loss: 19.8358 - val_loss: 4.4921
# Epoch 34/50
# 57/57 [==============================] - 3s 44ms/step - loss: 21.7163 - val_loss: 4.8296
# Epoch 35/50
# 57/57 [==============================] - 3s 45ms/step - loss: 20.5992 - val_loss: 5.3078
# Epoch 36/50
# 57/57 [==============================] - 3s 44ms/step - loss: 21.5170 - val_loss: 3.7124
# Epoch 37/50
# 57/57 [==============================] - 4s 63ms/step - loss: 20.7198 - val_loss: 4.6978
# Epoch 38/50
# 57/57 [==============================] - 3s 53ms/step - loss: 20.1241 - val_loss: 4.9041
# Epoch 39/50
# 57/57 [==============================] - 3s 46ms/step - loss: 20.9581 - val_loss: 4.7291
# Epoch 40/50
# 57/57 [==============================] - 3s 46ms/step - loss: 21.5378 - val_loss: 4.3502
# Epoch 41/50
# 57/57 [==============================] - 2s 44ms/step - loss: 20.6555 - val_loss: 9.7359
# Epoch 42/50
# 57/57 [==============================] - 4s 69ms/step - loss: 20.5075 - val_loss: 4.2062
# Epoch 43/50
# 57/57 [==============================] - 3s 47ms/step - loss: 19.4926 - val_loss: 3.7050
# Epoch 44/50
# 57/57 [==============================] - 3s 46ms/step - loss: 21.8839 - val_loss: 6.6592
# Epoch 45/50
# 57/57 [==============================] - 3s 44ms/step - loss: 20.2143 - val_loss: 3.5993
# Epoch 46/50
# 57/57 [==============================] - 3s 46ms/step - loss: 21.1027 - val_loss: 3.7600
# Epoch 47/50
# 57/57 [==============================] - 4s 72ms/step - loss: 21.5364 - val_loss: 11.3751
# Epoch 48/50
# 57/57 [==============================] - 3s 45ms/step - loss: 21.2895 - val_loss: 16.6001
# Epoch 49/50
# 57/57 [==============================] - 3s 45ms/step - loss: 22.1125 - val_loss: 6.0452
# Epoch 50/50
# 57/57 [==============================] - 3s 44ms/step - loss: 20.5603 - val_loss: 3.8633
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_40 (LSTM)              (None, 60, 64)            16896
#
#  lstm_41 (LSTM)              (None, 32)                12416
#
#  dropout_20 (Dropout)        (None, 32)                0
#
#  dense_20 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 29345 (114.63 KB)
# Trainable params: 29345 (114.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 57/57 [==============================] - 7s 62ms/step - loss: 59.9535 - val_loss: 391.7540
# Epoch 2/50
# 57/57 [==============================] - 3s 44ms/step - loss: 50.5397 - val_loss: 110.0605
# Epoch 3/50
# 57/57 [==============================] - 2s 44ms/step - loss: 36.1487 - val_loss: 340.3026
# Epoch 4/50
# 57/57 [==============================] - 3s 45ms/step - loss: 36.6778 - val_loss: 176.3522
# Epoch 5/50
# 57/57 [==============================] - 4s 71ms/step - loss: 33.0355 - val_loss: 233.2944
# Epoch 6/50
# 57/57 [==============================] - 3s 45ms/step - loss: 34.1815 - val_loss: 266.8675
# Epoch 7/50
# 57/57 [==============================] - 3s 45ms/step - loss: 32.4921 - val_loss: 118.2399
# Epoch 8/50
# 57/57 [==============================] - 3s 46ms/step - loss: 31.2618 - val_loss: 238.3705
# Epoch 9/50
# 57/57 [==============================] - 3s 47ms/step - loss: 35.5641 - val_loss: 102.7625
# Epoch 10/50
# 57/57 [==============================] - 4s 70ms/step - loss: 31.1864 - val_loss: 185.6444
# Epoch 11/50
# 57/57 [==============================] - 3s 46ms/step - loss: 28.8760 - val_loss: 119.0184
# Epoch 12/50
# 57/57 [==============================] - 3s 46ms/step - loss: 26.3645 - val_loss: 250.0954
# Epoch 13/50
# 57/57 [==============================] - 3s 46ms/step - loss: 25.6251 - val_loss: 194.5423
# Epoch 14/50
# 57/57 [==============================] - 3s 57ms/step - loss: 48.9123 - val_loss: 157.4389
# Epoch 15/50
# 57/57 [==============================] - 3s 60ms/step - loss: 28.9201 - val_loss: 164.9863
# Epoch 16/50
# 57/57 [==============================] - 3s 45ms/step - loss: 24.9956 - val_loss: 150.0008
# Epoch 17/50
# 57/57 [==============================] - 3s 47ms/step - loss: 31.9846 - val_loss: 253.5886
# Epoch 18/50
# 57/57 [==============================] - 3s 45ms/step - loss: 27.1782 - val_loss: 168.2345
# Epoch 19/50
# 57/57 [==============================] - 4s 65ms/step - loss: 25.4398 - val_loss: 167.7399
# Epoch 20/50
# 57/57 [==============================] - 3s 52ms/step - loss: 22.3439 - val_loss: 345.0379
# Epoch 21/50
# 57/57 [==============================] - 3s 45ms/step - loss: 79.3769 - val_loss: 413.2042
# Epoch 22/50
# 57/57 [==============================] - 3s 45ms/step - loss: 45.4818 - val_loss: 370.4294
# Epoch 23/50
# 57/57 [==============================] - 3s 45ms/step - loss: 35.6166 - val_loss: 218.4029
# Epoch 24/50
# 57/57 [==============================] - 4s 73ms/step - loss: 50.0300 - val_loss: 208.7160
# Epoch 25/50
# 57/57 [==============================] - 3s 45ms/step - loss: 31.7846 - val_loss: 314.3218
# Epoch 26/50
# 57/57 [==============================] - 3s 45ms/step - loss: 33.6478 - val_loss: 122.7817
# Epoch 27/50
# 57/57 [==============================] - 3s 45ms/step - loss: 25.1631 - val_loss: 257.2587
# Epoch 28/50
# 57/57 [==============================] - 3s 48ms/step - loss: 28.9937 - val_loss: 116.5367
# Epoch 29/50
# 57/57 [==============================] - 4s 70ms/step - loss: 30.0925 - val_loss: 225.8124
# Epoch 30/50
# 57/57 [==============================] - 3s 45ms/step - loss: 27.8187 - val_loss: 187.9586
# Epoch 31/50
# 57/57 [==============================] - 3s 45ms/step - loss: 30.4679 - val_loss: 191.6536
# Epoch 32/50
# 57/57 [==============================] - 3s 44ms/step - loss: 30.2420 - val_loss: 248.2737
# Epoch 33/50
# 57/57 [==============================] - 3s 56ms/step - loss: 27.3754 - val_loss: 148.2999
# Epoch 34/50
# 57/57 [==============================] - 4s 63ms/step - loss: 27.0588 - val_loss: 214.3873
# Epoch 35/50
# 57/57 [==============================] - 3s 45ms/step - loss: 26.5241 - val_loss: 154.1967
# Epoch 36/50
# 57/57 [==============================] - 3s 46ms/step - loss: 27.9220 - val_loss: 152.7726
# Epoch 37/50
# 57/57 [==============================] - 3s 47ms/step - loss: 28.4583 - val_loss: 371.9041
# Epoch 38/50
# 57/57 [==============================] - 4s 67ms/step - loss: 24.7284 - val_loss: 99.7826
# Epoch 39/50
# 57/57 [==============================] - 3s 54ms/step - loss: 25.0924 - val_loss: 169.8714
# Epoch 40/50
# 57/57 [==============================] - 3s 45ms/step - loss: 25.1465 - val_loss: 322.4599
# Epoch 41/50
# 57/57 [==============================] - 3s 46ms/step - loss: 25.4600 - val_loss: 221.4246
# Epoch 42/50
# 57/57 [==============================] - 3s 46ms/step - loss: 26.4471 - val_loss: 161.5017
# Epoch 43/50
# 57/57 [==============================] - 4s 73ms/step - loss: 20.9863 - val_loss: 163.1954
# Epoch 44/50
# 57/57 [==============================] - 3s 45ms/step - loss: 21.2904 - val_loss: 121.9858
# Epoch 45/50
# 57/57 [==============================] - 3s 46ms/step - loss: 26.0428 - val_loss: 335.9709
# Epoch 46/50
# 57/57 [==============================] - 3s 46ms/step - loss: 23.0096 - val_loss: 246.2142
# Epoch 47/50
# 57/57 [==============================] - 3s 48ms/step - loss: 24.8294 - val_loss: 110.7863
# Epoch 48/50
# 57/57 [==============================] - 4s 68ms/step - loss: 22.3406 - val_loss: 121.0963
# Epoch 49/50
# 57/57 [==============================] - 3s 45ms/step - loss: 26.9765 - val_loss: 206.6055
# Epoch 50/50
# 57/57 [==============================] - 3s 46ms/step - loss: 24.6209 - val_loss: 116.1557
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_42 (LSTM)              (None, 60, 64)            16896
#
#  lstm_43 (LSTM)              (None, 32)                12416
#
#  dropout_21 (Dropout)        (None, 32)                0
#
#  dense_21 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 29345 (114.63 KB)
# Trainable params: 29345 (114.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 57/57 [==============================] - 6s 52ms/step - loss: 30.7618 - val_loss: 2.6186
# Epoch 2/50
# 57/57 [==============================] - 3s 59ms/step - loss: 12.4914 - val_loss: 10.2997
# Epoch 3/50
# 57/57 [==============================] - 3s 59ms/step - loss: 11.3146 - val_loss: 6.4672
# Epoch 4/50
# 57/57 [==============================] - 3s 45ms/step - loss: 12.0855 - val_loss: 1.2835
# Epoch 5/50
# 57/57 [==============================] - 3s 47ms/step - loss: 11.4990 - val_loss: 4.2629
# Epoch 6/50
# 57/57 [==============================] - 3s 45ms/step - loss: 10.5904 - val_loss: 3.7634
# Epoch 7/50
# 57/57 [==============================] - 4s 66ms/step - loss: 10.7651 - val_loss: 7.8230
# Epoch 8/50
# 57/57 [==============================] - 3s 53ms/step - loss: 10.5273 - val_loss: 5.3449
# Epoch 9/50
# 57/57 [==============================] - 3s 48ms/step - loss: 10.4609 - val_loss: 8.4311
# Epoch 10/50
# 57/57 [==============================] - 3s 46ms/step - loss: 10.5793 - val_loss: 9.1574
# Epoch 11/50
# 57/57 [==============================] - 3s 45ms/step - loss: 10.3515 - val_loss: 7.2522
# Epoch 12/50
# 57/57 [==============================] - 4s 74ms/step - loss: 10.4345 - val_loss: 4.1420
# Epoch 13/50
# 57/57 [==============================] - 3s 48ms/step - loss: 10.9579 - val_loss: 1.4580
# Epoch 14/50
# 57/57 [==============================] - 3s 47ms/step - loss: 10.5882 - val_loss: 4.6392
# Epoch 15/50
# 57/57 [==============================] - 3s 46ms/step - loss: 9.6003 - val_loss: 10.1984
# Epoch 16/50
# 57/57 [==============================] - 3s 57ms/step - loss: 10.4735 - val_loss: 4.5240
# Epoch 17/50
# 57/57 [==============================] - 4s 63ms/step - loss: 10.0627 - val_loss: 5.4622
# Epoch 18/50
# 57/57 [==============================] - 3s 45ms/step - loss: 9.7737 - val_loss: 2.0457
# Epoch 19/50
# 57/57 [==============================] - 3s 46ms/step - loss: 10.1918 - val_loss: 3.9656
# Epoch 20/50
# 57/57 [==============================] - 3s 46ms/step - loss: 9.5400 - val_loss: 6.6685
# Epoch 21/50
# 57/57 [==============================] - 4s 64ms/step - loss: 9.0517 - val_loss: 4.1308
# Epoch 22/50
# 57/57 [==============================] - 3s 53ms/step - loss: 8.6739 - val_loss: 1.8057
# Epoch 23/50
# 57/57 [==============================] - 3s 46ms/step - loss: 8.6419 - val_loss: 2.9861
# Epoch 24/50
# 57/57 [==============================] - 3s 46ms/step - loss: 8.7410 - val_loss: 4.7746
# Epoch 25/50
# 57/57 [==============================] - 3s 45ms/step - loss: 8.5447 - val_loss: 6.1944
# Epoch 26/50
# 57/57 [==============================] - 4s 74ms/step - loss: 8.9137 - val_loss: 3.8106
# Epoch 27/50
# 57/57 [==============================] - 3s 45ms/step - loss: 8.6368 - val_loss: 1.6054
# Epoch 28/50
# 57/57 [==============================] - 3s 47ms/step - loss: 8.4516 - val_loss: 0.5754
# Epoch 29/50
# 57/57 [==============================] - 3s 46ms/step - loss: 8.3244 - val_loss: 3.9872
# Epoch 30/50
# 57/57 [==============================] - 3s 50ms/step - loss: 8.2575 - val_loss: 5.5003
# Epoch 31/50
# 57/57 [==============================] - 4s 68ms/step - loss: 8.0453 - val_loss: 1.8492
# Epoch 32/50
# 57/57 [==============================] - 3s 46ms/step - loss: 8.3911 - val_loss: 1.9496
# Epoch 33/50
# 57/57 [==============================] - 3s 46ms/step - loss: 8.1450 - val_loss: 2.0716
# Epoch 34/50
# 57/57 [==============================] - 3s 45ms/step - loss: 8.1075 - val_loss: 3.9957
# Epoch 35/50
# 57/57 [==============================] - 3s 60ms/step - loss: 7.7268 - val_loss: 3.2307
# Epoch 36/50
# 57/57 [==============================] - 3s 59ms/step - loss: 8.0790 - val_loss: 5.2701
# Epoch 37/50
# 57/57 [==============================] - 3s 46ms/step - loss: 7.9044 - val_loss: 3.3825
# Epoch 38/50
# 57/57 [==============================] - 3s 46ms/step - loss: 7.8641 - val_loss: 2.6629
# Epoch 39/50
# 57/57 [==============================] - 3s 45ms/step - loss: 7.6527 - val_loss: 3.4855
# Epoch 40/50
# 57/57 [==============================] - 4s 69ms/step - loss: 7.8358 - val_loss: 2.3655
# Epoch 41/50
# 57/57 [==============================] - 3s 50ms/step - loss: 7.4611 - val_loss: 0.6198
# Epoch 42/50
# 57/57 [==============================] - 3s 45ms/step - loss: 7.8230 - val_loss: 1.9167
# Epoch 43/50
# 57/57 [==============================] - 3s 45ms/step - loss: 7.3181 - val_loss: 3.8914
# Epoch 44/50
# 57/57 [==============================] - 3s 46ms/step - loss: 6.9485 - val_loss: 3.9200
# Epoch 45/50
# 57/57 [==============================] - 4s 74ms/step - loss: 7.1955 - val_loss: 4.6838
# Epoch 46/50
# 57/57 [==============================] - 3s 46ms/step - loss: 7.5479 - val_loss: 1.6783
# Epoch 47/50
# 57/57 [==============================] - 3s 45ms/step - loss: 7.5929 - val_loss: 4.4114
# Epoch 48/50
# 57/57 [==============================] - 3s 47ms/step - loss: 7.0422 - val_loss: 3.6059
# Epoch 49/50
# 57/57 [==============================] - 3s 53ms/step - loss: 7.0429 - val_loss: 1.8293
# Epoch 50/50
# 57/57 [==============================] - 4s 68ms/step - loss: 7.0883 - val_loss: 0.3391

# %%
#prediction = model.predict(testX)
#prediction_copies = np.repeat(prediction, train_data.shape[1], axis=-1)
#y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]
#print(y_pred_future)

predicts = []
for i in range(8):
  #tạo predict mới cho test X: predict Y chua scale lai
  pred_y = models[i].predict(testX[:,:,i])
  print("Predict ", i)
  print(pred_y)

  predicts.append(pred_y)
#predicts = np.array(predicts)
print("Predict set: ", predicts.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c41067f59569> in <cell line: 7>()
#       7 for i in range(8):
#       8   #tạo predict mới cho test X: predict Y chua scale lai
# ----> 9   pred_y = models[i].predict(testX[:,:,i])
#      10   print("Predict ", i)
#      11   print(pred_y)
#
# NameError: name 'models' is not defined

# %%
# Scale nguoc lai
# Scale truc tiep tu array predict
# row x 8 cols
#pred_back = scaler.inverse_transform(predicts.T)

predicts_rs = predicts.reshape(predicts.shape[0], predicts.shape[1])
predicts_rs = predicts_rs.T

pred_cop = np.repeat(predicts_rs, 1, axis=-1)
pred_back = scaler.inverse_transform(pred_cop)[:,0]
pred_back
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-06920e05f277> in <cell line: 10>()
#       8
#       9 pred_cop = np.repeat(predicts_rs, 1, axis=-1)
# ---> 10 pred_back = scaler.inverse_transform(pred_cop)[:,0]
#      11 pred_back
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X, copy)
#    1050         else:
#    1051             if self.with_std:
# -> 1052                 X *= self.scale_
#    1053             if self.with_mean:
#    1054                 X += self.mean_
#
# ValueError: operands could not be broadcast together with shapes (267,8) (1634,) (267,8)

# %%
train_back = scaler.inverse_transform(train_data)
test_back = scaler.inverse_transform(test_data)

# %%
s_train = train_back.sum(axis = 1)
s_test = test_back.sum(axis = 1)
s_pred = pred_back.sum(axis = 1)

print("Train: ", s_train.shape)
print("Test: ", s_test.shape)
print("Predict: ", s_pred.shape)

# %%
plt.figure(figsize=(12, 5))
n_future = 60

# Plot actual values
plt.plot(range(train_size, train_size+test_size+1),s_test.reshape(-1,1), linestyle='-',  color='r', label='Test Data')
plt.plot(range(train_size), s_train, linestyle='-', color='b', label='Training Data')
#predict_date = Test_data['Time'];
plt.plot(range(train_size+n_future-1, train_size+test_size),  s_pred, label='Predict', linestyle='-',  color='orange')
# # Plot predicted values
#plt.plot( test_Date, y_pred, label='Predicted', linestyle='-',  color='b')

plt.title('VIB - Actual vs Predicted Stock Price Over Time')
plt.xlabel('Time')
plt.ylabel('Close')
plt.legend()

plt.show()

# %%
### 3. Predict 60 days
n_past = 1
n_days_for_prediction= 60

#print(test_data.reshape(1,-1).T.shape)

test_for_forecast = test_data.reshape(1,-1).T

x_forecast = []
y_forecast = []

for i in range(n_days_for_prediction):
  # B1 Duyệt dữ liệu test n ngày gần nhất => bỏ vào x tạm
  x = np.array(test_for_forecast[(-60):])
  print(x.shape)
  x = x.T.reshape(x.shape[1], x.shape[0], 1)
  print(x.shape)

  # B2 dùng predict để chạy 1 ngày
  y = model.predict(x)
  # B3 thêm data ngày đó vào y_forecast, test_for_forecast và append x vào x_forecast
  y_c = np.repeat(y, x.shape[1], axis=-1)
  y_pr = scaler.inverse_transform(y_c)[:,0]

  x_forecast.append(x)
  y_forecast.append(y_pr)
  test_for_forecast = np.append(test_for_forecast, y).reshape(-1,1)
  print(test_for_forecast.shape)
  #test_for_forecast.append(y)
  # B4 lặp lại đến ngày thứ 60

x_forecast = np.array(x_forecast)
y_forecast = np.array(y_forecast)

# %%
print(y_forecast)

# %%
plt.figure(figsize=(12, 6))

# Plot actual values
plt.plot(range(train_size, train_size+test_size+1),test_back.reshape(-1,1), linestyle='-',  color='r', label='Test Data')
plt.plot(range(train_size), train_back, linestyle='-', color='b', label='Training Data')
# Plot predict test and actual test
plt.plot(range(train_size + 60, train_size + test_size+1),  y_pred_future, label='Predict', linestyle='-',  color='orange')
# Plot 60 days
plt.plot(range(train_size+test_size, train_size+test_size+60), y_forecast, linestyle='-', color='b', label='60 days')

plt.title('VIB - Actual vs Predicted Stock Price Over Time')
plt.xlabel('Time')
plt.ylabel('Close')
plt.legend()

plt.show()

# %%
def RSME (data1, data2):
    return np.sqrt(np.mean((data1-data2)*(data1-data2)))
def MAE (data1, data2):
    return np.mean(np.absolute(data1-data2))
def MAPE (pred, actual):
    return np.mean(np.absolute((pred-actual)/actual))*100

# %%
print("RSME: ", RSME(y_pred_future, test_back[60:]))
print("MAE: ", MAE(y_pred_future, test_back[60:]))
print("MAPE: ", MAPE(y_pred_future, test_back[60:]))
