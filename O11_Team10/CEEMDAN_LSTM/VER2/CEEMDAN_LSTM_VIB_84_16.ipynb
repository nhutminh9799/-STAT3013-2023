# %%
# !pip install EMD-signal
# !pip install vnstock
# Out:
# Requirement already satisfied: EMD-signal in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.10/dist-packages (from EMD-signal) (1.23.5)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.10/dist-packages (from EMD-signal) (1.11.4)
# Requirement already satisfied: pathos>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from EMD-signal) (0.3.1)
# Requirement already satisfied: tqdm==4.64.* in /usr/local/lib/python3.10/dist-packages (from EMD-signal) (4.64.1)
# Requirement already satisfied: ppft>=1.7.6.7 in /usr/local/lib/python3.10/dist-packages (from pathos>=0.2.1->EMD-signal) (1.7.6.7)
# Requirement already satisfied: dill>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from pathos>=0.2.1->EMD-signal) (0.3.7)
# Requirement already satisfied: pox>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from pathos>=0.2.1->EMD-signal) (0.3.3)
# Requirement already satisfied: multiprocess>=0.70.15 in /usr/local/lib/python3.10/dist-packages (from pathos>=0.2.1->EMD-signal) (0.70.15)
# Requirement already satisfied: vnstock in /usr/local/lib/python3.10/dist-packages (0.2.8.7)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import PyEMD as pe
from vnstock import *

# %%
# Import data
VIB = stock_historical_data(symbol = "VIB", start_date="2017-06-01", end_date="2023-12-15", resolution="1D", type = "stock", beautify=True, decor=True, source = "DNSE")
from matplotlib import pyplot
print("Observations: ",len(VIB['Close']))
print(pd.DataFrame(VIB.head(6)))
train_dates = VIB.index
plt.figure(figsize=(12, 5))
VIB["Close"].plot()
# Out:
# Observations:  1634
#             Open  High   Low  Close  Volume Ticker
# Time
# 2017-06-02  3410  3440  3290   3320    2580    VIB
# 2017-06-05  3320  3410  3290   3290   39900    VIB
# 2017-06-06  3310  3320  3290   3320   53340    VIB
# 2017-06-07  3420  3420  3310   3340   69855    VIB
# 2017-06-08  3310  3310  3290   3310   50310    VIB
# 2017-06-09  3290  3310  3290   3290   43100    VIB
# <Axes: xlabel='Time'>

# %%
VIB = VIB.reset_index(drop = True)
df = VIB['Close']
df
# Out:
# 0        3320
# 1        3290
# 2        3320
# 3        3340
# 4        3310
#         ...
# 1629    19200
# 1630    19200
# 1631    19050
# 1632    18900
# 1633    18800
# Name: Close, Length: 1634, dtype: int64

# %% [markdown]
# ## (A) CEEMDAN
# #### 1. Thêm white noise vào chuỗi gốc s(t) thành chuỗi s1(t)
# #### 2. Decompose chuỗi s1(t) bằng EMD ra các chuỗi IMF1 và Residue1
# #### 3. Trung bình các chuỗi IMF1(t) thành mIMF1(t)
# #### 4. r1(t) = s1(t) - mIMF1(t)
# #### 5. Chuỗi mới s2(t) = r1(t) + coef*EMD(noise)
# #### 6. Làm lại từ 1->5 đến khi chuỗi residue dừng

# %%
from PyEMD import EMD, CEEMDAN

# %%
#ceemdan = CEEMDAN(range_thr=0.001, total_power_thr=0.01)
ceemdan = CEEMDAN(epsilon=0.0001, range_thr = 0.005)
ceemdan.noise_seed(seed = 1)
cIMFs = ceemdan.ceemdan(S=np.array(df.values), T= np.array(df.index))

# %%
pd.DataFrame(cIMFs.T, columns = ["IMF"+str(i+1) for i in range(cIMFs.shape[0])])
# Out:
#            IMF1        IMF2        IMF3        IMF4        IMF5         IMF6  \
# 0     14.060450   -0.125064  -99.866516   11.987497 -399.090638 -1029.482901
# 1    -17.956063   11.265541 -110.230602   12.831072 -404.944516 -1028.816121
# 2      6.095708   24.916011 -118.433636   13.525396 -411.409980 -1027.890276
# 3     19.532313   37.101328 -124.037969   14.044812 -418.488330 -1026.707236
# 4    -11.749570   41.514616 -126.604223   14.349789 -426.166152 -1025.269706
# ...         ...         ...         ...         ...         ...          ...
# 1629 -46.674086  224.388131  257.201353 -330.263136 -792.512950  3199.710613
# 1630  46.875445  170.049943  224.266408 -349.425016 -771.946674  3195.435082
# 1631   7.147697  112.288481  171.192773 -358.770973 -754.142068  3190.801640
# 1632 -35.262052   66.015384  103.111707 -358.856059 -739.183122  3185.811667
# 1633 -48.283858   44.667620   25.154472 -350.419914 -726.969242  3180.466543
#
#              IMF7          IMF8
# 0     3254.726296   1567.790876
# 1     3257.666048   1570.184641
# 2     3260.575205   1572.621572
# 3     3263.453467   1575.101614
# 4     3266.300533   1577.624713
# ...           ...           ...
# 1629 -4562.340498  21250.490574
# 1630 -4561.326994  21246.071808
# 1631 -4560.121850  21241.604301
# 1632 -4558.725530  21237.088006
# 1633 -4557.138501  21232.522880
#
# [1634 rows x 8 columns]

# %%
N = cIMFs.shape[0]+1
# Plot results
plt.subplot(N,1,1)
plt.plot(df.index, df.values, 'r')
plt.title("Input signal")
plt.xlabel("Time")

for n, imf in enumerate(cIMFs):
  plt.subplot(N,1,n+2)
  plt.plot(df.index, imf, 'g')
  plt.title("IMF "+str(n+1), x=1.2, y = 0)
  plt.xlabel("Time")
  plt.show()

# %%
# Tính residue
scIMF = cIMFs.sum(axis = 0).reshape(-1, 1)
residue = (np.array(df)-cIMFs.sum(axis = 0)).reshape(-1,1)

print("sIMF:", scIMF.shape)
print("Residue:", residue.shape)
# Out:
# sIMF: (1634, 1)
# Residue: (1634, 1)

# %%
plt.figure(figsize=(12,5))
plt.plot(range(0,len(df)), residue)
plt.plot(range(0,len(df)), scIMF)
plt.plot(range(0,len(df)), scIMF+residue)
plt.plot(df)
plt.legend(["Residual", "cIMF", "Ensembled series", "Original series"])

plt.show()

# %% [markdown]
# ## (B) LSTM
# ### 0. Tiền xử lý

# %%
# load các thư viện cần thiết
import math
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.regularizers import l1, l2
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import seaborn as sns
from sklearn.model_selection import KFold, cross_val_predict, train_test_split,GridSearchCV,cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder,StandardScaler,PowerTransformer, MinMaxScaler, RobustScaler

# %% [markdown]
# #### 0.1. Scale dữ liệu

# %%
# Scale data to 0-1
scaler = MinMaxScaler(feature_range=(0,1))
def Scaling (data):
    IMFscale = scaler.fit_transform(np.array(data))

    return IMFscale
cIMFs_t = cIMFs.T
IMFscale = Scaling(cIMFs_t)

# %%
print(IMFscale.shape)
# Out:
# (1634, 8)

# %% [markdown]
# #### 0.2. Chia Train test

# %%
print(IMFscale.shape)
# Chia train test
train_size = int(0.84*IMFscale.shape[0])
test_size = int(0.16*IMFscale.shape[0])
train_data = IMFscale[:train_size]
test_data = IMFscale[train_size:]

print("Train: ", train_data.shape)
print("Test: ", test_data.shape)

# Plotting both training and test data on the same chart
plt.figure(figsize=(12,5))

plt.plot(range(train_size), train_data, linestyle='-', color='b')
plt.plot(range(train_size -1,  train_size+test_size), test_data, linestyle='-',  color='r')

plt.title('VIB - Stock Close Over Time')
plt.xlabel('Time')
plt.ylabel('Close')
plt.show()
# Out:
# (1634, 8)
# Train:  (1372, 8)
# Test:  (262, 8)

# %%
# Train X and Y
# For each SAMPLE, we have a matrix of (1, 15, 8)
# consisting of one target, 15 days to look back and 8 features
###===
# For each LABEL, we have a matrix of (1, 8)
# consisting of one target and 8 features
###==
# LSTM is to be conducted parallelly

trainX = []
trainY = []

n_past = 30
n_future = 1

for i in range(n_past, len(train_data) - n_future + 1):
    past_sequence = train_data[i - n_past:i, :]  # Exclude the first column ("Close") for trainX
    future_sequence = train_data[i + n_future - 1: i + n_future, :]  # Use the "Close" column for trainY

    trainX.append(past_sequence)
    trainY.append(future_sequence)

trainX, trainY = np.array(trainX), np.array(trainY)
trainY = trainY.reshape(trainY.shape[0], trainY.shape[2])

print("X train: ", trainX.shape)
print("Y train: ", trainY.shape)
# Out:
# X train:  (1342, 30, 8)
# Y train:  (1342, 8)

# %%
# Test X and Y
# For each SAMPLE, we have a matrix of (1, 15, 8)
# consisting of one target, 15 days to look back and 8 features
###===
# For each LABEL, we have a matrix of (1, 8)
# consisting of one target and 8 features
###==
# LSTM is to be conducted parallelly
testX = []
testY = []

for i in range(n_past, len(test_data) - n_future + 1):
    past_sequence = test_data[i - n_past:i, :]  # Exclude the first column ("Close") for trainX
    future_sequence = test_data[i + n_future - 1: i + n_future, :]  # Use the "Close" column for trainY

    testX.append(past_sequence)
    testY.append(future_sequence)

testX, testY = np.array(testX), np.array(testY)
testY = testY.reshape(testY.shape[0], testY.shape[2])

print("X test: ", testX.shape)
print("Y test: ", testY.shape)
# Out:
# X test:  (232, 30, 8)
# Y test:  (232, 8)

# %%
# Plotting both training and test data on the same chart
plt.figure(figsize=(12,5))

plt.plot(range(train_size), train_data, linestyle='-', color='b', label='Training Data')
plt.plot(range(train_size-n_past), trainX[:,0,0], linestyle='-', label='Training Data X')
plt.plot(range(n_past,train_size), trainY[:,0], linestyle='-', label='Training Data Y')
plt.plot(range(train_size, train_size+test_size+1), test_data, linestyle='-',  color='r', label='Test Data')
plt.plot(range(train_size, train_size+test_size-n_past+1), testX[:,0,0], linestyle='-',  label='Test Data X')
plt.plot(range(train_size+n_past, train_size+test_size+1), testY[:,0], linestyle='-', label='Test Data Y')


plt.title('VIB - Stock Close Over Time')
plt.xlabel('Time')
plt.ylabel('Close')
plt.legend()
plt.show()

# %% [markdown]
# ### 1. Train model

# %%
# Tạo model lstm cho việc training
## kernel_regularizer=l2(0.01),
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]),

               recurrent_regularizer=l2(0.01),
               bias_regularizer=l2(0.01),
               return_sequences=True))
model.add(LSTM(20, activation='relu',
               recurrent_regularizer=l2(0.01),
               bias_regularizer=l2(0.01),
               return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainX.shape[2], kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_84 (LSTM)              (None, 30, 50)            11800
#
#  lstm_85 (LSTM)              (None, 20)                5680
#
#  dropout_40 (Dropout)        (None, 20)                0
#
#  dense_40 (Dense)            (None, 8)                 168
#
# =================================================================
# Total params: 17648 (68.94 KB)
# Trainable params: 17648 (68.94 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(trainX, trainY,epochs = 60, batch_size = 4, validation_split = 0.1, verbose=1)
# Out:
# Epoch 1/60
# 302/302 [==============================] - 11s 28ms/step - loss: 0.7854 - val_loss: 0.4814
# Epoch 2/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.3100 - val_loss: 0.2336
# Epoch 3/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.1450 - val_loss: 0.1315
# Epoch 4/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.0673 - val_loss: 0.0698
# Epoch 5/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0365 - val_loss: 0.0497
# Epoch 6/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.0239 - val_loss: 0.0580
# Epoch 7/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0207 - val_loss: 0.0439
# Epoch 8/60
# 302/302 [==============================] - 7s 23ms/step - loss: 0.0194 - val_loss: 0.0379
# Epoch 9/60
# 302/302 [==============================] - 7s 24ms/step - loss: 0.0183 - val_loss: 0.0347
# Epoch 10/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0180 - val_loss: 0.0382
# Epoch 11/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.0179 - val_loss: 0.0374
# Epoch 12/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0176 - val_loss: 0.0391
# Epoch 13/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.0175 - val_loss: 0.0342
# Epoch 14/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0181 - val_loss: 0.0344
# Epoch 15/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.0172 - val_loss: 0.0332
# Epoch 16/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0174 - val_loss: 0.0323
# Epoch 17/60
# 302/302 [==============================] - 7s 23ms/step - loss: 0.0166 - val_loss: 0.0354
# Epoch 18/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0174 - val_loss: 0.0337
# Epoch 19/60
# 302/302 [==============================] - 7s 25ms/step - loss: 0.0175 - val_loss: 0.0337
# Epoch 20/60
# 302/302 [==============================] - 7s 24ms/step - loss: 0.0167 - val_loss: 0.0385
# Epoch 21/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0165 - val_loss: 0.0320
# Epoch 22/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.0163 - val_loss: 0.0351
# Epoch 23/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0158 - val_loss: 0.0310
# Epoch 24/60
# 302/302 [==============================] - 7s 23ms/step - loss: 0.0161 - val_loss: 0.0351
# Epoch 25/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0159 - val_loss: 0.0307
# Epoch 26/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.0153 - val_loss: 0.0345
# Epoch 27/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0160 - val_loss: 0.0321
# Epoch 28/60
# 302/302 [==============================] - 9s 31ms/step - loss: 0.0162 - val_loss: 0.0312
# Epoch 29/60
# 302/302 [==============================] - 8s 27ms/step - loss: 0.0156 - val_loss: 0.0296
# Epoch 30/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0156 - val_loss: 0.0340
# Epoch 31/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.0161 - val_loss: 0.0285
# Epoch 32/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0153 - val_loss: 0.0305
# Epoch 33/60
# 302/302 [==============================] - 7s 23ms/step - loss: 0.0164 - val_loss: 0.0317
# Epoch 34/60
# 302/302 [==============================] - 8s 25ms/step - loss: 0.0155 - val_loss: 0.0393
# Epoch 35/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0156 - val_loss: 0.0312
# Epoch 36/60
# 302/302 [==============================] - 7s 23ms/step - loss: 0.0154 - val_loss: 0.0400
# Epoch 37/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0151 - val_loss: 0.0300
# Epoch 38/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.0160 - val_loss: 0.0313
# Epoch 39/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0156 - val_loss: 0.0309
# Epoch 40/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.0157 - val_loss: 0.0348
# Epoch 41/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0149 - val_loss: 0.0309
# Epoch 42/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.0150 - val_loss: 0.0302
# Epoch 43/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0155 - val_loss: 0.0288
# Epoch 44/60
# 302/302 [==============================] - 7s 24ms/step - loss: 0.0152 - val_loss: 0.0330
# Epoch 45/60
# 302/302 [==============================] - 7s 24ms/step - loss: 0.0158 - val_loss: 0.0310
# Epoch 46/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0149 - val_loss: 0.0312
# Epoch 47/60
# 302/302 [==============================] - 9s 31ms/step - loss: 0.0150 - val_loss: 0.0317
# Epoch 48/60
# 302/302 [==============================] - 8s 27ms/step - loss: 0.0154 - val_loss: 0.0335
# Epoch 49/60
# 302/302 [==============================] - 7s 23ms/step - loss: 0.0151 - val_loss: 0.0302
# Epoch 50/60
# 302/302 [==============================] - 9s 30ms/step - loss: 0.0154 - val_loss: 0.0303
# Epoch 51/60
# 302/302 [==============================] - 8s 27ms/step - loss: 0.0151 - val_loss: 0.0319
# Epoch 52/60
# 302/302 [==============================] - 8s 25ms/step - loss: 0.0152 - val_loss: 0.0331
# Epoch 53/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0146 - val_loss: 0.0293
# Epoch 54/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.0150 - val_loss: 0.0298
# Epoch 55/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0149 - val_loss: 0.0295
# Epoch 56/60
# 302/302 [==============================] - 7s 24ms/step - loss: 0.0148 - val_loss: 0.0302
# Epoch 57/60
# 302/302 [==============================] - 7s 24ms/step - loss: 0.0152 - val_loss: 0.0312
# Epoch 58/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0150 - val_loss: 0.0307
# Epoch 59/60
# 302/302 [==============================] - 7s 22ms/step - loss: 0.0151 - val_loss: 0.0289
# Epoch 60/60
# 302/302 [==============================] - 8s 26ms/step - loss: 0.0148 - val_loss: 0.0297

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### 2. Test model

# %%
testY.shape
# Out:
# (232, 8)

# %%
prediction = model.predict(testX)
prediction_copies = np.repeat(prediction, train_data.shape[1], axis=-1)
print(prediction_copies.shape)
y_pred_future = scaler.inverse_transform(prediction)[:]
print(y_pred_future.shape)
# Out:
# 8/8 [==============================] - 0s 8ms/step
# (232, 64)
# (232, 8)

# %%
train_back = scaler.inverse_transform(train_data)
test_back = scaler.inverse_transform(test_data)

# %%
train_sum = train_back.sum(axis = 1).reshape(-1, 1)
test_sum = test_back.sum(axis = 1).reshape(-1, 1)
pred_sum = y_pred_future.sum(axis=1).reshape(-1, 1)


print (train_sum.shape)
print(test_sum.shape)
print(pred_sum.shape)
print(pred_sum)
# Out:
# (1372, 1)
# (262, 1)
# (232, 1)
# [[16958.16  ]
#  [17161.203 ]
#  [17470.096 ]
#  [17813.377 ]
#  [18203.328 ]
#  [18411.576 ]
#  [18467.68  ]
#  [18543.492 ]
#  [18482.455 ]
#  [18573.508 ]
#  [18779.395 ]
#  [19064.56  ]
#  [19430.365 ]
#  [19458.486 ]
#  [19143.02  ]
#  [18754.377 ]
#  [18255.479 ]
#  [17395.898 ]
#  [16418.873 ]
#  [15956.694 ]
#  [15964.826 ]
#  [16353.35  ]
#  [16989.457 ]
#  [17591.26  ]
#  [17801.59  ]
#  [17484.459 ]
#  [17256.406 ]
#  [16901.441 ]
#  [16492.84  ]
#  [16259.309 ]
#  [16257.177 ]
#  [16350.028 ]
#  [16451.396 ]
#  [16539.047 ]
#  [16537.059 ]
#  [16443.4   ]
#  [16433.684 ]
#  [16323.007 ]
#  [16170.488 ]
#  [16065.84  ]
#  [16409.008 ]
#  [16516.582 ]
#  [16342.307 ]
#  [16106.5625]
#  [16052.766 ]
#  [16004.342 ]
#  [15947.542 ]
#  [15989.044 ]
#  [16117.915 ]
#  [16275.245 ]
#  [16376.828 ]
#  [16434.19  ]
#  [16537.953 ]
#  [16769.217 ]
#  [17049.268 ]
#  [17225.584 ]
#  [17241.338 ]
#  [17128.416 ]
#  [16998.25  ]
#  [16920.824 ]
#  [16905.705 ]
#  [16892.137 ]
#  [16815.73  ]
#  [16681.592 ]
#  [16513.607 ]
#  [16341.964 ]
#  [16200.792 ]
#  [16087.412 ]
#  [16006.121 ]
#  [15928.829 ]
#  [15915.711 ]
#  [15959.822 ]
#  [16011.579 ]
#  [16039.881 ]
#  [16043.099 ]
#  [16055.999 ]
#  [16092.017 ]
#  [16203.351 ]
#  [16319.276 ]
#  [16381.933 ]
#  [16414.008 ]
#  [16463.895 ]
#  [16622.193 ]
#  [16941.518 ]
#  [17182.072 ]
#  [17181.611 ]
#  [17022.215 ]
#  [16758.127 ]
#  [16448.775 ]
#  [16174.692 ]
#  [15971.409 ]
#  [15848.651 ]
#  [15899.424 ]
#  [16262.566 ]
#  [17034.838 ]
#  [17854.865 ]
#  [18182.703 ]
#  [18059.154 ]
#  [17814.521 ]
#  [17705.523 ]
#  [17740.299 ]
#  [17795.322 ]
#  [17804.809 ]
#  [17754.828 ]
#  [17658.047 ]
#  [17543.29  ]
#  [17468.215 ]
#  [17548.703 ]
#  [17776.344 ]
#  [18024.973 ]
#  [18155.238 ]
#  [18143.545 ]
#  [18042.406 ]
#  [17947.58  ]
#  [17901.006 ]
#  [17906.621 ]
#  [17908.025 ]
#  [17825.521 ]
#  [17786.62  ]
#  [17913.752 ]
#  [18097.328 ]
#  [18219.385 ]
#  [18266.662 ]
#  [18266.602 ]
#  [18299.094 ]
#  [18344.582 ]
#  [18399.252 ]
#  [18489.146 ]
#  [18616.611 ]
#  [18753.836 ]
#  [18833.3   ]
#  [18860.104 ]
#  [18853.01  ]
#  [18844.293 ]
#  [18855.012 ]
#  [18854.822 ]
#  [18794.596 ]
#  [18687.578 ]
#  [18807.443 ]
#  [19187.805 ]
#  [19563.393 ]
#  [19697.389 ]
#  [19547.383 ]
#  [19256.447 ]
#  [19024.291 ]
#  [19045.258 ]
#  [19326.14  ]
#  [19399.727 ]
#  [19055.17  ]
#  [18467.055 ]
#  [18071.055 ]
#  [17984.94  ]
#  [18066.533 ]
#  [18057.537 ]
#  [18008.713 ]
#  [18020.697 ]
#  [18139.346 ]
#  [18396.248 ]
#  [18762.242 ]
#  [19130.236 ]
#  [19361.734 ]
#  [19359.953 ]
#  [19272.328 ]
#  [19296.246 ]
#  [19506.203 ]
#  [19839.242 ]
#  [20196.352 ]
#  [20667.238 ]
#  [21101.984 ]
#  [21196.256 ]
#  [20798.275 ]
#  [20167.367 ]
#  [19449.984 ]
#  [18843.973 ]
#  [18527.02  ]
#  [18488.883 ]
#  [18678.39  ]
#  [18810.488 ]
#  [18660.516 ]
#  [18345.8   ]
#  [18074.844 ]
#  [18018.787 ]
#  [18211.602 ]
#  [18604.152 ]
#  [19074.764 ]
#  [19507.062 ]
#  [19759.01  ]
#  [19736.898 ]
#  [19499.238 ]
#  [19177.898 ]
#  [18893.166 ]
#  [18702.146 ]
#  [18585.377 ]
#  [18577.965 ]
#  [18413.564 ]
#  [18069.793 ]
#  [17833.46  ]
#  [17749.803 ]
#  [17758.984 ]
#  [17652.5   ]
#  [17887.139 ]
#  [18344.398 ]
#  [18681.559 ]
#  [18832.125 ]
#  [19077.809 ]
#  [19358.34  ]
#  [19621.709 ]
#  [19806.691 ]
#  [19861.299 ]
#  [19811.312 ]
#  [19758.287 ]
#  [19717.643 ]
#  [19700.861 ]
#  [19640.938 ]
#  [19529.402 ]
#  [19345.871 ]
#  [19101.47  ]
#  [18751.434 ]
#  [18480.074 ]
#  [18382.79  ]
#  [18423.627 ]
#  [18558.26  ]
#  [18718.977 ]
#  [18891.342 ]
#  [19087.781 ]
#  [19266.576 ]
#  [19387.035 ]
#  [19437.152 ]
#  [19421.744 ]
#  [19318.857 ]
#  [19169.072 ]
#  [18997.574 ]]

# %%
plt.figure(figsize=(12, 6))
n_future = 30

# Plot actual values
plt.plot(range(train_size, train_size+test_size+1),test_sum, linestyle='-',  color='r', label='Test Data')
plt.plot(range(train_size), train_sum, linestyle='-', color='b', label='Training Data')
#predict_date = Test_data['Time'];
plt.plot(range(train_size+n_future-1, train_size+test_size),  pred_sum, label='Predict', linestyle='-',  color='orange')
# # Plot predicted values
#plt.plot( test_Date, y_pred, label='Predicted', linestyle='-',  color='b')

plt.title('VIB - Actual vs Predicted Stock Price Over Time')
plt.xlabel('Time')
plt.ylabel('Close')
plt.legend()

plt.show()

# %% [markdown]
# ### 3. Predict 60 days

# %%
n_past = 1
n_days_for_prediction= 60

#print(test_data.reshape(1,-1).T.shape)

test_for_forecast = test_data
print("Test: ", test_for_forecast.shape)

x_forecast = []
y_forecast = []

for i in range(n_days_for_prediction):
  # B1 Duyệt dữ liệu test n ngày gần nhất => bỏ vào x tạm
  x = np.array(test_for_forecast[(-15):])
  print("X shape:",x.shape)
  x = x.reshape(1, x.shape[0], x.shape[1])
  print("X reshape: ",x.shape)

  # B2 dùng predict để chạy 1 ngày
  y = model.predict(x)
  print("Y shape:", y.shape)
  # B3 thêm data ngày đó vào y_forecast, test_for_forecast và append x vào x_forecast
  #y_c = np.repeat(y, train_data.shape[1], axis=-1)
  #print("Y copied:",y_c.shape)
  y_pr = scaler.inverse_transform(y)[:]

  x_forecast.append(x)
  y_forecast.append(y_pr)
  test_for_forecast = np.append(test_for_forecast, y).reshape(-1, 8)
  print(test_for_forecast.shape)
  #test_for_forecast.append(y)
  # B4 lặp lại đến ngày thứ 60

x_forecast = np.array(x_forecast)
y_forecast = np.array(y_forecast)
# Out:
# Test:  (262, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 346ms/step
# Y shape: (1, 8)
# (263, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 26ms/step
# Y shape: (1, 8)
# (264, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 24ms/step
# Y shape: (1, 8)
# (265, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 27ms/step
# Y shape: (1, 8)
# (266, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 23ms/step
# Y shape: (1, 8)
# (267, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (268, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 23ms/step
# Y shape: (1, 8)
# (269, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 28ms/step
# Y shape: (1, 8)
# (270, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 21ms/step
# Y shape: (1, 8)
# (271, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 21ms/step
# Y shape: (1, 8)
# (272, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 29ms/step
# Y shape: (1, 8)
# (273, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (274, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (275, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (276, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 24ms/step
# Y shape: (1, 8)
# (277, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 25ms/step
# Y shape: (1, 8)
# (278, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 25ms/step
# Y shape: (1, 8)
# (279, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 23ms/step
# Y shape: (1, 8)
# (280, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 21ms/step
# Y shape: (1, 8)
# (281, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 21ms/step
# Y shape: (1, 8)
# (282, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 21ms/step
# Y shape: (1, 8)
# (283, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (284, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 31ms/step
# Y shape: (1, 8)
# (285, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (286, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (287, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 23ms/step
# Y shape: (1, 8)
# (288, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (289, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 24ms/step
# Y shape: (1, 8)
# (290, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 24ms/step
# Y shape: (1, 8)
# (291, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 23ms/step
# Y shape: (1, 8)
# (292, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (293, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (294, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (295, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 25ms/step
# Y shape: (1, 8)
# (296, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 23ms/step
# Y shape: (1, 8)
# (297, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (298, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 24ms/step
# Y shape: (1, 8)
# (299, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 24ms/step
# Y shape: (1, 8)
# (300, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 29ms/step
# Y shape: (1, 8)
# (301, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 21ms/step
# Y shape: (1, 8)
# (302, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 21ms/step
# Y shape: (1, 8)
# (303, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 23ms/step
# Y shape: (1, 8)
# (304, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 26ms/step
# Y shape: (1, 8)
# (305, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (306, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (307, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 28ms/step
# Y shape: (1, 8)
# (308, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 25ms/step
# Y shape: (1, 8)
# (309, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 23ms/step
# Y shape: (1, 8)
# (310, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (311, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 24ms/step
# Y shape: (1, 8)
# (312, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 26ms/step
# Y shape: (1, 8)
# (313, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 24ms/step
# Y shape: (1, 8)
# (314, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 23ms/step
# Y shape: (1, 8)
# (315, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 23ms/step
# Y shape: (1, 8)
# (316, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (317, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (318, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 24ms/step
# Y shape: (1, 8)
# (319, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (320, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 22ms/step
# Y shape: (1, 8)
# (321, 8)
# X shape: (15, 8)
# X reshape:  (1, 15, 8)
# 1/1 [==============================] - 0s 37ms/step
# Y shape: (1, 8)
# (322, 8)

# %% [markdown]
# ## (C) Plot kiểm tra

# %%
print(y_forecast)
# Out:
# [[[ 1.91259995e+02  1.02634155e+02  2.72129791e+02  4.67649536e+02
#     3.44161224e+02  2.66051221e+03 -1.06754919e+03  1.58510205e+04]]
#
#  [[ 1.95113922e+02  1.11678764e+02  2.86104095e+02  4.90519318e+02
#     4.48146698e+02  2.69074683e+03 -1.01588940e+03  1.56679043e+04]]
#
#  [[ 1.86638580e+02  1.07952164e+02  2.74950256e+02  4.74526886e+02
#     4.41244049e+02  2.66509131e+03 -1.00636615e+03  1.53462783e+04]]
#
#  [[ 1.72250717e+02  9.75529251e+01  2.50426178e+02  4.38021301e+02
#     3.87316467e+02  2.61132056e+03 -1.01560217e+03  1.49972285e+04]]
#
#  [[ 1.55148605e+02  8.39250412e+01  2.19737793e+02  3.92056488e+02
#     3.09903137e+02  2.53632324e+03 -1.03370264e+03  1.46531436e+04]]
#
#  [[ 1.36839981e+02  6.87683487e+01  1.86431992e+02  3.42160339e+02
#     2.21145538e+02  2.44040649e+03 -1.05379382e+03  1.43290967e+04]]
#
#  [[ 1.18231628e+02  5.31964302e+01  1.52770432e+02  2.91439880e+02
#     1.28006012e+02  2.33085962e+03 -1.07010083e+03  1.40174033e+04]]
#
#  [[ 1.00940170e+02  3.87943840e+01  1.22252174e+02  2.44126862e+02
#     4.54794617e+01  2.21874536e+03 -1.06772620e+03  1.37035176e+04]]
#
#  [[ 8.40532684e+01  2.48013725e+01  9.27726898e+01  1.98289978e+02
#    -3.46736298e+01  2.10134619e+03 -1.06135730e+03  1.34022119e+04]]
#
#  [[ 6.77649078e+01  1.12509260e+01  6.44268723e+01  1.54379761e+02
#    -1.10598404e+02  1.97419849e+03 -1.05276550e+03  1.31269014e+04]]
#
#  [[ 5.18334579e+01 -1.99719346e+00  3.67913055e+01  1.11793724e+02
#    -1.84507751e+02  1.84032947e+03 -1.04421948e+03  1.28712725e+04]]
#
#  [[ 3.62420082e+01 -1.49510145e+01  9.80439281e+00  7.04351196e+01
#    -2.57138000e+02  1.70159827e+03 -1.03736890e+03  1.26324512e+04]]
#
#  [[ 2.09172573e+01 -2.76796398e+01 -1.66933079e+01  3.00393925e+01
#    -3.28577362e+02  1.55816357e+03 -1.03195703e+03  1.24082832e+04]]
#
#  [[ 5.89202452e+00 -4.01585770e+01 -4.26679611e+01 -9.36414146e+00
#    -3.99135071e+02  1.41167761e+03 -1.02903357e+03  1.21967773e+04]]
#
#  [[-8.56001568e+00 -5.21282883e+01 -6.75669708e+01 -4.69386673e+01
#    -4.67957245e+02  1.26334644e+03 -1.02524036e+03  1.19927754e+04]]
#
#  [[-2.14079456e+01 -6.25965233e+01 -8.92536316e+01 -7.93937225e+01
#    -5.31461792e+02  1.11517017e+03 -1.00743884e+03  1.17826992e+04]]
#
#  [[-3.30507278e+01 -7.19730301e+01 -1.08648331e+02 -1.08291847e+02
#    -5.91936523e+02  9.72666199e+02 -9.88883667e+02  1.15780439e+04]]
#
#  [[-4.39618607e+01 -8.06882782e+01 -1.26649139e+02 -1.35089828e+02
#    -6.49602356e+02  8.33319580e+02 -9.68149536e+02  1.13797236e+04]]
#
#  [[-5.42650146e+01 -8.88708191e+01 -1.43539734e+02 -1.60241333e+02
#    -7.05239380e+02  6.98325134e+02 -9.47347534e+02  1.11889463e+04]]
#
#  [[-6.40392456e+01 -9.66050034e+01 -1.59509323e+02 -1.84039352e+02
#    -7.59248230e+02  5.68447754e+02 -9.27555420e+02  1.10061299e+04]]
#
#  [[-7.27081223e+01 -1.03553642e+02 -1.73843140e+02 -2.04927231e+02
#    -8.09078857e+02  4.45435394e+02 -9.01309998e+02  1.08159873e+04]]
#
#  [[-8.02809753e+01 -1.09706268e+02 -1.86538559e+02 -2.22959259e+02
#    -8.54480591e+02  3.30179138e+02 -8.68698364e+02  1.06171533e+04]]
#
#  [[-8.69589157e+01 -1.15173767e+02 -1.97842499e+02 -2.38717056e+02
#    -8.96124451e+02  2.23142197e+02 -8.32163452e+02  1.04132021e+04]]
#
#  [[-9.28932114e+01 -1.20047989e+02 -2.07952957e+02 -2.52639923e+02
#    -9.34573425e+02  1.24621277e+02 -7.93450806e+02  1.02071152e+04]]
#
#  [[-9.81861267e+01 -1.24400375e+02 -2.17021088e+02 -2.65025177e+02
#    -9.70215942e+02  3.46916656e+01 -7.53599060e+02  1.00008115e+04]]
#
#  [[-1.02900490e+02 -1.28282364e+02 -2.25155640e+02 -2.76054474e+02
#    -1.00327435e+03 -4.67542229e+01 -7.13095276e+02  9.79522070e+03]]
#
#  [[-1.07106079e+02 -1.31746155e+02 -2.32463333e+02 -2.85919922e+02
#    -1.03399414e+03 -1.19932655e+02 -6.72578674e+02  9.59195410e+03]]
#
#  [[-1.10860077e+02 -1.34836197e+02 -2.39033127e+02 -2.94772919e+02
#    -1.06256519e+03 -1.85169647e+02 -6.32522583e+02  9.39240723e+03]]
#
#  [[-1.14198601e+02 -1.37584274e+02 -2.44927673e+02 -3.02703003e+02
#    -1.08908594e+03 -2.42876175e+02 -5.93086182e+02  9.19729004e+03]]
#
#  [[-1.17153152e+02 -1.40017426e+02 -2.50198166e+02 -3.09782196e+02
#    -1.11363306e+03 -2.93502258e+02 -5.54380737e+02  9.00726172e+03]]
#
#  [[-1.19751625e+02 -1.42158859e+02 -2.54888107e+02 -3.16071411e+02
#    -1.13626440e+03 -3.37519409e+02 -5.16475769e+02  8.82289551e+03]]
#
#  [[-1.22018501e+02 -1.44028564e+02 -2.59033966e+02 -3.21619598e+02
#    -1.15703394e+03 -3.75405945e+02 -4.79413483e+02  8.64467090e+03]]
#
#  [[-1.23976227e+02 -1.45644455e+02 -2.62667938e+02 -3.26470093e+02
#    -1.17598547e+03 -4.07646790e+02 -4.43193390e+02  8.47295508e+03]]
#
#  [[-1.25644997e+02 -1.47022614e+02 -2.65818604e+02 -3.30661041e+02
#    -1.19316785e+03 -4.34711853e+02 -4.07803223e+02  8.30802539e+03]]
#
#  [[-1.27043533e+02 -1.48177505e+02 -2.68511993e+02 -3.34224823e+02
#    -1.20862683e+03 -4.57056274e+02 -3.73215912e+02  8.15007178e+03]]
#
#  [[-1.28284500e+02 -1.49195755e+02 -2.70944000e+02 -3.37412323e+02
#    -1.22212036e+03 -4.76411194e+02 -3.39967163e+02  8.00068652e+03]]
#
#  [[-1.29471909e+02 -1.50160568e+02 -2.73300293e+02 -3.40473145e+02
#    -1.23358337e+03 -4.94328156e+02 -3.08668121e+02  7.86104639e+03]]
#
#  [[-1.30635788e+02 -1.51100220e+02 -2.75634277e+02 -3.43495300e+02
#    -1.24328040e+03 -5.11303680e+02 -2.79553864e+02  7.73098438e+03]]
#
#  [[-1.31781433e+02 -1.52023514e+02 -2.77953369e+02 -3.46500275e+02
#    -1.25151538e+03 -5.27506653e+02 -2.52679169e+02  7.60996533e+03]]
#
#  [[-1.32906738e+02 -1.52930588e+02 -2.80247650e+02 -3.49479980e+02
#    -1.25860278e+03 -5.43017273e+02 -2.28015747e+02  7.49742627e+03]]
#
#  [[-1.34006882e+02 -1.53819580e+02 -2.82504395e+02 -3.52420990e+02
#    -1.26477734e+03 -5.57864075e+02 -2.05476913e+02  7.39277832e+03]]
#
#  [[-1.35078094e+02 -1.54688049e+02 -2.84712769e+02 -3.55310211e+02
#    -1.27020801e+03 -5.72059631e+02 -1.84946625e+02  7.29542969e+03]]
#
#  [[-1.36117172e+02 -1.55534363e+02 -2.86864349e+02 -3.58135773e+02
#    -1.27502783e+03 -5.85613159e+02 -1.66296204e+02  7.20483301e+03]]
#
#  [[-1.37121948e+02 -1.56356491e+02 -2.88952271e+02 -3.60888641e+02
#    -1.27934436e+03 -5.98536987e+02 -1.49395157e+02  7.12048389e+03]]
#
#  [[-1.38091110e+02 -1.57153259e+02 -2.90972168e+02 -3.63561646e+02
#    -1.28324268e+03 -6.10846436e+02 -1.34113510e+02  7.04192236e+03]]
#
#  [[-1.39023956e+02 -1.57923813e+02 -2.92921173e+02 -3.66150085e+02
#    -1.28679492e+03 -6.22559082e+02 -1.20327156e+02  6.96873096e+03]]
#
#  [[-1.39920410e+02 -1.58667587e+02 -2.94797455e+02 -3.68650543e+02
#    -1.29005701e+03 -6.33692261e+02 -1.07917076e+02  6.90052783e+03]]
#
#  [[-1.40780533e+02 -1.59384384e+02 -2.96600616e+02 -3.71061127e+02
#    -1.29307544e+03 -6.44266235e+02 -9.67717590e+01  6.83696240e+03]]
#
#  [[-1.41605484e+02 -1.60074661e+02 -2.98331512e+02 -3.73382812e+02
#    -1.29588818e+03 -6.54306030e+02 -8.67892990e+01  6.77772412e+03]]
#
#  [[-1.42395554e+02 -1.60738251e+02 -2.99990540e+02 -3.75614624e+02
#    -1.29852698e+03 -6.63828857e+02 -7.78688736e+01  6.72250684e+03]]
#
#  [[-1.43151871e+02 -1.61375931e+02 -3.01579498e+02 -3.77758118e+02
#    -1.30101538e+03 -6.72859436e+02 -6.99219589e+01  6.67104590e+03]]
#
#  [[-1.43875259e+02 -1.61988007e+02 -3.03099396e+02 -3.79814606e+02
#    -1.30337488e+03 -6.81416016e+02 -6.28624268e+01  6.62308203e+03]]
#
#  [[-1.44567398e+02 -1.62575577e+02 -3.04553406e+02 -3.81787445e+02
#    -1.30562073e+03 -6.89526428e+02 -5.66196785e+01  6.57839893e+03]]
#
#  [[-1.45229034e+02 -1.63138870e+02 -3.05942688e+02 -3.83677277e+02
#    -1.30776819e+03 -6.97206421e+02 -5.11161537e+01  6.53676562e+03]]
#
#  [[-1.45861237e+02 -1.63678894e+02 -3.07269867e+02 -3.85487579e+02
#    -1.30982739e+03 -7.04477844e+02 -4.62882004e+01  6.49798291e+03]]
#
#  [[-1.46465134e+02 -1.64196106e+02 -3.08536774e+02 -3.87220184e+02
#    -1.31180603e+03 -7.11359497e+02 -4.20727005e+01  6.46186426e+03]]
#
#  [[-1.47041824e+02 -1.64691360e+02 -3.09745667e+02 -3.88876953e+02
#    -1.31371228e+03 -7.17871277e+02 -3.84134941e+01  6.42823193e+03]]
#
#  [[-1.47592514e+02 -1.65165543e+02 -3.10898712e+02 -3.90461975e+02
#    -1.31555188e+03 -7.24032898e+02 -3.52586899e+01  6.39692236e+03]]
#
#  [[-1.48118088e+02 -1.65619171e+02 -3.11998352e+02 -3.91976471e+02
#    -1.31732874e+03 -7.29861206e+02 -3.25601463e+01  6.36778076e+03]]
#
#  [[-1.48619598e+02 -1.66053101e+02 -3.13046539e+02 -3.93423584e+02
#    -1.31904639e+03 -7.35374268e+02 -3.02729397e+01  6.34066455e+03]]]

# %%
forecast_sum = y_forecast.sum(axis = -1)
print(forecast_sum.shape)
# Out:
# (60, 1)

# %%
plt.figure(figsize=(12, 6))

# Plot actual values
plt.plot(range(train_size, train_size+test_size+1),test_sum, linestyle='-',  color='r', label='Test Data')
plt.plot(range(train_size), train_sum, linestyle='-', color='b', label='Training Data')
#predict_date = Test_data['Time'];
plt.plot(range(train_size+n_future-1, train_size+test_size),  pred_sum, label='Predict', linestyle='-',  color='orange')
# Plot 60 days
plt.plot(range(train_size+test_size, train_size+test_size+60), forecast_sum, linestyle='-', color='green', label='60 days')

plt.title('VIB - Actual vs Predicted Stock Price Over Time')
plt.xlabel('Time')
plt.ylabel('Close')
plt.legend()

plt.show()

# %% [markdown]
# ## (D) Evaluation

# %%
def RSME (data1, data2):
    return np.sqrt(np.mean((data1-data2)*(data1-data2)))
def MAE (data1, data2):
    return np.mean(np.absolute(data1-data2))
def MAPE (pred, actual):
    return np.mean(np.absolute((pred-actual)/actual))*100
def MSLE (pred, actual):
    return np.mean((np.log(1+actual)-np.log(1+pred))*(np.log(1+actual)-np.log(1+pred)))

print("RSME: ", RSME(pred_sum, test_sum[30:]))
print("MAE: ", MAE(pred_sum, test_sum[30:]))
print("MAPE: ", MAPE(pred_sum, test_sum[30:]))
print("MSLR: ", MSLE(pred_sum, test_sum[30:]))
# Out:
# RSME:  1172.9391846101166
# MAE:  965.052906957166
# MAPE:  5.05490845099793
# MSLR:  0.0039586605350072
