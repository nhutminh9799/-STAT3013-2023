# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
data = pd.read_csv('/content/sample_data/SamSung.csv')
data
# Out:
#             Date     Open     High      Low    Close     Adj Close    Volume
# 0     2018-12-12  40250.0  40700.0  40150.0  40450.0  35281.417969  12024279
# 1     2018-12-13  40650.0  40750.0  40000.0  40000.0  34888.921875  26254646
# 2     2018-12-14  40200.0  40200.0  38700.0  38950.0  33973.089844  19671783
# 3     2018-12-17  38650.0  39600.0  38650.0  39150.0  34147.535156  11532968
# 4     2018-12-18  38300.0  39200.0  38300.0  38900.0  33929.472656  11042101
# ...          ...      ...      ...      ...      ...           ...       ...
# 1227  2023-12-06  71800.0  72100.0  71600.0  71700.0  71700.000000   8123087
# 1228  2023-12-07  71800.0  71900.0  71100.0  71500.0  71500.000000   8862017
# 1229  2023-12-08  72100.0  72800.0  71900.0  72600.0  72600.000000  10859463
# 1230  2023-12-11  72800.0  73000.0  72200.0  73000.0  73000.000000   9861960
# 1231  2023-12-12  73300.0  73500.0  73100.0  73500.0  73500.000000  13758646
#
# [1232 rows x 7 columns]

# %%
# Xử lý dữ liệu
timestamps = pd.to_datetime(data['Date'])
prices = data['Close']

# %%
# Chuẩn hóa dữ liệu
scaler = MinMaxScaler()
scaled_prices = scaler.fit_transform(prices.values.reshape(-1, 1))

# %%
# Chia dữ liệu thành tập huấn luyện, tập kiểm tra và tập validation
train_size = int(len(scaled_prices) * 0.8)
test_size = len(scaled_prices) - train_size

train_data = scaled_prices[:train_size]
test_data = scaled_prices[train_size:train_size+test_size]

# %%
# Chia dữ liệu thành các mẫu chuỗi thời gian
def create_time_series(data, time_steps):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i+time_steps])
        y.append(data[i+time_steps])
    return np.array(X), np.array(y)

time_steps = 100  # Số ngày quan sát trước để dự đoán ngày tiếp theo
X_train, y_train = create_time_series(train_data, time_steps)
X_test, y_test = create_time_series(test_data, time_steps)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Tạo mô hình DNN
model = Sequential()
model.add(Dense(50, activation='relu', input_shape=(time_steps,)))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))

# %%
# Biên dịch mô hình
model.compile(optimizer='adam', loss='mean_squared_error')

# Huấn luyện mô hình
model.fit(X_train, y_train, epochs=100, batch_size=64)

# Đánh giá mô hình trên tập kiểm tra
loss = model.evaluate(X_test, y_test)
print('Loss trên tập kiểm tra:', loss)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 3ms/step - loss: 0.0959
# Epoch 2/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0113
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0057
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 5/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 6/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0034
# Epoch 7/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0031
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 9/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 10/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 11/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 12/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 13/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 14/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 15/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 16/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 17/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 18/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 19/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 20/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 21/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 22/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 23/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 24/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0012
# Epoch 25/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 26/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 27/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 28/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 29/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 30/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 31/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 32/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 33/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 34/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 35/100
# 14/14 [==============================] - 0s 3ms/step - loss: 9.8207e-04
# Epoch 36/100
# 14/14 [==============================] - 0s 3ms/step - loss: 9.7979e-04
# Epoch 37/100
# 14/14 [==============================] - 0s 3ms/step - loss: 9.0803e-04
# Epoch 38/100
# 14/14 [==============================] - 0s 3ms/step - loss: 8.8680e-04
# Epoch 39/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 40/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 41/100
# 14/14 [==============================] - 0s 3ms/step - loss: 9.1704e-04
# Epoch 42/100
# 14/14 [==============================] - 0s 3ms/step - loss: 8.6988e-04
# Epoch 43/100
# 14/14 [==============================] - 0s 3ms/step - loss: 9.7009e-04
# Epoch 44/100
# 14/14 [==============================] - 0s 3ms/step - loss: 8.8061e-04
# Epoch 45/100
# 14/14 [==============================] - 0s 3ms/step - loss: 8.0733e-04
# Epoch 46/100
# 14/14 [==============================] - 0s 4ms/step - loss: 7.8083e-04
# Epoch 47/100
# 14/14 [==============================] - 0s 2ms/step - loss: 8.1802e-04
# Epoch 48/100
# 14/14 [==============================] - 0s 2ms/step - loss: 8.1408e-04
# Epoch 49/100
# 14/14 [==============================] - 0s 2ms/step - loss: 8.5732e-04
# Epoch 50/100
# 14/14 [==============================] - 0s 3ms/step - loss: 8.8560e-04
# Epoch 51/100
# 14/14 [==============================] - 0s 3ms/step - loss: 9.8104e-04
# Epoch 52/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.6990e-04
# Epoch 53/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.7677e-04
# Epoch 54/100
# 14/14 [==============================] - 0s 2ms/step - loss: 7.9732e-04
# Epoch 55/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.3258e-04
# Epoch 56/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.2125e-04
# Epoch 57/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.0796e-04
# Epoch 58/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.9450e-04
# Epoch 59/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.7716e-04
# Epoch 60/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.9533e-04
# Epoch 61/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.3900e-04
# Epoch 62/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.6631e-04
# Epoch 63/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.2026e-04
# Epoch 64/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.5268e-04
# Epoch 65/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.9133e-04
# Epoch 66/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.1933e-04
# Epoch 67/100
# 14/14 [==============================] - 0s 4ms/step - loss: 7.5464e-04
# Epoch 68/100
# 14/14 [==============================] - 0s 2ms/step - loss: 6.7155e-04
# Epoch 69/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.9260e-04
# Epoch 70/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.0634e-04
# Epoch 71/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.6727e-04
# Epoch 72/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.6569e-04
# Epoch 73/100
# 14/14 [==============================] - 0s 2ms/step - loss: 6.5292e-04
# Epoch 74/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.3749e-04
# Epoch 75/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.4532e-04
# Epoch 76/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.3384e-04
# Epoch 77/100
# 14/14 [==============================] - 0s 3ms/step - loss: 5.8749e-04
# Epoch 78/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.8302e-04
# Epoch 79/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.2752e-04
# Epoch 80/100
# 14/14 [==============================] - 0s 3ms/step - loss: 5.9857e-04
# Epoch 81/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.7652e-04
# Epoch 82/100
# 14/14 [==============================] - 0s 3ms/step - loss: 8.0216e-04
# Epoch 83/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.1995e-04
# Epoch 84/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.0559e-04
# Epoch 85/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.0929e-04
# Epoch 86/100
# 14/14 [==============================] - 0s 3ms/step - loss: 8.3045e-04
# Epoch 87/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.3607e-04
# Epoch 88/100
# 14/14 [==============================] - 0s 4ms/step - loss: 7.6129e-04
# Epoch 89/100
# 14/14 [==============================] - 0s 2ms/step - loss: 6.5440e-04
# Epoch 90/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.8047e-04
# Epoch 91/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.3138e-04
# Epoch 92/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.0192e-04
# Epoch 93/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.3081e-04
# Epoch 94/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.2481e-04
# Epoch 95/100
# 14/14 [==============================] - 0s 3ms/step - loss: 6.0387e-04
# Epoch 96/100
# 14/14 [==============================] - 0s 3ms/step - loss: 5.6216e-04
# Epoch 97/100
# 14/14 [==============================] - 0s 3ms/step - loss: 5.7931e-04
# Epoch 98/100
# 14/14 [==============================] - 0s 3ms/step - loss: 7.8475e-04
# Epoch 99/100
# 14/14 [==============================] - 0s 3ms/step - loss: 5.5074e-04
# Epoch 100/100
# 14/14 [==============================] - 0s 3ms/step - loss: 5.1370e-04
# 5/5 [==============================] - 0s 3ms/step - loss: 7.3196e-04
# Loss trên tập kiểm tra: 0.0007319636642932892

# %%
# Dự đoán giá trong quá trình kiểm tra
y_test_pred = model.predict(X_test)
y_test_pred = scaler.inverse_transform(y_test_pred)


# Tạo biến train, test, validate
train = prices[:train_size]
test = prices[train_size:train_size+test_size]

# Tạo biến dự đoán 30 ngày tiếp theo
predicted_prices = prices[-30:]
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
# Tạo biểu đồ train, test, validate và dự đoán 30 ngày tiếp theo
#plt.figure(figsize=(10, 6))
plt.plot(train, label='Train')
plt.plot(range(train_size, train_size+len(test)), test, label='Test')
plt.plot(range(train_size, train_size+len(y_test_pred)), y_test_pred, 'g', label='Test Predicted')
plt.plot(range(len(prices)-30, len(prices)), predicted_prices, 'r', label='Predicted')

plt.xlabel('Ngày')
plt.ylabel('Giá cổ phiếu')
plt.title('Biểu đồ train, test và dự đoán 30 ngày tiếp theo')
plt.legend()
plt.show()

# %%
print("Giá trị dự đoán 30 ngày tiếp theo:")
print(predicted_prices)
# Out:
# Giá trị dự đoán 30 ngày tiếp theo:
# 1202    68600.0
# 1203    69700.0
# 1204    69600.0
# 1205    70900.0
# 1206    70900.0
# 1207    69900.0
# 1208    70300.0
# 1209    70500.0
# 1210    70400.0
# 1211    70800.0
# 1212    72200.0
# 1213    72800.0
# 1214    72500.0
# 1215    72700.0
# 1216    72800.0
# 1217    72800.0
# 1218    72400.0
# 1219    71700.0
# 1220    71300.0
# 1221    72700.0
# 1222    72700.0
# 1223    72800.0
# 1224    72000.0
# 1225    72600.0
# 1226    71200.0
# 1227    71700.0
# 1228    71500.0
# 1229    72600.0
# 1230    73000.0
# 1231    73500.0
# Name: Close, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# Dự đoán giá trong quá trình testing
y_test_predicted = model.predict(X_test)


# Đưa các dự đoán về lại tỷ lệ ban đầu
y_test_predicted = scaler.inverse_transform(y_test_predicted)
y_test = scaler.inverse_transform(y_test)

# Tính MAE cho testing
mae_test = mean_absolute_error(y_test, y_test_predicted)

# Tính MAPE cho testing
mape_test = mean_absolute_percentage_error(y_test, y_test_predicted)

# Tính RMSE cho testing
rmse_test = mean_squared_error(y_test, y_test_predicted, squared=False)
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
mape_test *= 100
print("MAPE:", round(mape_test, 3))
print("MAE:", round(mae_test, 3))
print("RMSE:", round(rmse_test, 3))
print('-------------------')
# Out:
# MAPE: 1.636
# MAE: 1145.503
# RMSE: 1448.786
# -------------------
