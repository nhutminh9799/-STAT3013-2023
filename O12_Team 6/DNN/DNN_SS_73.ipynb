# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
data = pd.read_csv('/content/sample_data/SamSung.csv')
data
# Out:
#             Date     Open     High      Low    Close     Adj Close    Volume
# 0     2018-12-12  40250.0  40700.0  40150.0  40450.0  35281.417969  12024279
# 1     2018-12-13  40650.0  40750.0  40000.0  40000.0  34888.921875  26254646
# 2     2018-12-14  40200.0  40200.0  38700.0  38950.0  33973.089844  19671783
# 3     2018-12-17  38650.0  39600.0  38650.0  39150.0  34147.535156  11532968
# 4     2018-12-18  38300.0  39200.0  38300.0  38900.0  33929.472656  11042101
# ...          ...      ...      ...      ...      ...           ...       ...
# 1227  2023-12-06  71800.0  72100.0  71600.0  71700.0  71700.000000   8123087
# 1228  2023-12-07  71800.0  71900.0  71100.0  71500.0  71500.000000   8862017
# 1229  2023-12-08  72100.0  72800.0  71900.0  72600.0  72600.000000  10859463
# 1230  2023-12-11  72800.0  73000.0  72200.0  73000.0  73000.000000   9861960
# 1231  2023-12-12  73300.0  73500.0  73100.0  73500.0  73500.000000  13758646
#
# [1232 rows x 7 columns]

# %%
# Xử lý dữ liệu
timestamps = pd.to_datetime(data['Date'])
prices = data['Close']

# %%
# Chuẩn hóa dữ liệu
scaler = MinMaxScaler()
scaled_prices = scaler.fit_transform(prices.values.reshape(-1, 1))

# %%
# Chia dữ liệu thành tập huấn luyện, tập kiểm tra và tập validation
train_size = int(len(scaled_prices) * 0.7)
test_size = len(scaled_prices) - train_size

train_data = scaled_prices[:train_size]
test_data = scaled_prices[train_size:train_size+test_size]

# %%
# Chia dữ liệu thành các mẫu chuỗi thời gian
def create_time_series(data, time_steps):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i+time_steps])
        y.append(data[i+time_steps])
    return np.array(X), np.array(y)

time_steps = 100  # Số ngày quan sát trước để dự đoán ngày tiếp theo
X_train, y_train = create_time_series(train_data, time_steps)
X_test, y_test = create_time_series(test_data, time_steps)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Tạo mô hình DNN
model = Sequential()
model.add(Dense(50, activation='relu', input_shape=(time_steps,)))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))

# %%
# Biên dịch mô hình
model.compile(optimizer='adam', loss='mean_squared_error')

# Huấn luyện mô hình
model.fit(X_train, y_train, epochs=100, batch_size=64)

# Đánh giá mô hình trên tập kiểm tra
loss = model.evaluate(X_test, y_test)
print('Loss trên tập kiểm tra:', loss)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 2s 3ms/step - loss: 0.0628
# Epoch 2/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0120
# Epoch 3/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0101
# Epoch 4/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0072
# Epoch 5/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0052
# Epoch 6/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 7/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 8/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0030
# Epoch 9/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 10/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 11/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 12/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 13/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 14/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 15/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 16/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 17/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 18/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 19/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 20/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 21/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 22/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 23/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 24/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 25/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 26/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 27/100
# 12/12 [==============================] - 0s 3ms/step - loss: 9.7405e-04
# Epoch 28/100
# 12/12 [==============================] - 0s 3ms/step - loss: 9.6456e-04
# Epoch 29/100
# 12/12 [==============================] - 0s 3ms/step - loss: 9.2727e-04
# Epoch 30/100
# 12/12 [==============================] - 0s 4ms/step - loss: 9.7657e-04
# Epoch 31/100
# 12/12 [==============================] - 0s 3ms/step - loss: 9.8503e-04
# Epoch 32/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0010
# Epoch 33/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 34/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 35/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.8297e-04
# Epoch 36/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.8938e-04
# Epoch 37/100
# 12/12 [==============================] - 0s 3ms/step - loss: 9.7126e-04
# Epoch 38/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 39/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 40/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 41/100
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 42/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 43/100
# 12/12 [==============================] - 0s 3ms/step - loss: 9.1907e-04
# Epoch 44/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.7517e-04
# Epoch 45/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.0738e-04
# Epoch 46/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.1809e-04
# Epoch 47/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.3576e-04
# Epoch 48/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 49/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.9535e-04
# Epoch 50/100
# 12/12 [==============================] - 0s 3ms/step - loss: 9.3587e-04
# Epoch 51/100
# 12/12 [==============================] - 0s 3ms/step - loss: 9.2421e-04
# Epoch 52/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.3517e-04
# Epoch 53/100
# 12/12 [==============================] - 0s 5ms/step - loss: 8.4033e-04
# Epoch 54/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.5406e-04
# Epoch 55/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.9703e-04
# Epoch 56/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.2176e-04
# Epoch 57/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.2980e-04
# Epoch 58/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.7963e-04
# Epoch 59/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.8325e-04
# Epoch 60/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.6976e-04
# Epoch 61/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.7777e-04
# Epoch 62/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.6295e-04
# Epoch 63/100
# 12/12 [==============================] - 0s 3ms/step - loss: 9.6837e-04
# Epoch 64/100
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 65/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.7254e-04
# Epoch 66/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.0050e-04
# Epoch 67/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.1057e-04
# Epoch 68/100
# 12/12 [==============================] - 0s 4ms/step - loss: 7.0647e-04
# Epoch 69/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.5932e-04
# Epoch 70/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.5333e-04
# Epoch 71/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.6684e-04
# Epoch 72/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.4864e-04
# Epoch 73/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.6964e-04
# Epoch 74/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.3966e-04
# Epoch 75/100
# 12/12 [==============================] - 0s 4ms/step - loss: 8.2410e-04
# Epoch 76/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.9645e-04
# Epoch 77/100
# 12/12 [==============================] - 0s 4ms/step - loss: 6.8160e-04
# Epoch 78/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.5232e-04
# Epoch 79/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.6811e-04
# Epoch 80/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.0700e-04
# Epoch 81/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.8648e-04
# Epoch 82/100
# 12/12 [==============================] - 0s 2ms/step - loss: 6.5437e-04
# Epoch 83/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.9981e-04
# Epoch 84/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.9554e-04
# Epoch 85/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.2954e-04
# Epoch 86/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.8400e-04
# Epoch 87/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.0836e-04
# Epoch 88/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.9087e-04
# Epoch 89/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.7872e-04
# Epoch 90/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.5772e-04
# Epoch 91/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.6263e-04
# Epoch 92/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.4543e-04
# Epoch 93/100
# 12/12 [==============================] - 0s 3ms/step - loss: 7.3213e-04
# Epoch 94/100
# 12/12 [==============================] - 0s 3ms/step - loss: 8.4048e-04
# Epoch 95/100
# 12/12 [==============================] - 0s 4ms/step - loss: 9.1697e-04
# Epoch 96/100
# 12/12 [==============================] - 0s 3ms/step - loss: 6.5472e-04
# Epoch 97/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.6166e-04
# Epoch 98/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.6113e-04
# Epoch 99/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.2946e-04
# Epoch 100/100
# 12/12 [==============================] - 0s 3ms/step - loss: 5.4546e-04
# 9/9 [==============================] - 0s 3ms/step - loss: 5.7259e-04
# Loss trên tập kiểm tra: 0.0005725884693674743

# %%
# Dự đoán giá trong quá trình kiểm tra
y_test_pred = model.predict(X_test)
y_test_pred = scaler.inverse_transform(y_test_pred)


# Tạo biến train, test, validate
train = prices[:train_size]
test = prices[train_size:train_size+test_size]

# Tạo biến dự đoán 30 ngày tiếp theo
predicted_prices = prices[-30:]
# Out:
# 9/9 [==============================] - 0s 4ms/step

# %%
# Tạo biểu đồ train, test, validate và dự đoán 30 ngày tiếp theo
#plt.figure(figsize=(10, 6))
plt.plot(train, label='Train')
plt.plot(range(train_size, train_size+len(test)), test, label='Test')
plt.plot(range(train_size, train_size+len(y_test_pred)), y_test_pred, 'g', label='Test Predicted')
plt.plot(range(len(prices)-30, len(prices)), predicted_prices, 'r', label='Predicted')

plt.xlabel('Ngày')
plt.ylabel('Giá cổ phiếu')
plt.title('Biểu đồ train, test và dự đoán 30 ngày tiếp theo')
plt.legend()
plt.show()

# %%
print("Giá trị dự đoán 30 ngày tiếp theo:")
print(predicted_prices)
# Out:
# Giá trị dự đoán 30 ngày tiếp theo:
# 1202    68600.0
# 1203    69700.0
# 1204    69600.0
# 1205    70900.0
# 1206    70900.0
# 1207    69900.0
# 1208    70300.0
# 1209    70500.0
# 1210    70400.0
# 1211    70800.0
# 1212    72200.0
# 1213    72800.0
# 1214    72500.0
# 1215    72700.0
# 1216    72800.0
# 1217    72800.0
# 1218    72400.0
# 1219    71700.0
# 1220    71300.0
# 1221    72700.0
# 1222    72700.0
# 1223    72800.0
# 1224    72000.0
# 1225    72600.0
# 1226    71200.0
# 1227    71700.0
# 1228    71500.0
# 1229    72600.0
# 1230    73000.0
# 1231    73500.0
# Name: Close, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

# Dự đoán giá trong quá trình testing
y_test_predicted = model.predict(X_test)


# Đưa các dự đoán về lại tỷ lệ ban đầu
y_test_predicted = scaler.inverse_transform(y_test_predicted)
y_test = scaler.inverse_transform(y_test)

# Tính MAE cho testing
mae_test = mean_absolute_error(y_test, y_test_predicted)

# Tính MAPE cho testing
mape_test = mean_absolute_percentage_error(y_test, y_test_predicted)

# Tính RMSE cho testing
rmse_test = mean_squared_error(y_test, y_test_predicted, squared=False)
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
mape_test *= 100
print("MAPE:", round(mape_test, 3))
print("MAE:", round(mae_test, 3))
print("RMSE:", round(rmse_test, 3))
print('-------------------')
# Out:
# MAPE: 1.48
# MAE: 976.946
# RMSE: 1281.388
# -------------------
