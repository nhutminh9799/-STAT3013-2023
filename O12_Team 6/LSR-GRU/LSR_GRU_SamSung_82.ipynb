# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import Lasso
from sklearn.ensemble import GradientBoostingRegressor
from keras.models import Sequential
from keras.layers import GRU, Dense
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# Đọc dữ liệu
df = pd.read_csv('/content/sample_data/SamSung.csv')
#df = pd.read_csv('AAPL.csv', header=0, parse_dates=[0], index_col=0)
df = df[['Close']].dropna().reset_index(drop=True)

df.head()
# Out:
#      Close
# 0  40450.0
# 1  40000.0
# 2  38950.0
# 3  39150.0
# 4  38900.0

# %%
# Chia tập train-test
train_size = int(0.8 * len(df))
test_size = len(df) - train_size
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# %%
# Scaling data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# Function to create dataset for model
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 1
X_train, Y_train = create_dataset(scaled_data[:train_size], look_back)
X_test, Y_test = create_dataset(scaled_data[train_size:], look_back)

# Reshape input to be [samples, time steps, features] for GRU
X_train_gru = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test_gru = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
# Lasso model
lasso = Lasso(alpha=0.01)
lasso.fit(X_train, Y_train)
# Out:
# Lasso(alpha=0.01)

# %%
# GRU model
gru_model = Sequential()
gru_model.add(GRU(units=50, return_sequences=True, input_shape=(1, look_back)))
gru_model.add(GRU(units=50))
gru_model.add(Dense(1))
gru_model.compile(loss='mean_squared_error', optimizer='adam')
gru_model.fit(X_train_gru, Y_train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 983/983 - 7s - loss: 0.0092 - 7s/epoch - 7ms/step
# Epoch 2/100
# 983/983 - 2s - loss: 5.3710e-04 - 2s/epoch - 3ms/step
# Epoch 3/100
# 983/983 - 3s - loss: 5.5498e-04 - 3s/epoch - 3ms/step
# Epoch 4/100
# 983/983 - 3s - loss: 5.8972e-04 - 3s/epoch - 3ms/step
# Epoch 5/100
# 983/983 - 3s - loss: 5.2394e-04 - 3s/epoch - 3ms/step
# Epoch 6/100
# 983/983 - 3s - loss: 6.2670e-04 - 3s/epoch - 3ms/step
# Epoch 7/100
# 983/983 - 2s - loss: 5.6850e-04 - 2s/epoch - 3ms/step
# Epoch 8/100
# 983/983 - 3s - loss: 6.2053e-04 - 3s/epoch - 3ms/step
# Epoch 9/100
# 983/983 - 3s - loss: 5.5517e-04 - 3s/epoch - 3ms/step
# Epoch 10/100
# 983/983 - 3s - loss: 5.1460e-04 - 3s/epoch - 3ms/step
# Epoch 11/100
# 983/983 - 4s - loss: 5.4722e-04 - 4s/epoch - 4ms/step
# Epoch 12/100
# 983/983 - 3s - loss: 5.0010e-04 - 3s/epoch - 3ms/step
# Epoch 13/100
# 983/983 - 2s - loss: 5.4553e-04 - 2s/epoch - 3ms/step
# Epoch 14/100
# 983/983 - 3s - loss: 5.5089e-04 - 3s/epoch - 3ms/step
# Epoch 15/100
# 983/983 - 3s - loss: 5.1955e-04 - 3s/epoch - 3ms/step
# Epoch 16/100
# 983/983 - 3s - loss: 5.2066e-04 - 3s/epoch - 3ms/step
# Epoch 17/100
# 983/983 - 3s - loss: 5.0545e-04 - 3s/epoch - 3ms/step
# Epoch 18/100
# 983/983 - 2s - loss: 4.8015e-04 - 2s/epoch - 3ms/step
# Epoch 19/100
# 983/983 - 3s - loss: 5.0978e-04 - 3s/epoch - 3ms/step
# Epoch 20/100
# 983/983 - 5s - loss: 5.0946e-04 - 5s/epoch - 5ms/step
# Epoch 21/100
# 983/983 - 4s - loss: 4.8812e-04 - 4s/epoch - 4ms/step
# Epoch 22/100
# 983/983 - 3s - loss: 4.9338e-04 - 3s/epoch - 3ms/step
# Epoch 23/100
# 983/983 - 2s - loss: 5.2497e-04 - 2s/epoch - 3ms/step
# Epoch 24/100
# 983/983 - 3s - loss: 5.0772e-04 - 3s/epoch - 3ms/step
# Epoch 25/100
# 983/983 - 3s - loss: 5.0010e-04 - 3s/epoch - 3ms/step
# Epoch 26/100
# 983/983 - 3s - loss: 4.6705e-04 - 3s/epoch - 3ms/step
# Epoch 27/100
# 983/983 - 3s - loss: 4.7498e-04 - 3s/epoch - 3ms/step
# Epoch 28/100
# 983/983 - 3s - loss: 4.9253e-04 - 3s/epoch - 3ms/step
# Epoch 29/100
# 983/983 - 3s - loss: 4.5588e-04 - 3s/epoch - 3ms/step
# Epoch 30/100
# 983/983 - 3s - loss: 4.6546e-04 - 3s/epoch - 3ms/step
# Epoch 31/100
# 983/983 - 3s - loss: 4.8959e-04 - 3s/epoch - 3ms/step
# Epoch 32/100
# 983/983 - 3s - loss: 4.6612e-04 - 3s/epoch - 3ms/step
# Epoch 33/100
# 983/983 - 3s - loss: 4.9605e-04 - 3s/epoch - 3ms/step
# Epoch 34/100
# 983/983 - 3s - loss: 4.5408e-04 - 3s/epoch - 3ms/step
# Epoch 35/100
# 983/983 - 3s - loss: 4.5866e-04 - 3s/epoch - 3ms/step
# Epoch 36/100
# 983/983 - 3s - loss: 4.6041e-04 - 3s/epoch - 3ms/step
# Epoch 37/100
# 983/983 - 3s - loss: 4.5326e-04 - 3s/epoch - 3ms/step
# Epoch 38/100
# 983/983 - 3s - loss: 4.7048e-04 - 3s/epoch - 3ms/step
# Epoch 39/100
# 983/983 - 3s - loss: 4.4621e-04 - 3s/epoch - 3ms/step
# Epoch 40/100
# 983/983 - 3s - loss: 4.5050e-04 - 3s/epoch - 3ms/step
# Epoch 41/100
# 983/983 - 3s - loss: 4.8766e-04 - 3s/epoch - 3ms/step
# Epoch 42/100
# 983/983 - 2s - loss: 4.5393e-04 - 2s/epoch - 3ms/step
# Epoch 43/100
# 983/983 - 3s - loss: 4.6421e-04 - 3s/epoch - 3ms/step
# Epoch 44/100
# 983/983 - 3s - loss: 4.4933e-04 - 3s/epoch - 4ms/step
# Epoch 45/100
# 983/983 - 3s - loss: 4.5178e-04 - 3s/epoch - 3ms/step
# Epoch 46/100
# 983/983 - 3s - loss: 4.7097e-04 - 3s/epoch - 3ms/step
# Epoch 47/100
# 983/983 - 3s - loss: 4.7698e-04 - 3s/epoch - 3ms/step
# Epoch 48/100
# 983/983 - 2s - loss: 4.2476e-04 - 2s/epoch - 2ms/step
# Epoch 49/100
# 983/983 - 4s - loss: 4.5019e-04 - 4s/epoch - 4ms/step
# Epoch 50/100
# 983/983 - 3s - loss: 4.3599e-04 - 3s/epoch - 3ms/step
# Epoch 51/100
# 983/983 - 3s - loss: 4.3452e-04 - 3s/epoch - 3ms/step
# Epoch 52/100
# 983/983 - 3s - loss: 4.5420e-04 - 3s/epoch - 3ms/step
# Epoch 53/100
# 983/983 - 2s - loss: 4.3093e-04 - 2s/epoch - 3ms/step
# Epoch 54/100
# 983/983 - 4s - loss: 4.5641e-04 - 4s/epoch - 4ms/step
# Epoch 55/100
# 983/983 - 3s - loss: 4.1871e-04 - 3s/epoch - 3ms/step
# Epoch 56/100
# 983/983 - 3s - loss: 4.2712e-04 - 3s/epoch - 3ms/step
# Epoch 57/100
# 983/983 - 3s - loss: 4.4276e-04 - 3s/epoch - 3ms/step
# Epoch 58/100
# 983/983 - 3s - loss: 4.3782e-04 - 3s/epoch - 3ms/step
# Epoch 59/100
# 983/983 - 4s - loss: 4.2881e-04 - 4s/epoch - 4ms/step
# Epoch 60/100
# 983/983 - 2s - loss: 4.8129e-04 - 2s/epoch - 3ms/step
# Epoch 61/100
# 983/983 - 3s - loss: 4.1717e-04 - 3s/epoch - 3ms/step
# Epoch 62/100
# 983/983 - 3s - loss: 4.3139e-04 - 3s/epoch - 3ms/step
# Epoch 63/100
# 983/983 - 3s - loss: 4.3700e-04 - 3s/epoch - 3ms/step
# Epoch 64/100
# 983/983 - 3s - loss: 4.4129e-04 - 3s/epoch - 3ms/step
# Epoch 65/100
# 983/983 - 2s - loss: 4.2659e-04 - 2s/epoch - 3ms/step
# Epoch 66/100
# 983/983 - 3s - loss: 4.5488e-04 - 3s/epoch - 3ms/step
# Epoch 67/100
# 983/983 - 3s - loss: 4.2517e-04 - 3s/epoch - 3ms/step
# Epoch 68/100
# 983/983 - 3s - loss: 4.8003e-04 - 3s/epoch - 3ms/step
# Epoch 69/100
# 983/983 - 3s - loss: 4.2268e-04 - 3s/epoch - 3ms/step
# Epoch 70/100
# 983/983 - 3s - loss: 4.3322e-04 - 3s/epoch - 3ms/step
# Epoch 71/100
# 983/983 - 3s - loss: 4.0900e-04 - 3s/epoch - 3ms/step
# Epoch 72/100
# 983/983 - 3s - loss: 4.3280e-04 - 3s/epoch - 3ms/step
# Epoch 73/100
# 983/983 - 3s - loss: 4.3580e-04 - 3s/epoch - 3ms/step
# Epoch 74/100
# 983/983 - 3s - loss: 4.4648e-04 - 3s/epoch - 3ms/step
# Epoch 75/100
# 983/983 - 2s - loss: 4.3986e-04 - 2s/epoch - 3ms/step
# Epoch 76/100
# 983/983 - 3s - loss: 4.3695e-04 - 3s/epoch - 3ms/step
# Epoch 77/100
# 983/983 - 3s - loss: 4.1775e-04 - 3s/epoch - 3ms/step
# Epoch 78/100
# 983/983 - 3s - loss: 4.2656e-04 - 3s/epoch - 3ms/step
# Epoch 79/100
# 983/983 - 3s - loss: 4.3652e-04 - 3s/epoch - 3ms/step
# Epoch 80/100
# 983/983 - 3s - loss: 4.1444e-04 - 3s/epoch - 3ms/step
# Epoch 81/100
# 983/983 - 3s - loss: 4.3689e-04 - 3s/epoch - 3ms/step
# Epoch 82/100
# 983/983 - 2s - loss: 4.1692e-04 - 2s/epoch - 3ms/step
# Epoch 83/100
# 983/983 - 3s - loss: 4.3555e-04 - 3s/epoch - 3ms/step
# Epoch 84/100
# 983/983 - 3s - loss: 4.3361e-04 - 3s/epoch - 3ms/step
# Epoch 85/100
# 983/983 - 3s - loss: 4.3294e-04 - 3s/epoch - 3ms/step
# Epoch 86/100
# 983/983 - 2s - loss: 4.1886e-04 - 2s/epoch - 3ms/step
# Epoch 87/100
# 983/983 - 3s - loss: 4.3440e-04 - 3s/epoch - 3ms/step
# Epoch 88/100
# 983/983 - 3s - loss: 4.2435e-04 - 3s/epoch - 4ms/step
# Epoch 89/100
# 983/983 - 3s - loss: 4.1762e-04 - 3s/epoch - 3ms/step
# Epoch 90/100
# 983/983 - 3s - loss: 4.2933e-04 - 3s/epoch - 3ms/step
# Epoch 91/100
# 983/983 - 3s - loss: 4.1445e-04 - 3s/epoch - 3ms/step
# Epoch 92/100
# 983/983 - 3s - loss: 4.3224e-04 - 3s/epoch - 3ms/step
# Epoch 93/100
# 983/983 - 4s - loss: 4.0994e-04 - 4s/epoch - 4ms/step
# Epoch 94/100
# 983/983 - 3s - loss: 4.2454e-04 - 3s/epoch - 3ms/step
# Epoch 95/100
# 983/983 - 3s - loss: 3.9835e-04 - 3s/epoch - 3ms/step
# Epoch 96/100
# 983/983 - 3s - loss: 4.2750e-04 - 3s/epoch - 3ms/step
# Epoch 97/100
# 983/983 - 3s - loss: 4.2492e-04 - 3s/epoch - 3ms/step
# Epoch 98/100
# 983/983 - 4s - loss: 4.4116e-04 - 4s/epoch - 4ms/step
# Epoch 99/100
# 983/983 - 2s - loss: 4.2341e-04 - 2s/epoch - 3ms/step
# Epoch 100/100
# 983/983 - 3s - loss: 4.2248e-04 - 3s/epoch - 3ms/step

# %%
# Gộp các dự đoán từ LSR và GRU
X_meta_train = np.column_stack((lasso.predict(X_train), gru_model.predict(X_train_gru).flatten()))
X_meta_test = np.column_stack((lasso.predict(X_test), gru_model.predict(X_test_gru).flatten()))
# Out:
# 31/31 [==============================] - 1s 2ms/step
# 8/8 [==============================] - 0s 3ms/step

# %%
# Huấn luyện meta-learner
from sklearn.linear_model import LinearRegression
meta_model = LinearRegression()
meta_model.fit(X_meta_train, Y_train)

# Sử dụng meta-learner để dự đoán
ensemble_pred = meta_model.predict(X_meta_test)
ensemble_pred = scaler.inverse_transform(ensemble_pred.reshape(-1, 1))

# %%
future_steps = 30  # Định nghĩa số ngày dự đoán tương lai

# Dự đoán cho 30 ngày tiếp theo
ensemble_future_pred = []
last_window = scaled_data[-look_back:]  # Cập nhật last_window cho bước thời gian cuối cùng của dữ liệu

for i in range(future_steps):
    # Chuẩn bị dữ liệu cho mỗi bước thời gian trong tương lai
    last_window_gru = np.reshape(last_window, (1, 1, look_back))
    lasso_future_pred = lasso.predict(last_window)
    gru_future_pred = gru_model.predict(last_window_gru).flatten()
    X_meta_future = np.column_stack((lasso_future_pred, gru_future_pred))

    # Dự đoán sử dụng meta-learner
    future_pred = meta_model.predict(X_meta_future)
    ensemble_future_pred.append(future_pred[0])

    # Cập nhật last_window cho bước tiếp theo
    last_window = np.append(last_window[1:], future_pred)[np.newaxis]

ensemble_future_pred = scaler.inverse_transform(np.array(ensemble_future_pred).reshape(-1, 1))
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
# Adjusting index for plotting
last_index = df.index[-1]
future_index = range(last_index + 1, last_index + future_steps + 1)

# %%
# Vẽ đồ thị
plt.figure(figsize=(15,8))
plt.plot(df.index[:train_size], scaler.inverse_transform(scaled_data[:train_size]), label='Train')
plt.plot(df.index[train_size:train_size+len(Y_test)], scaler.inverse_transform(scaled_data[train_size:train_size+len(Y_test)]), label='Test')
plt.plot(df.index[train_size:train_size+len(ensemble_pred)], ensemble_pred, label='Ensemble Prediction on Test Data')
plt.plot(future_index, ensemble_future_pred, label='Ensemble Future Prediction Next 30 Days')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error,mean_absolute_error
# 7. Đánh giá độ chính xác test bằng RMSE, MAE , MAPE
# RMSE
test_rmse = np.sqrt(np.mean((ensemble_pred - Y_test)**2))
print('Testing RMSE:', test_rmse)
# MAPE
test_mape = mean_absolute_percentage_error(Y_test,ensemble_pred)
print('Testing MAPE:', test_mape)
# MAE
test_mae = mean_absolute_error(Y_test,ensemble_pred)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 66781.71607438449
# Testing MAPE: 124109.548235763
# Testing MAE: 66622.97033373748
