# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import Lasso
from sklearn.ensemble import GradientBoostingRegressor
from keras.models import Sequential
from keras.layers import GRU, Dense
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# Đọc dữ liệu
df = pd.read_csv('/content/sample_data/NOK.csv')
#df = pd.read_csv('AAPL.csv', header=0, parse_dates=[0], index_col=0)
df = df[['Close']].dropna().reset_index(drop=True)

df.head()
# Out:
#    Close
# 0   6.04
# 1   6.03
# 2   5.94
# 3   5.87
# 4   5.78

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Chia tập train-test
train_size = int(0.8 * len(df))
test_size = len(df) - train_size
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# %%
# Scaling data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# Function to create dataset for model
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 1
X_train, Y_train = create_dataset(scaled_data[:train_size], look_back)
X_test, Y_test = create_dataset(scaled_data[train_size:], look_back)

# Reshape input to be [samples, time steps, features] for GRU
X_train_gru = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test_gru = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
# Lasso model
lasso = Lasso(alpha=0.01)
lasso.fit(X_train, Y_train)
# Out:
# Lasso(alpha=0.01)

# %%
# GRU model
gru_model = Sequential()
gru_model.add(GRU(units=50, return_sequences=True, input_shape=(1, look_back)))
gru_model.add(GRU(units=50))
gru_model.add(Dense(1))
gru_model.compile(loss='mean_squared_error', optimizer='adam')
gru_model.fit(X_train_gru, Y_train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 1004/1004 - 6s - loss: 0.0083 - 6s/epoch - 6ms/step
# Epoch 2/100
# 1004/1004 - 4s - loss: 0.0017 - 4s/epoch - 4ms/step
# Epoch 3/100
# 1004/1004 - 4s - loss: 0.0016 - 4s/epoch - 4ms/step
# Epoch 4/100
# 1004/1004 - 3s - loss: 0.0017 - 3s/epoch - 3ms/step
# Epoch 5/100
# 1004/1004 - 2s - loss: 0.0017 - 2s/epoch - 2ms/step
# Epoch 6/100
# 1004/1004 - 3s - loss: 0.0016 - 3s/epoch - 3ms/step
# Epoch 7/100
# 1004/1004 - 3s - loss: 0.0016 - 3s/epoch - 3ms/step
# Epoch 8/100
# 1004/1004 - 3s - loss: 0.0015 - 3s/epoch - 3ms/step
# Epoch 9/100
# 1004/1004 - 3s - loss: 0.0017 - 3s/epoch - 3ms/step
# Epoch 10/100
# 1004/1004 - 3s - loss: 0.0018 - 3s/epoch - 3ms/step
# Epoch 11/100
# 1004/1004 - 4s - loss: 0.0015 - 4s/epoch - 4ms/step
# Epoch 12/100
# 1004/1004 - 3s - loss: 0.0016 - 3s/epoch - 3ms/step
# Epoch 13/100
# 1004/1004 - 3s - loss: 0.0016 - 3s/epoch - 3ms/step
# Epoch 14/100
# 1004/1004 - 3s - loss: 0.0015 - 3s/epoch - 3ms/step
# Epoch 15/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 16/100
# 1004/1004 - 4s - loss: 0.0015 - 4s/epoch - 4ms/step
# Epoch 17/100
# 1004/1004 - 3s - loss: 0.0015 - 3s/epoch - 3ms/step
# Epoch 18/100
# 1004/1004 - 3s - loss: 0.0015 - 3s/epoch - 3ms/step
# Epoch 19/100
# 1004/1004 - 3s - loss: 0.0015 - 3s/epoch - 3ms/step
# Epoch 20/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 21/100
# 1004/1004 - 3s - loss: 0.0015 - 3s/epoch - 3ms/step
# Epoch 22/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 23/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 2ms/step
# Epoch 24/100
# 1004/1004 - 3s - loss: 0.0015 - 3s/epoch - 3ms/step
# Epoch 25/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 26/100
# 1004/1004 - 3s - loss: 0.0015 - 3s/epoch - 3ms/step
# Epoch 27/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 2ms/step
# Epoch 28/100
# 1004/1004 - 3s - loss: 0.0015 - 3s/epoch - 3ms/step
# Epoch 29/100
# 1004/1004 - 2s - loss: 0.0014 - 2s/epoch - 2ms/step
# Epoch 30/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 31/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 32/100
# 1004/1004 - 2s - loss: 0.0014 - 2s/epoch - 2ms/step
# Epoch 33/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 34/100
# 1004/1004 - 4s - loss: 0.0014 - 4s/epoch - 4ms/step
# Epoch 35/100
# 1004/1004 - 4s - loss: 0.0014 - 4s/epoch - 4ms/step
# Epoch 36/100
# 1004/1004 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 37/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 38/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 39/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 40/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 41/100
# 1004/1004 - 2s - loss: 0.0014 - 2s/epoch - 2ms/step
# Epoch 42/100
# 1004/1004 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 43/100
# 1004/1004 - 2s - loss: 0.0014 - 2s/epoch - 2ms/step
# Epoch 44/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 45/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 46/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 47/100
# 1004/1004 - 4s - loss: 0.0014 - 4s/epoch - 4ms/step
# Epoch 48/100
# 1004/1004 - 4s - loss: 0.0014 - 4s/epoch - 4ms/step
# Epoch 49/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 50/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 51/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 2ms/step
# Epoch 52/100
# 1004/1004 - 2s - loss: 0.0014 - 2s/epoch - 2ms/step
# Epoch 53/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 54/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 55/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 56/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 57/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 58/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 59/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 60/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 2ms/step
# Epoch 61/100
# 1004/1004 - 2s - loss: 0.0014 - 2s/epoch - 2ms/step
# Epoch 62/100
# 1004/1004 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 63/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 64/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 65/100
# 1004/1004 - 2s - loss: 0.0014 - 2s/epoch - 2ms/step
# Epoch 66/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 67/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 68/100
# 1004/1004 - 4s - loss: 0.0013 - 4s/epoch - 4ms/step
# Epoch 69/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 70/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 71/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 72/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 73/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 74/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 75/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 76/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 77/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 78/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 79/100
# 1004/1004 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 80/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 81/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 82/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 83/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 84/100
# 1004/1004 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 85/100
# 1004/1004 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 86/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 87/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 88/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 89/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 90/100
# 1004/1004 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 91/100
# 1004/1004 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 92/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 93/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 94/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 2ms/step
# Epoch 95/100
# 1004/1004 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 96/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 2ms/step
# Epoch 97/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step
# Epoch 98/100
# 1004/1004 - 3s - loss: 0.0014 - 3s/epoch - 3ms/step
# Epoch 99/100
# 1004/1004 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 100/100
# 1004/1004 - 3s - loss: 0.0013 - 3s/epoch - 3ms/step

# %%
# Gộp các dự đoán từ LSR và GRU
X_meta_train = np.column_stack((lasso.predict(X_train), gru_model.predict(X_train_gru).flatten()))
X_meta_test = np.column_stack((lasso.predict(X_test), gru_model.predict(X_test_gru).flatten()))
# Out:
# 32/32 [==============================] - 1s 2ms/step
# 8/8 [==============================] - 0s 3ms/step

# %%
# Huấn luyện meta-learner
from sklearn.linear_model import LinearRegression
meta_model = LinearRegression()
meta_model.fit(X_meta_train, Y_train)

# Sử dụng meta-learner để dự đoán
ensemble_pred = meta_model.predict(X_meta_test)
ensemble_pred = scaler.inverse_transform(ensemble_pred.reshape(-1, 1))

# %%
future_steps = 30  # Định nghĩa số ngày dự đoán tương lai

# Dự đoán cho 30 ngày tiếp theo
ensemble_future_pred = []
last_window = scaled_data[-look_back:]  # Cập nhật last_window cho bước thời gian cuối cùng của dữ liệu

for i in range(future_steps):
    # Chuẩn bị dữ liệu cho mỗi bước thời gian trong tương lai
    last_window_gru = np.reshape(last_window, (1, 1, look_back))
    lasso_future_pred = lasso.predict(last_window)
    gru_future_pred = gru_model.predict(last_window_gru).flatten()
    X_meta_future = np.column_stack((lasso_future_pred, gru_future_pred))

    # Dự đoán sử dụng meta-learner
    future_pred = meta_model.predict(X_meta_future)
    ensemble_future_pred.append(future_pred[0])

    # Cập nhật last_window cho bước tiếp theo
    last_window = np.append(last_window[1:], future_pred)[np.newaxis]

ensemble_future_pred = scaler.inverse_transform(np.array(ensemble_future_pred).reshape(-1, 1))
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
# Adjusting index for plotting
last_index = df.index[-1]
future_index = range(last_index + 1, last_index + future_steps + 1)

# %%
# Vẽ đồ thị
plt.figure(figsize=(15,8))
plt.plot(df.index[:train_size], scaler.inverse_transform(scaled_data[:train_size]), label='Train')
plt.plot(df.index[train_size:train_size+len(Y_test)], scaler.inverse_transform(scaled_data[train_size:train_size+len(Y_test)]), label='Test')
plt.plot(df.index[train_size:train_size+len(ensemble_pred)], ensemble_pred, label='Ensemble Prediction on Test Data')
plt.plot(future_index, ensemble_future_pred, label='Ensemble Future Prediction Next 30 Days')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error,mean_absolute_error
# 7. Đánh giá độ chính xác test bằng RMSE, MAE , MAPE
# RMSE
test_rmse = np.sqrt(np.mean((ensemble_pred - Y_test)**2))
print('Testing RMSE:', test_rmse)
# MAPE
test_mape = mean_absolute_percentage_error(Y_test,ensemble_pred)
print('Testing MAPE:', test_mape)
# MAE
test_mae = mean_absolute_error(Y_test,ensemble_pred)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 3.7816895872895797
# Testing MAPE: 9.724610511482444
# Testing MAE: 3.7466659737442134
