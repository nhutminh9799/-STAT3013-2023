# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import Lasso
from sklearn.ensemble import GradientBoostingRegressor
from keras.models import Sequential
from keras.layers import GRU, Dense
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# Đọc dữ liệu
df = pd.read_csv('/content/sample_data/SamSung.csv')
#df = pd.read_csv('AAPL.csv', header=0, parse_dates=[0], index_col=0)
df = df[['Close']].dropna().reset_index(drop=True)

df.head()
# Out:
#      Close
# 0  40450.0
# 1  40000.0
# 2  38950.0
# 3  39150.0
# 4  38900.0

# %%
# Chia tập train-test
train_size = int(0.7 * len(df))
test_size = len(df) - train_size
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# %%
# Scaling data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# Function to create dataset for model
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 1
X_train, Y_train = create_dataset(scaled_data[:train_size], look_back)
X_test, Y_test = create_dataset(scaled_data[train_size:], look_back)

# Reshape input to be [samples, time steps, features] for GRU
X_train_gru = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test_gru = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
# Lasso model
lasso = Lasso(alpha=0.01)
lasso.fit(X_train, Y_train)
# Out:
# Lasso(alpha=0.01)

# %%
# GRU model
gru_model = Sequential()
gru_model.add(GRU(units=50, return_sequences=True, input_shape=(1, look_back)))
gru_model.add(GRU(units=50))
gru_model.add(Dense(1))
gru_model.compile(loss='mean_squared_error', optimizer='adam')
gru_model.fit(X_train_gru, Y_train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 860/860 - 5s - loss: 0.0079 - 5s/epoch - 6ms/step
# Epoch 2/100
# 860/860 - 2s - loss: 5.6089e-04 - 2s/epoch - 3ms/step
# Epoch 3/100
# 860/860 - 2s - loss: 5.5653e-04 - 2s/epoch - 3ms/step
# Epoch 4/100
# 860/860 - 3s - loss: 5.7824e-04 - 3s/epoch - 4ms/step
# Epoch 5/100
# 860/860 - 2s - loss: 6.3719e-04 - 2s/epoch - 3ms/step
# Epoch 6/100
# 860/860 - 2s - loss: 5.8419e-04 - 2s/epoch - 3ms/step
# Epoch 7/100
# 860/860 - 2s - loss: 5.9013e-04 - 2s/epoch - 3ms/step
# Epoch 8/100
# 860/860 - 2s - loss: 5.4848e-04 - 2s/epoch - 3ms/step
# Epoch 9/100
# 860/860 - 3s - loss: 5.5888e-04 - 3s/epoch - 3ms/step
# Epoch 10/100
# 860/860 - 3s - loss: 4.8603e-04 - 3s/epoch - 3ms/step
# Epoch 11/100
# 860/860 - 2s - loss: 5.1005e-04 - 2s/epoch - 3ms/step
# Epoch 12/100
# 860/860 - 2s - loss: 5.4848e-04 - 2s/epoch - 3ms/step
# Epoch 13/100
# 860/860 - 2s - loss: 6.1079e-04 - 2s/epoch - 3ms/step
# Epoch 14/100
# 860/860 - 2s - loss: 5.4717e-04 - 2s/epoch - 3ms/step
# Epoch 15/100
# 860/860 - 5s - loss: 5.1897e-04 - 5s/epoch - 5ms/step
# Epoch 16/100
# 860/860 - 2s - loss: 5.4914e-04 - 2s/epoch - 3ms/step
# Epoch 17/100
# 860/860 - 2s - loss: 5.5697e-04 - 2s/epoch - 3ms/step
# Epoch 18/100
# 860/860 - 2s - loss: 5.0182e-04 - 2s/epoch - 3ms/step
# Epoch 19/100
# 860/860 - 2s - loss: 5.2422e-04 - 2s/epoch - 3ms/step
# Epoch 20/100
# 860/860 - 3s - loss: 5.4291e-04 - 3s/epoch - 3ms/step
# Epoch 21/100
# 860/860 - 3s - loss: 5.1987e-04 - 3s/epoch - 3ms/step
# Epoch 22/100
# 860/860 - 2s - loss: 5.4323e-04 - 2s/epoch - 3ms/step
# Epoch 23/100
# 860/860 - 2s - loss: 5.1564e-04 - 2s/epoch - 3ms/step
# Epoch 24/100
# 860/860 - 2s - loss: 5.1795e-04 - 2s/epoch - 3ms/step
# Epoch 25/100
# 860/860 - 2s - loss: 4.9733e-04 - 2s/epoch - 3ms/step
# Epoch 26/100
# 860/860 - 3s - loss: 4.6575e-04 - 3s/epoch - 4ms/step
# Epoch 27/100
# 860/860 - 2s - loss: 4.9987e-04 - 2s/epoch - 3ms/step
# Epoch 28/100
# 860/860 - 2s - loss: 4.7059e-04 - 2s/epoch - 3ms/step
# Epoch 29/100
# 860/860 - 2s - loss: 4.9012e-04 - 2s/epoch - 3ms/step
# Epoch 30/100
# 860/860 - 2s - loss: 4.6262e-04 - 2s/epoch - 3ms/step
# Epoch 31/100
# 860/860 - 3s - loss: 4.8974e-04 - 3s/epoch - 3ms/step
# Epoch 32/100
# 860/860 - 3s - loss: 5.3303e-04 - 3s/epoch - 3ms/step
# Epoch 33/100
# 860/860 - 2s - loss: 4.9455e-04 - 2s/epoch - 3ms/step
# Epoch 34/100
# 860/860 - 2s - loss: 4.4933e-04 - 2s/epoch - 3ms/step
# Epoch 35/100
# 860/860 - 2s - loss: 4.7161e-04 - 2s/epoch - 3ms/step
# Epoch 36/100
# 860/860 - 2s - loss: 4.7830e-04 - 2s/epoch - 3ms/step
# Epoch 37/100
# 860/860 - 3s - loss: 4.4631e-04 - 3s/epoch - 4ms/step
# Epoch 38/100
# 860/860 - 2s - loss: 4.8666e-04 - 2s/epoch - 3ms/step
# Epoch 39/100
# 860/860 - 2s - loss: 4.2779e-04 - 2s/epoch - 3ms/step
# Epoch 40/100
# 860/860 - 2s - loss: 4.6498e-04 - 2s/epoch - 3ms/step
# Epoch 41/100
# 860/860 - 2s - loss: 4.7866e-04 - 2s/epoch - 3ms/step
# Epoch 42/100
# 860/860 - 3s - loss: 4.7121e-04 - 3s/epoch - 3ms/step
# Epoch 43/100
# 860/860 - 3s - loss: 4.8078e-04 - 3s/epoch - 3ms/step
# Epoch 44/100
# 860/860 - 2s - loss: 4.6215e-04 - 2s/epoch - 3ms/step
# Epoch 45/100
# 860/860 - 2s - loss: 4.9120e-04 - 2s/epoch - 3ms/step
# Epoch 46/100
# 860/860 - 2s - loss: 4.7556e-04 - 2s/epoch - 3ms/step
# Epoch 47/100
# 860/860 - 2s - loss: 4.3886e-04 - 2s/epoch - 3ms/step
# Epoch 48/100
# 860/860 - 3s - loss: 4.4760e-04 - 3s/epoch - 4ms/step
# Epoch 49/100
# 860/860 - 2s - loss: 5.3252e-04 - 2s/epoch - 3ms/step
# Epoch 50/100
# 860/860 - 2s - loss: 4.3552e-04 - 2s/epoch - 3ms/step
# Epoch 51/100
# 860/860 - 2s - loss: 4.3370e-04 - 2s/epoch - 3ms/step
# Epoch 52/100
# 860/860 - 2s - loss: 4.5971e-04 - 2s/epoch - 3ms/step
# Epoch 53/100
# 860/860 - 3s - loss: 4.7643e-04 - 3s/epoch - 3ms/step
# Epoch 54/100
# 860/860 - 3s - loss: 4.5608e-04 - 3s/epoch - 3ms/step
# Epoch 55/100
# 860/860 - 2s - loss: 4.4958e-04 - 2s/epoch - 3ms/step
# Epoch 56/100
# 860/860 - 2s - loss: 4.7336e-04 - 2s/epoch - 3ms/step
# Epoch 57/100
# 860/860 - 2s - loss: 4.4590e-04 - 2s/epoch - 3ms/step
# Epoch 58/100
# 860/860 - 2s - loss: 4.7273e-04 - 2s/epoch - 3ms/step
# Epoch 59/100
# 860/860 - 3s - loss: 4.4018e-04 - 3s/epoch - 4ms/step
# Epoch 60/100
# 860/860 - 2s - loss: 4.4385e-04 - 2s/epoch - 3ms/step
# Epoch 61/100
# 860/860 - 2s - loss: 4.3569e-04 - 2s/epoch - 2ms/step
# Epoch 62/100
# 860/860 - 2s - loss: 4.4372e-04 - 2s/epoch - 3ms/step
# Epoch 63/100
# 860/860 - 2s - loss: 4.1780e-04 - 2s/epoch - 3ms/step
# Epoch 64/100
# 860/860 - 3s - loss: 4.2642e-04 - 3s/epoch - 3ms/step
# Epoch 65/100
# 860/860 - 3s - loss: 4.1990e-04 - 3s/epoch - 3ms/step
# Epoch 66/100
# 860/860 - 2s - loss: 4.0970e-04 - 2s/epoch - 3ms/step
# Epoch 67/100
# 860/860 - 2s - loss: 4.5425e-04 - 2s/epoch - 3ms/step
# Epoch 68/100
# 860/860 - 2s - loss: 4.3422e-04 - 2s/epoch - 3ms/step
# Epoch 69/100
# 860/860 - 2s - loss: 4.6901e-04 - 2s/epoch - 3ms/step
# Epoch 70/100
# 860/860 - 3s - loss: 4.5460e-04 - 3s/epoch - 3ms/step
# Epoch 71/100
# 860/860 - 3s - loss: 4.2641e-04 - 3s/epoch - 3ms/step
# Epoch 72/100
# 860/860 - 2s - loss: 4.5247e-04 - 2s/epoch - 3ms/step
# Epoch 73/100
# 860/860 - 2s - loss: 4.3633e-04 - 2s/epoch - 3ms/step
# Epoch 74/100
# 860/860 - 2s - loss: 4.5267e-04 - 2s/epoch - 3ms/step
# Epoch 75/100
# 860/860 - 2s - loss: 4.6079e-04 - 2s/epoch - 3ms/step
# Epoch 76/100
# 860/860 - 3s - loss: 4.5116e-04 - 3s/epoch - 4ms/step
# Epoch 77/100
# 860/860 - 2s - loss: 4.4446e-04 - 2s/epoch - 3ms/step
# Epoch 78/100
# 860/860 - 2s - loss: 4.1996e-04 - 2s/epoch - 3ms/step
# Epoch 79/100
# 860/860 - 2s - loss: 4.2597e-04 - 2s/epoch - 3ms/step
# Epoch 80/100
# 860/860 - 2s - loss: 4.5612e-04 - 2s/epoch - 3ms/step
# Epoch 81/100
# 860/860 - 3s - loss: 4.3318e-04 - 3s/epoch - 3ms/step
# Epoch 82/100
# 860/860 - 3s - loss: 4.4103e-04 - 3s/epoch - 3ms/step
# Epoch 83/100
# 860/860 - 2s - loss: 4.2041e-04 - 2s/epoch - 3ms/step
# Epoch 84/100
# 860/860 - 2s - loss: 4.2929e-04 - 2s/epoch - 3ms/step
# Epoch 85/100
# 860/860 - 2s - loss: 4.1957e-04 - 2s/epoch - 3ms/step
# Epoch 86/100
# 860/860 - 2s - loss: 4.4514e-04 - 2s/epoch - 3ms/step
# Epoch 87/100
# 860/860 - 3s - loss: 4.3906e-04 - 3s/epoch - 4ms/step
# Epoch 88/100
# 860/860 - 2s - loss: 4.2975e-04 - 2s/epoch - 3ms/step
# Epoch 89/100
# 860/860 - 2s - loss: 4.2320e-04 - 2s/epoch - 3ms/step
# Epoch 90/100
# 860/860 - 2s - loss: 4.2016e-04 - 2s/epoch - 3ms/step
# Epoch 91/100
# 860/860 - 2s - loss: 4.3222e-04 - 2s/epoch - 3ms/step
# Epoch 92/100
# 860/860 - 3s - loss: 4.3403e-04 - 3s/epoch - 3ms/step
# Epoch 93/100
# 860/860 - 3s - loss: 4.1659e-04 - 3s/epoch - 3ms/step
# Epoch 94/100
# 860/860 - 2s - loss: 4.3930e-04 - 2s/epoch - 3ms/step
# Epoch 95/100
# 860/860 - 2s - loss: 4.2554e-04 - 2s/epoch - 3ms/step
# Epoch 96/100
# 860/860 - 2s - loss: 4.6635e-04 - 2s/epoch - 3ms/step
# Epoch 97/100
# 860/860 - 2s - loss: 4.3720e-04 - 2s/epoch - 3ms/step
# Epoch 98/100
# 860/860 - 3s - loss: 4.2354e-04 - 3s/epoch - 4ms/step
# Epoch 99/100
# 860/860 - 2s - loss: 4.6042e-04 - 2s/epoch - 3ms/step
# Epoch 100/100
# 860/860 - 2s - loss: 4.4022e-04 - 2s/epoch - 3ms/step

# %%
# Gộp các dự đoán từ LSR và GRU
X_meta_train = np.column_stack((lasso.predict(X_train), gru_model.predict(X_train_gru).flatten()))
X_meta_test = np.column_stack((lasso.predict(X_test), gru_model.predict(X_test_gru).flatten()))
# Out:
# 27/27 [==============================] - 1s 2ms/step
# 12/12 [==============================] - 0s 2ms/step

# %%
# Huấn luyện meta-learner
from sklearn.linear_model import LinearRegression
meta_model = LinearRegression()
meta_model.fit(X_meta_train, Y_train)

# Sử dụng meta-learner để dự đoán
ensemble_pred = meta_model.predict(X_meta_test)
ensemble_pred = scaler.inverse_transform(ensemble_pred.reshape(-1, 1))

# %%
future_steps = 30  # Định nghĩa số ngày dự đoán tương lai

# Dự đoán cho 30 ngày tiếp theo
ensemble_future_pred = []
last_window = scaled_data[-look_back:]  # Cập nhật last_window cho bước thời gian cuối cùng của dữ liệu

for i in range(future_steps):
    # Chuẩn bị dữ liệu cho mỗi bước thời gian trong tương lai
    last_window_gru = np.reshape(last_window, (1, 1, look_back))
    lasso_future_pred = lasso.predict(last_window)
    gru_future_pred = gru_model.predict(last_window_gru).flatten()
    X_meta_future = np.column_stack((lasso_future_pred, gru_future_pred))

    # Dự đoán sử dụng meta-learner
    future_pred = meta_model.predict(X_meta_future)
    ensemble_future_pred.append(future_pred[0])

    # Cập nhật last_window cho bước tiếp theo
    last_window = np.append(last_window[1:], future_pred)[np.newaxis]

ensemble_future_pred = scaler.inverse_transform(np.array(ensemble_future_pred).reshape(-1, 1))
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 52ms/step

# %%
# Adjusting index for plotting
last_index = df.index[-1]
future_index = range(last_index + 1, last_index + future_steps + 1)

# %%
# Vẽ đồ thị
plt.figure(figsize=(15,8))
plt.plot(df.index[:train_size], scaler.inverse_transform(scaled_data[:train_size]), label='Train')
plt.plot(df.index[train_size:train_size+len(Y_test)], scaler.inverse_transform(scaled_data[train_size:train_size+len(Y_test)]), label='Test')
plt.plot(df.index[train_size:train_size+len(ensemble_pred)], ensemble_pred, label='Ensemble Prediction on Test Data')
plt.plot(future_index, ensemble_future_pred, label='Ensemble Future Prediction Next 30 Days')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error,mean_absolute_error
# 7. Đánh giá độ chính xác test bằng RMSE, MAE , MAPE
# RMSE
test_rmse = np.sqrt(np.mean((ensemble_pred - Y_test)**2))
print('Testing RMSE:', test_rmse)
# MAPE
test_mape = mean_absolute_percentage_error(Y_test,ensemble_pred)
print('Testing MAPE:', test_mape)
# MAE
test_mae = mean_absolute_error(Y_test,ensemble_pred)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 64248.25283648526
# Testing MAPE: 132365.8977179913
# Testing MAE: 64017.012585850374
