# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('/content/drive/MyDrive/StockData/Apple.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-12-12   42.599998   42.980000   42.255001   42.275002   40.576008
# 1     2018-12-13   42.622501   43.142502   42.387501   42.737499   41.019917
# 2     2018-12-14   42.250000   42.270000   41.320000   41.369999   39.707371
# 3     2018-12-17   41.362499   42.087502   40.682499   40.985001   39.337845
# 4     2018-12-18   41.345001   41.882500   41.097500   41.517502   39.848946
# ...          ...         ...         ...         ...         ...         ...
# 1253  2023-12-05  190.210007  194.399994  190.179993  193.419998  193.419998
# 1254  2023-12-06  194.449997  194.759995  192.110001  192.320007  192.320007
# 1255  2023-12-07  193.630005  195.000000  193.589996  194.270004  194.270004
# 1256  2023-12-08  194.199997  195.990005  193.669998  195.710007  195.710007
# 1257  2023-12-11  193.110001  193.490005  191.419998  193.179993  193.179993
#
#          Volume
# 0     142510800
# 1     127594400
# 2     162814800
# 3     177151600
# 4     135366000
# ...         ...
# 1253   66628400
# 1254   41089700
# 1255   47477700
# 1256   53377300
# 1257   60943700
#
# [1258 rows x 7 columns]

# %%
df1=df.reset_index()['Close']
df1 = df1.dropna() #clean data
df1
# Out:
# 0        42.275002
# 1        42.737499
# 2        41.369999
# 3        40.985001
# 4        41.517502
#            ...
# 1253    193.419998
# 1254    192.320007
# 1255    194.270004
# 1256    195.710007
# 1257    193.179993
# Name: Close, Length: 1258, dtype: float64

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.9 * len(df1))
test_size = int(0.1 * len(df1))

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 \n",
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 3
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape)
# Out:
# (1128, 3, 1) (122, 3, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, LSTM #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import MeanSquaredError

#import cac metrics nhu mse,mae,rmse
from tensorflow.keras import metrics

#import cac loss function nhu mse,mae,rmse,mape
from tensorflow.keras import losses

# Tạo model
model = Sequential()

input_shape = (time_step, 1)
model.add(LSTM(64, input_shape=input_shape, return_sequences=True))
model.add(LSTM(32, input_shape=input_shape, return_sequences=True))
model.add(LSTM(16))


model.add(Dense(5))
model.add(Dropout(0.2))

model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics
model.compile (loss= "mean_squared_error", optimizer=Adam(learning_rate=0.0001), metrics="mean_squared_error")
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=50, restore_best_weights=True)

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=200,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/200
# 18/18 [==============================] - 17s 142ms/step - loss: 0.2957 - mean_squared_error: 0.2957 - val_loss: 0.7501 - val_mean_squared_error: 0.7501
# Epoch 2/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.2581 - mean_squared_error: 0.2581 - val_loss: 0.6693 - val_mean_squared_error: 0.6693
# Epoch 3/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.2242 - mean_squared_error: 0.2242 - val_loss: 0.5892 - val_mean_squared_error: 0.5892
# Epoch 4/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.1900 - mean_squared_error: 0.1900 - val_loss: 0.5073 - val_mean_squared_error: 0.5073
# Epoch 5/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.1590 - mean_squared_error: 0.1590 - val_loss: 0.4252 - val_mean_squared_error: 0.4252
# Epoch 6/200
# 18/18 [==============================] - 0s 20ms/step - loss: 0.1254 - mean_squared_error: 0.1254 - val_loss: 0.3414 - val_mean_squared_error: 0.3414
# Epoch 7/200
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0954 - mean_squared_error: 0.0954 - val_loss: 0.2589 - val_mean_squared_error: 0.2589
# Epoch 8/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0708 - mean_squared_error: 0.0708 - val_loss: 0.1844 - val_mean_squared_error: 0.1844
# Epoch 9/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0568 - mean_squared_error: 0.0568 - val_loss: 0.1231 - val_mean_squared_error: 0.1231
# Epoch 10/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0434 - mean_squared_error: 0.0434 - val_loss: 0.0789 - val_mean_squared_error: 0.0789
# Epoch 11/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0375 - mean_squared_error: 0.0375 - val_loss: 0.0545 - val_mean_squared_error: 0.0545
# Epoch 12/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.0433 - val_mean_squared_error: 0.0433
# Epoch 13/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0341 - mean_squared_error: 0.0341 - val_loss: 0.0393 - val_mean_squared_error: 0.0393
# Epoch 14/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0373 - val_mean_squared_error: 0.0373
# Epoch 15/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.0326 - val_mean_squared_error: 0.0326
# Epoch 16/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0292 - mean_squared_error: 0.0292 - val_loss: 0.0298 - val_mean_squared_error: 0.0298
# Epoch 17/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0286 - mean_squared_error: 0.0286 - val_loss: 0.0270 - val_mean_squared_error: 0.0270
# Epoch 18/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.0238 - val_mean_squared_error: 0.0238
# Epoch 19/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 20/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0245 - mean_squared_error: 0.0245 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 21/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0151 - val_mean_squared_error: 0.0151
# Epoch 22/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0132 - val_mean_squared_error: 0.0132
# Epoch 23/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.0108 - val_mean_squared_error: 0.0108
# Epoch 24/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0094 - val_mean_squared_error: 0.0094
# Epoch 25/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 26/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 27/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 28/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 29/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 30/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 31/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 32/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 33/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 34/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 35/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 36/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 8.2266e-04 - val_mean_squared_error: 8.2266e-04
# Epoch 37/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 6.6436e-04 - val_mean_squared_error: 6.6436e-04
# Epoch 38/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 7.4757e-04 - val_mean_squared_error: 7.4757e-04
# Epoch 39/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 7.9695e-04 - val_mean_squared_error: 7.9695e-04
# Epoch 40/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 6.7625e-04 - val_mean_squared_error: 6.7625e-04
# Epoch 41/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 6.8262e-04 - val_mean_squared_error: 6.8262e-04
# Epoch 42/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 7.0479e-04 - val_mean_squared_error: 7.0479e-04
# Epoch 43/200
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 7.0683e-04 - val_mean_squared_error: 7.0683e-04
# Epoch 44/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 6.9310e-04 - val_mean_squared_error: 6.9310e-04
# Epoch 45/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 6.9996e-04 - val_mean_squared_error: 6.9996e-04
# Epoch 46/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 8.0433e-04 - val_mean_squared_error: 8.0433e-04
# Epoch 47/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 8.1120e-04 - val_mean_squared_error: 8.1120e-04
# Epoch 48/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 7.2556e-04 - val_mean_squared_error: 7.2556e-04
# Epoch 49/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 8.5904e-04 - val_mean_squared_error: 8.5904e-04
# Epoch 50/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 6.9786e-04 - val_mean_squared_error: 6.9786e-04
# Epoch 51/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 7.0137e-04 - val_mean_squared_error: 7.0137e-04
# Epoch 52/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 7.0941e-04 - val_mean_squared_error: 7.0941e-04
# Epoch 53/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 7.0335e-04 - val_mean_squared_error: 7.0335e-04
# Epoch 54/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 6.9515e-04 - val_mean_squared_error: 6.9515e-04
# Epoch 55/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 8.6057e-04 - val_mean_squared_error: 8.6057e-04
# Epoch 56/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 8.4827e-04 - val_mean_squared_error: 8.4827e-04
# Epoch 57/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 6.9506e-04 - val_mean_squared_error: 6.9506e-04
# Epoch 58/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 8.1081e-04 - val_mean_squared_error: 8.1081e-04
# Epoch 59/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 9.8557e-04 - val_mean_squared_error: 9.8557e-04
# Epoch 60/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 6.9431e-04 - val_mean_squared_error: 6.9431e-04
# Epoch 61/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 7.1163e-04 - val_mean_squared_error: 7.1163e-04
# Epoch 62/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 7.9297e-04 - val_mean_squared_error: 7.9297e-04
# Epoch 63/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 8.7145e-04 - val_mean_squared_error: 8.7145e-04
# Epoch 64/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 7.4403e-04 - val_mean_squared_error: 7.4403e-04
# Epoch 65/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 6.9822e-04 - val_mean_squared_error: 6.9822e-04
# Epoch 66/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 8.5214e-04 - val_mean_squared_error: 8.5214e-04
# Epoch 67/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 9.9106e-04 - val_mean_squared_error: 9.9106e-04
# Epoch 68/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 6.7036e-04 - val_mean_squared_error: 6.7036e-04
# Epoch 69/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 6.6664e-04 - val_mean_squared_error: 6.6664e-04
# Epoch 70/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 6.5354e-04 - val_mean_squared_error: 6.5354e-04
# Epoch 71/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 6.6956e-04 - val_mean_squared_error: 6.6956e-04
# Epoch 72/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 6.6330e-04 - val_mean_squared_error: 6.6330e-04
# Epoch 73/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 6.8801e-04 - val_mean_squared_error: 6.8801e-04
# Epoch 74/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 6.7050e-04 - val_mean_squared_error: 6.7050e-04
# Epoch 75/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 6.4611e-04 - val_mean_squared_error: 6.4611e-04
# Epoch 76/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 7.7698e-04 - val_mean_squared_error: 7.7698e-04
# Epoch 77/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 6.4608e-04 - val_mean_squared_error: 6.4608e-04
# Epoch 78/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 6.5719e-04 - val_mean_squared_error: 6.5719e-04
# Epoch 79/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 6.3521e-04 - val_mean_squared_error: 6.3521e-04
# Epoch 80/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 6.5686e-04 - val_mean_squared_error: 6.5686e-04
# Epoch 81/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 6.9016e-04 - val_mean_squared_error: 6.9016e-04
# Epoch 82/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 6.8256e-04 - val_mean_squared_error: 6.8256e-04
# Epoch 83/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 6.3146e-04 - val_mean_squared_error: 6.3146e-04
# Epoch 84/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 6.7806e-04 - val_mean_squared_error: 6.7806e-04
# Epoch 85/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 9.5468e-04 - val_mean_squared_error: 9.5468e-04
# Epoch 86/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 6.2718e-04 - val_mean_squared_error: 6.2718e-04
# Epoch 87/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 6.3324e-04 - val_mean_squared_error: 6.3324e-04
# Epoch 88/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 7.8669e-04 - val_mean_squared_error: 7.8669e-04
# Epoch 89/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 90/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 7.3755e-04 - val_mean_squared_error: 7.3755e-04
# Epoch 91/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 7.1623e-04 - val_mean_squared_error: 7.1623e-04
# Epoch 92/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 6.1645e-04 - val_mean_squared_error: 6.1645e-04
# Epoch 93/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 7.6625e-04 - val_mean_squared_error: 7.6625e-04
# Epoch 94/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 7.5590e-04 - val_mean_squared_error: 7.5590e-04
# Epoch 95/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 9.2762e-04 - val_mean_squared_error: 9.2762e-04
# Epoch 96/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 6.3436e-04 - val_mean_squared_error: 6.3436e-04
# Epoch 97/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 98/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 6.6693e-04 - val_mean_squared_error: 6.6693e-04
# Epoch 99/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 6.9687e-04 - val_mean_squared_error: 6.9687e-04
# Epoch 100/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 9.1295e-04 - val_mean_squared_error: 9.1295e-04
# Epoch 101/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 5.9426e-04 - val_mean_squared_error: 5.9426e-04
# Epoch 102/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 7.8840e-04 - val_mean_squared_error: 7.8840e-04
# Epoch 103/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 6.2511e-04 - val_mean_squared_error: 6.2511e-04
# Epoch 104/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 8.0838e-04 - val_mean_squared_error: 8.0838e-04
# Epoch 105/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 7.0152e-04 - val_mean_squared_error: 7.0152e-04
# Epoch 106/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 5.9169e-04 - val_mean_squared_error: 5.9169e-04
# Epoch 107/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 5.8574e-04 - val_mean_squared_error: 5.8574e-04
# Epoch 108/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 8.0702e-04 - val_mean_squared_error: 8.0702e-04
# Epoch 109/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 7.6141e-04 - val_mean_squared_error: 7.6141e-04
# Epoch 110/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 5.8480e-04 - val_mean_squared_error: 5.8480e-04
# Epoch 111/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 8.0979e-04 - val_mean_squared_error: 8.0979e-04
# Epoch 112/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 6.2787e-04 - val_mean_squared_error: 6.2787e-04
# Epoch 113/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 5.9568e-04 - val_mean_squared_error: 5.9568e-04
# Epoch 114/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 6.7739e-04 - val_mean_squared_error: 6.7739e-04
# Epoch 115/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 9.0956e-04 - val_mean_squared_error: 9.0956e-04
# Epoch 116/200
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 6.0783e-04 - val_mean_squared_error: 6.0783e-04
# Epoch 117/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 9.1394e-04 - val_mean_squared_error: 9.1394e-04
# Epoch 118/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 5.7479e-04 - val_mean_squared_error: 5.7479e-04
# Epoch 119/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 6.5593e-04 - val_mean_squared_error: 6.5593e-04
# Epoch 120/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 6.3657e-04 - val_mean_squared_error: 6.3657e-04
# Epoch 121/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 122/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 8.5801e-04 - val_mean_squared_error: 8.5801e-04
# Epoch 123/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 6.1998e-04 - val_mean_squared_error: 6.1998e-04
# Epoch 124/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 6.3588e-04 - val_mean_squared_error: 6.3588e-04
# Epoch 125/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 7.1369e-04 - val_mean_squared_error: 7.1369e-04
# Epoch 126/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 127/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 6.4433e-04 - val_mean_squared_error: 6.4433e-04
# Epoch 128/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 7.6420e-04 - val_mean_squared_error: 7.6420e-04
# Epoch 129/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 7.3089e-04 - val_mean_squared_error: 7.3089e-04
# Epoch 130/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 8.3316e-04 - val_mean_squared_error: 8.3316e-04
# Epoch 131/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 8.7519e-04 - val_mean_squared_error: 8.7519e-04
# Epoch 132/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 6.6368e-04 - val_mean_squared_error: 6.6368e-04
# Epoch 133/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 6.8624e-04 - val_mean_squared_error: 6.8624e-04
# Epoch 134/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 8.4614e-04 - val_mean_squared_error: 8.4614e-04
# Epoch 135/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 136/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 6.8200e-04 - val_mean_squared_error: 6.8200e-04
# Epoch 137/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 138/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 8.2245e-04 - val_mean_squared_error: 8.2245e-04
# Epoch 139/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 140/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 141/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 5.5795e-04 - val_mean_squared_error: 5.5795e-04
# Epoch 142/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 8.3676e-04 - val_mean_squared_error: 8.3676e-04
# Epoch 143/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 8.3894e-04 - val_mean_squared_error: 8.3894e-04
# Epoch 144/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 9.0908e-04 - val_mean_squared_error: 9.0908e-04
# Epoch 145/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 7.6636e-04 - val_mean_squared_error: 7.6636e-04
# Epoch 146/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 147/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 6.0612e-04 - val_mean_squared_error: 6.0612e-04
# Epoch 148/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 7.7161e-04 - val_mean_squared_error: 7.7161e-04
# Epoch 149/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 150/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 151/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 152/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 7.3647e-04 - val_mean_squared_error: 7.3647e-04
# Epoch 153/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 154/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 6.3666e-04 - val_mean_squared_error: 6.3666e-04
# Epoch 155/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 156/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 9.3068e-04 - val_mean_squared_error: 9.3068e-04
# Epoch 157/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 9.6423e-04 - val_mean_squared_error: 9.6423e-04
# Epoch 158/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 9.5911e-04 - val_mean_squared_error: 9.5911e-04
# Epoch 159/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 5.6583e-04 - val_mean_squared_error: 5.6583e-04
# Epoch 160/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 161/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 7.3923e-04 - val_mean_squared_error: 7.3923e-04
# Epoch 162/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 163/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 9.4043e-04 - val_mean_squared_error: 9.4043e-04
# Epoch 164/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 165/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 6.6606e-04 - val_mean_squared_error: 6.6606e-04
# Epoch 166/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 167/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 9.3486e-04 - val_mean_squared_error: 9.3486e-04
# Epoch 168/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 8.8500e-04 - val_mean_squared_error: 8.8500e-04
# Epoch 169/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 170/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 171/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 172/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 173/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 174/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 175/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 176/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 177/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 9.5630e-04 - val_mean_squared_error: 9.5630e-04
# Epoch 178/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 179/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 180/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 181/200
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 182/200
# 18/18 [==============================] - 0s 23ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 7.7335e-04 - val_mean_squared_error: 7.7335e-04
# Epoch 183/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 184/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 185/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 186/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 187/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 188/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 6.8157e-04 - val_mean_squared_error: 6.8157e-04
# Epoch 189/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 9.2937e-04 - val_mean_squared_error: 9.2937e-04
# Epoch 190/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 9.9952e-04 - val_mean_squared_error: 9.9952e-04
# Epoch 191/200
# 16/18 [=========================>....] - ETA: 0s - loss: 0.0102 - mean_squared_error: 0.0102Restoring model weights from the end of the best epoch: 141.
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 191: early stopping

# %%
# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)

print(train_predict.shape, y_pred.shape)
# Out:
# 36/36 [==============================] - 1s 3ms/step
# 4/4 [==============================] - 0s 4ms/step
# (1128, 1) (122, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, y_test.shape)
# Out:
# (1128,) (122,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred
train_predict=scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

#in head
print(y_train[:5])
# Out:
# [0.03379376 0.03710322 0.02905486 0.02274669 0.01326889]

# %%
#Chuẩn hóa ngược lại y_test và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
y_test = y_test.reshape(y_test.shape[0],1)
y_train=scaler.inverse_transform(y_train)
y_test=scaler.inverse_transform(y_test)

#in head
print(y_train[:5])
# Out:
# [[40.985001]
#  [41.517502]
#  [40.2225  ]
#  [39.2075  ]
#  [37.682499]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
from sklearn.metrics import mean_absolute_percentage_error,mean_absolute_error, r2_score, mean_squared_error
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
train_rmse = np.sqrt(np.mean((train_predict - y_train)**2))
print('Testing RMSE:', test_rmse)
print('Training RMSE:', train_rmse)
# 8+. Tính MAPE
test_mape = mean_absolute_percentage_error(y_test, y_pred)
print('Testing MAPE:', test_mape)
train_mape = mean_absolute_percentage_error(y_train, train_predict)
print('Training MAPE:', train_mape)
# 8+. Tính MAE
test_mae = mean_absolute_error(y_test, y_pred)
print('Testing MAE:', test_mae)
train_mae = mean_absolute_error(y_train, train_predict)
print('Training MAE:', train_mae)
# Out:
# Testing RMSE: 3.8006736105592056
# Training RMSE: 4.689936787123858
# Testing MAPE: 0.015899386655158207
# Training MAPE: 0.038102053731199174
# Testing MAE: 2.89321335484439
# Training MAE: 3.823643249465181

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])


    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (3, 1)
# -----------------
# day  1  have input =  [0.98645147 0.995401   0.97967711]
# day  1  have output =  0.9911592
# -----------------
# day  2  have input =  [0.995401   0.97967711 0.9911592 ]
# day  2  have output =  0.9930487
# -----------------
# day  3  have input =  [0.97967711 0.9911592  0.99304873]
# day  3  have output =  0.9867761
# -----------------
# day  4  have input =  [0.9911592  0.99304873 0.98677611]
# day  4  have output =  0.99421144
# -----------------
# day  5  have input =  [0.99304873 0.98677611 0.99421144]
# day  5  have output =  0.99417394
# -----------------
# day  6  have input =  [0.98677611 0.99421144 0.99417394]
# day  6  have output =  0.99252486
# -----------------
# day  7  have input =  [0.99421144 0.99417394 0.99252486]
# day  7  have output =  0.9971831
# -----------------
# day  8  have input =  [0.99417394 0.99252486 0.99718308]
# day  8  have output =  0.99711275
# -----------------
# day  9  have input =  [0.99252486 0.99718308 0.99711275]
# day  9  have output =  0.9975608
# -----------------
# day  10  have input =  [0.99718308 0.99711275 0.9975608 ]
# day  10  have output =  1.0006217
# -----------------
# day  11  have input =  [0.99711275 0.9975608  1.00062168]
# day  11  have output =  1.0010487
# -----------------
# day  12  have input =  [0.9975608  1.00062168 1.00104868]
# day  12  have output =  1.0023918
# -----------------
# day  13  have input =  [1.00062168 1.00104868 1.00239182]
# day  13  have output =  1.00467
# -----------------
# day  14  have input =  [1.00104868 1.00239182 1.00467002]
# day  14  have output =  1.0056319
# -----------------
# day  15  have input =  [1.00239182 1.00467002 1.00563192]
# day  15  have output =  1.007358
# -----------------
# day  16  have input =  [1.00467002 1.00563192 1.00735795]
# day  16  have output =  1.0093423
# -----------------
# day  17  have input =  [1.00563192 1.00735795 1.00934231]
# day  17  have output =  1.0107471
# -----------------
# day  18  have input =  [1.00735795 1.00934231 1.01074708]
# day  18  have output =  1.0126733
# -----------------
# day  19  have input =  [1.00934231 1.01074708 1.01267326]
# day  19  have output =  1.0146327
# -----------------
# day  20  have input =  [1.01074708 1.01267326 1.0146327 ]
# day  20  have output =  1.016389
# -----------------
# day  21  have input =  [1.01267326 1.0146327  1.01638901]
# day  21  have output =  1.0184745
# -----------------
# day  22  have input =  [1.0146327  1.01638901 1.01847446]
# day  22  have output =  1.0205498
# -----------------
# day  23  have input =  [1.01638901 1.01847446 1.02054977]
# day  23  have output =  1.0225992
# -----------------
# day  24  have input =  [1.01847446 1.02054977 1.02259922]
# day  24  have output =  1.0248574
# -----------------
# day  25  have input =  [1.02054977 1.02259922 1.0248574 ]
# day  25  have output =  1.0271221
# -----------------
# day  26  have input =  [1.02259922 1.0248574  1.02712214]
# day  26  have output =  1.0294392
# -----------------
# day  27  have input =  [1.0248574  1.02712214 1.02943921]
# day  27  have output =  1.0318999
# -----------------
# day  28  have input =  [1.02712214 1.02943921 1.03189993]
# day  28  have output =  1.0343969
# -----------------
# day  29  have input =  [1.02943921 1.03189993 1.03439689]
# day  29  have output =  1.0369788
# -----------------
# day  30  have input =  [1.03189993 1.03439689 1.03697884]
# day  30  have output =  1.0396749

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='blue', label='Next 30 days')
plt.show()

# %%
#chuẩn hóa ngược lại dữ liệu

train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[42.275002]
#  [42.737499]
#  [41.369999]
#  [40.985001]
#  [41.517502]]
# [[183.309998]
#  [183.949997]
#  [186.009995]
#  [184.919998]
#  [185.009995]]
# [[195.02748]
#  [195.33153]
#  [194.32224]
#  [195.5186 ]
#  [195.51257]]

# %%
#vẽ y_train nối với ytest với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=len(df1), step=1)
#val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=len(df1), stop=len(df1)+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
#y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
#plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Predict')
#plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
#plt.xticks(np.arange(0, len(df1), 100), df['Date'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
