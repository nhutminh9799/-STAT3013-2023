# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('/content/drive/MyDrive/StockData/Apple.csv')
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-12-12   42.599998   42.980000   42.255001   42.275002   40.576008
# 1     2018-12-13   42.622501   43.142502   42.387501   42.737499   41.019917
# 2     2018-12-14   42.250000   42.270000   41.320000   41.369999   39.707371
# 3     2018-12-17   41.362499   42.087502   40.682499   40.985001   39.337845
# 4     2018-12-18   41.345001   41.882500   41.097500   41.517502   39.848946
# ...          ...         ...         ...         ...         ...         ...
# 1253  2023-12-05  190.210007  194.399994  190.179993  193.419998  193.419998
# 1254  2023-12-06  194.449997  194.759995  192.110001  192.320007  192.320007
# 1255  2023-12-07  193.630005  195.000000  193.589996  194.270004  194.270004
# 1256  2023-12-08  194.199997  195.990005  193.669998  195.710007  195.710007
# 1257  2023-12-11  193.110001  193.490005  191.419998  193.179993  193.179993
#
#          Volume
# 0     142510800
# 1     127594400
# 2     162814800
# 3     177151600
# 4     135366000
# ...         ...
# 1253   66628400
# 1254   41089700
# 1255   47477700
# 1256   53377300
# 1257   60943700
#
# [1258 rows x 7 columns]

# %%
df1=df.reset_index()['Close']
df1 = df1.dropna() #clean data
df1
# Out:
# 0        42.275002
# 1        42.737499
# 2        41.369999
# 3        40.985001
# 4        41.517502
#            ...
# 1253    193.419998
# 1254    192.320007
# 1255    194.270004
# 1256    195.710007
# 1257    193.179993
# Name: Close, Length: 1258, dtype: float64

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.8 * len(df1))
test_size = int(0.2 * len(df1))

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 \n",
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 3
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape)
# Out:
# (1002, 3, 1) (248, 3, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, LSTM #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import MeanSquaredError

#import cac metrics nhu mse,mae,rmse
from tensorflow.keras import metrics

#import cac loss function nhu mse,mae,rmse,mape
from tensorflow.keras import losses

# Tạo model
model = Sequential()

input_shape = (time_step, 1)
model.add(LSTM(64, input_shape=input_shape, return_sequences=True))
model.add(LSTM(32, input_shape=input_shape, return_sequences=True))
model.add(LSTM(16))


model.add(Dense(5))
model.add(Dropout(0.2))

model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics
model.compile (loss= "mean_squared_error", optimizer=Adam(learning_rate=0.0001), metrics="mean_squared_error")
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=50, restore_best_weights=True)

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=200,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/200
# 16/16 [==============================] - 17s 103ms/step - loss: 0.2856 - mean_squared_error: 0.2856 - val_loss: 0.6898 - val_mean_squared_error: 0.6898
# Epoch 2/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.2700 - mean_squared_error: 0.2700 - val_loss: 0.6582 - val_mean_squared_error: 0.6582
# Epoch 3/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2547 - mean_squared_error: 0.2547 - val_loss: 0.6265 - val_mean_squared_error: 0.6265
# Epoch 4/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2393 - mean_squared_error: 0.2393 - val_loss: 0.5927 - val_mean_squared_error: 0.5927
# Epoch 5/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.2232 - mean_squared_error: 0.2232 - val_loss: 0.5566 - val_mean_squared_error: 0.5566
# Epoch 6/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.2059 - mean_squared_error: 0.2059 - val_loss: 0.5168 - val_mean_squared_error: 0.5168
# Epoch 7/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.1859 - mean_squared_error: 0.1859 - val_loss: 0.4715 - val_mean_squared_error: 0.4715
# Epoch 8/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1669 - mean_squared_error: 0.1669 - val_loss: 0.4203 - val_mean_squared_error: 0.4203
# Epoch 9/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.1451 - mean_squared_error: 0.1451 - val_loss: 0.3637 - val_mean_squared_error: 0.3637
# Epoch 10/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1222 - mean_squared_error: 0.1222 - val_loss: 0.3010 - val_mean_squared_error: 0.3010
# Epoch 11/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.1005 - mean_squared_error: 0.1005 - val_loss: 0.2364 - val_mean_squared_error: 0.2364
# Epoch 12/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0782 - mean_squared_error: 0.0782 - val_loss: 0.1701 - val_mean_squared_error: 0.1701
# Epoch 13/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0621 - mean_squared_error: 0.0621 - val_loss: 0.1141 - val_mean_squared_error: 0.1141
# Epoch 14/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0498 - mean_squared_error: 0.0498 - val_loss: 0.0753 - val_mean_squared_error: 0.0753
# Epoch 15/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0453 - mean_squared_error: 0.0453 - val_loss: 0.0523 - val_mean_squared_error: 0.0523
# Epoch 16/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0433 - mean_squared_error: 0.0433 - val_loss: 0.0432 - val_mean_squared_error: 0.0432
# Epoch 17/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0432 - mean_squared_error: 0.0432 - val_loss: 0.0400 - val_mean_squared_error: 0.0400
# Epoch 18/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0357 - mean_squared_error: 0.0357 - val_loss: 0.0377 - val_mean_squared_error: 0.0377
# Epoch 19/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0418 - mean_squared_error: 0.0418 - val_loss: 0.0360 - val_mean_squared_error: 0.0360
# Epoch 20/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0398 - mean_squared_error: 0.0398 - val_loss: 0.0293 - val_mean_squared_error: 0.0293
# Epoch 21/200
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0289 - val_mean_squared_error: 0.0289
# Epoch 22/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 23/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0328 - mean_squared_error: 0.0328 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 24/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# Epoch 25/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0350 - mean_squared_error: 0.0350 - val_loss: 0.0165 - val_mean_squared_error: 0.0165
# Epoch 26/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# Epoch 27/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0286 - mean_squared_error: 0.0286 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 28/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0263 - mean_squared_error: 0.0263 - val_loss: 0.0133 - val_mean_squared_error: 0.0133
# Epoch 29/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0263 - mean_squared_error: 0.0263 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 30/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 31/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0270 - mean_squared_error: 0.0270 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 32/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 33/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 34/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 35/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 36/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0220 - mean_squared_error: 0.0220 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 37/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 38/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0211 - mean_squared_error: 0.0211 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 39/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 40/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 41/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0195 - mean_squared_error: 0.0195 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 42/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 43/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 44/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 45/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 46/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 47/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 48/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 49/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 50/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 51/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 52/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 53/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 54/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 55/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 56/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 57/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 58/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 59/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 60/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 61/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 62/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 63/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 64/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 65/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 66/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 67/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 68/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 69/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 70/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 71/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 72/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 73/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 74/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 75/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 76/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 77/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 78/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 79/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 80/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 81/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 82/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 9.6258e-04 - val_mean_squared_error: 9.6258e-04
# Epoch 83/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 84/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 85/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 9.3114e-04 - val_mean_squared_error: 9.3114e-04
# Epoch 86/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 87/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 9.7047e-04 - val_mean_squared_error: 9.7047e-04
# Epoch 88/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 89/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 9.9833e-04 - val_mean_squared_error: 9.9833e-04
# Epoch 90/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 91/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 92/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 9.3053e-04 - val_mean_squared_error: 9.3053e-04
# Epoch 93/200
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 94/200
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 9.7183e-04 - val_mean_squared_error: 9.7183e-04
# Epoch 95/200
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 96/200
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 97/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 98/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 8.4326e-04 - val_mean_squared_error: 8.4326e-04
# Epoch 99/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 100/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 9.0505e-04 - val_mean_squared_error: 9.0505e-04
# Epoch 101/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 8.0439e-04 - val_mean_squared_error: 8.0439e-04
# Epoch 102/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 103/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 9.8779e-04 - val_mean_squared_error: 9.8779e-04
# Epoch 104/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 105/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 8.1170e-04 - val_mean_squared_error: 8.1170e-04
# Epoch 106/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 107/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 108/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 7.6899e-04 - val_mean_squared_error: 7.6899e-04
# Epoch 109/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 110/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 111/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 8.8478e-04 - val_mean_squared_error: 8.8478e-04
# Epoch 112/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 7.3810e-04 - val_mean_squared_error: 7.3810e-04
# Epoch 113/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 114/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 115/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 116/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 117/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 118/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 119/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 6.2055e-04 - val_mean_squared_error: 6.2055e-04
# Epoch 120/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 121/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 122/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 123/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 124/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 125/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 126/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 7.8650e-04 - val_mean_squared_error: 7.8650e-04
# Epoch 127/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 9.1970e-04 - val_mean_squared_error: 9.1970e-04
# Epoch 128/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 129/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 130/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 131/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 132/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 133/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 134/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 135/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 136/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 137/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 138/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 139/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 8.8036e-04 - val_mean_squared_error: 8.8036e-04
# Epoch 140/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 141/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 142/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 143/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 144/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 145/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 146/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 147/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 148/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 149/200
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 150/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 151/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 152/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 153/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 154/200
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 155/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 156/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 157/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 158/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 159/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 160/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 161/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 162/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 163/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 164/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 165/200
# 16/16 [==============================] - 0s 25ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 166/200
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 167/200
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 168/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 169/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0119 - mean_squared_error: 0.0119Restoring model weights from the end of the best epoch: 119.
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 169: early stopping

# %%
# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)

print(train_predict.shape, y_pred.shape)
# Out:
# 32/32 [==============================] - 2s 5ms/step
# 8/8 [==============================] - 0s 5ms/step
# (1002, 1) (248, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, y_test.shape)
# Out:
# (1002,) (248,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred
train_predict=scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

#in head
print(y_train[:5])
# Out:
# [0.03379376 0.03710322 0.02905486 0.02274669 0.01326889]

# %%
#Chuẩn hóa ngược lại y_test và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
y_test = y_test.reshape(y_test.shape[0],1)
y_train=scaler.inverse_transform(y_train)
y_test=scaler.inverse_transform(y_test)

#in head
print(y_train[:5])
# Out:
# [[40.985001]
#  [41.517502]
#  [40.2225  ]
#  [39.2075  ]
#  [37.682499]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
from sklearn.metrics import mean_absolute_percentage_error,mean_absolute_error, r2_score, mean_squared_error
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
train_rmse = np.sqrt(np.mean((train_predict - y_train)**2))
print('Testing RMSE:', test_rmse)
print('Training RMSE:', train_rmse)
# 8+. Tính MAPE
test_mape = mean_absolute_percentage_error(y_test, y_pred)
print('Testing MAPE:', test_mape)
train_mape = mean_absolute_percentage_error(y_train, train_predict)
print('Training MAPE:', train_mape)
# 8+. Tính MAE
test_mae = mean_absolute_error(y_test, y_pred)
print('Testing MAE:', test_mae)
train_mae = mean_absolute_error(y_train, train_predict)
print('Training MAE:', train_mae)
# Out:
# Testing RMSE: 4.008228398958765
# Training RMSE: 5.126693841837769
# Testing MAPE: 0.019010427591293243
# Training MAPE: 0.05002477280708398
# Testing MAE: 3.1048678651162387
# Training MAE: 4.298016377400958

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])


    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (3, 1)
# -----------------
# day  1  have input =  [0.98645147 0.995401   0.97967711]
# day  1  have output =  0.99503
# -----------------
# day  2  have input =  [0.995401   0.97967711 0.99502999]
# day  2  have output =  0.99741673
# -----------------
# day  3  have input =  [0.97967711 0.99502999 0.99741673]
# day  3  have output =  0.992068
# -----------------
# day  4  have input =  [0.99502999 0.99741673 0.99206799]
# day  4  have output =  1.0021693
# -----------------
# day  5  have input =  [0.99741673 0.99206799 1.00216925]
# day  5  have output =  1.0029674
# -----------------
# day  6  have input =  [0.99206799 1.00216925 1.00296736]
# day  6  have output =  1.0025891
# -----------------
# day  7  have input =  [1.00216925 1.00296736 1.00258911]
# day  7  have output =  1.0092472
# -----------------
# day  8  have input =  [1.00296736 1.00258911 1.00924718]
# day  8  have output =  1.0102004
# -----------------
# day  9  have input =  [1.00258911 1.00924718 1.01020038]
# day  9  have output =  1.011992
# -----------------
# day  10  have input =  [1.00924718 1.01020038 1.01199198]
# day  10  have output =  1.0166594
# -----------------
# day  11  have input =  [1.01020038 1.01199198 1.01665938]
# day  11  have output =  1.0181758
# -----------------
# day  12  have input =  [1.01199198 1.01665938 1.01817584]
# day  12  have output =  1.0208021
# -----------------
# day  13  have input =  [1.01665938 1.01817584 1.02080214]
# day  13  have output =  1.0244216
# -----------------
# day  14  have input =  [1.01817584 1.02080214 1.02442157]
# day  14  have output =  1.0264444
# -----------------
# day  15  have input =  [1.02080214 1.02442157 1.02644444]
# day  15  have output =  1.0293242
# -----------------
# day  16  have input =  [1.02442157 1.02644444 1.02932417]
# day  16  have output =  1.0324341
# -----------------
# day  17  have input =  [1.02644444 1.02932417 1.03243411]
# day  17  have output =  1.0347986
# -----------------
# day  18  have input =  [1.02932417 1.03243411 1.03479862]
# day  18  have output =  1.0377057
# -----------------
# day  19  have input =  [1.03243411 1.03479862 1.03770566]
# day  19  have output =  1.0405821
# -----------------
# day  20  have input =  [1.03479862 1.03770566 1.04058206]
# day  20  have output =  1.0431395
# -----------------
# day  21  have input =  [1.03770566 1.04058206 1.04313946]
# day  21  have output =  1.0459987
# -----------------
# day  22  have input =  [1.04058206 1.04313946 1.04599869]
# day  22  have output =  1.0487672
# -----------------
# day  23  have input =  [1.04313946 1.04599869 1.04876721]
# day  23  have output =  1.0514109
# -----------------
# day  24  have input =  [1.04599869 1.04876721 1.05141091]
# day  24  have output =  1.0542033
# -----------------
# day  25  have input =  [1.04876721 1.05141091 1.05420327]
# day  25  have output =  1.0569108
# -----------------
# day  26  have input =  [1.05141091 1.05420327 1.05691075]
# day  26  have output =  1.059572
# -----------------
# day  27  have input =  [1.05420327 1.05691075 1.05957198]
# day  27  have output =  1.0622936
# -----------------
# day  28  have input =  [1.05691075 1.05957198 1.06229365]
# day  28  have output =  1.0649498
# -----------------
# day  29  have input =  [1.05957198 1.06229365 1.06494975]
# day  29  have output =  1.067585
# -----------------
# day  30  have input =  [1.06229365 1.06494975 1.06758499]
# day  30  have output =  1.0702336

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='blue', label='Next 30 days')
plt.show()

# %%
#chuẩn hóa ngược lại dữ liệu

train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[42.275002]
#  [42.737499]
#  [41.369999]
#  [40.985001]
#  [41.517502]]
# [[142.160004]
#  [144.490005]
#  [145.470001]
#  [143.210007]
#  [136.5     ]]
# [[195.65031]
#  [196.03433]
#  [195.17372]
#  [196.79903]
#  [196.92744]]

# %%
#vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=len(df1), step=1)
#val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=len(df1), stop=len(df1)+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
#y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
#plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Predict')
#plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
#plt.xticks(np.arange(0, len(df1), 100), df['Date'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
