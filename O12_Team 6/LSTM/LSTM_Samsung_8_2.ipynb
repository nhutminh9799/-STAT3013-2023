# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('/content/drive/MyDrive/StockData/SamSung.csv')
df
# Out:
#             Date     Open     High      Low    Close     Adj Close    Volume
# 0     2018-12-12  40250.0  40700.0  40150.0  40450.0  35281.417969  12024279
# 1     2018-12-13  40650.0  40750.0  40000.0  40000.0  34888.921875  26254646
# 2     2018-12-14  40200.0  40200.0  38700.0  38950.0  33973.089844  19671783
# 3     2018-12-17  38650.0  39600.0  38650.0  39150.0  34147.535156  11532968
# 4     2018-12-18  38300.0  39200.0  38300.0  38900.0  33929.472656  11042101
# ...          ...      ...      ...      ...      ...           ...       ...
# 1227  2023-12-06  71800.0  72100.0  71600.0  71700.0  71700.000000   8123087
# 1228  2023-12-07  71800.0  71900.0  71100.0  71500.0  71500.000000   8862017
# 1229  2023-12-08  72100.0  72800.0  71900.0  72600.0  72600.000000  10859463
# 1230  2023-12-11  72800.0  73000.0  72200.0  73000.0  73000.000000   9861960
# 1231  2023-12-12  73300.0  73500.0  73100.0  73500.0  73500.000000  13758646
#
# [1232 rows x 7 columns]

# %%
df1=df.reset_index()['Close']
df1 = df1.dropna() #clean data
df1
# Out:
# 0       40450.0
# 1       40000.0
# 2       38950.0
# 3       39150.0
# 4       38900.0
#          ...
# 1227    71700.0
# 1228    71500.0
# 1229    72600.0
# 1230    73000.0
# 1231    73500.0
# Name: Close, Length: 1232, dtype: float64

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.8 * len(df1))
test_size = int(0.2 * len(df1))

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 \n",
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 3
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape)
# Out:
# (981, 3, 1) (243, 3, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, LSTM #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import MeanSquaredError

#import cac metrics nhu mse,mae,rmse
from tensorflow.keras import metrics

#import cac loss function nhu mse,mae,rmse,mape
from tensorflow.keras import losses

# Tạo model
model = Sequential()

input_shape = (time_step, 1)
model.add(LSTM(64, input_shape=input_shape, return_sequences=True))
model.add(LSTM(32, input_shape=input_shape, return_sequences=True))
model.add(LSTM(16))


model.add(Dense(5))
model.add(Dropout(0.2))

model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics
model.compile (loss= "mean_squared_error", optimizer=Adam(learning_rate=0.0001), metrics="mean_squared_error")
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=50, restore_best_weights=True)

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=200,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/200
# 16/16 [==============================] - 18s 146ms/step - loss: 0.2484 - mean_squared_error: 0.2484 - val_loss: 0.2757 - val_mean_squared_error: 0.2757
# Epoch 2/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.2317 - mean_squared_error: 0.2317 - val_loss: 0.2551 - val_mean_squared_error: 0.2551
# Epoch 3/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.2152 - mean_squared_error: 0.2152 - val_loss: 0.2341 - val_mean_squared_error: 0.2341
# Epoch 4/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1971 - mean_squared_error: 0.1971 - val_loss: 0.2118 - val_mean_squared_error: 0.2118
# Epoch 5/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1789 - mean_squared_error: 0.1789 - val_loss: 0.1878 - val_mean_squared_error: 0.1878
# Epoch 6/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.1577 - mean_squared_error: 0.1577 - val_loss: 0.1620 - val_mean_squared_error: 0.1620
# Epoch 7/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1375 - mean_squared_error: 0.1375 - val_loss: 0.1345 - val_mean_squared_error: 0.1345
# Epoch 8/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.1148 - mean_squared_error: 0.1148 - val_loss: 0.1060 - val_mean_squared_error: 0.1060
# Epoch 9/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0945 - mean_squared_error: 0.0945 - val_loss: 0.0778 - val_mean_squared_error: 0.0778
# Epoch 10/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0705 - mean_squared_error: 0.0705 - val_loss: 0.0512 - val_mean_squared_error: 0.0512
# Epoch 11/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0569 - mean_squared_error: 0.0569 - val_loss: 0.0297 - val_mean_squared_error: 0.0297
# Epoch 12/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0406 - mean_squared_error: 0.0406 - val_loss: 0.0154 - val_mean_squared_error: 0.0154
# Epoch 13/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0335 - mean_squared_error: 0.0335 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 14/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0308 - mean_squared_error: 0.0308 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 15/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0306 - mean_squared_error: 0.0306 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 16/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0299 - mean_squared_error: 0.0299 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 17/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0316 - mean_squared_error: 0.0316 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 18/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0270 - mean_squared_error: 0.0270 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 19/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 20/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 21/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 22/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 23/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 24/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 25/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0221 - mean_squared_error: 0.0221 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 26/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 27/200
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 28/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 29/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 30/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 31/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 32/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 33/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 34/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 35/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 36/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 37/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 38/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 39/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 40/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 41/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 42/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 43/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 44/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 45/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 46/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 47/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 48/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 49/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 50/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 51/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 52/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 53/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 54/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 55/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 56/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 57/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 58/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 59/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 60/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 61/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 62/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 63/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 64/200
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 65/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 66/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 67/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 68/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 69/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 70/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 71/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 72/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 73/200
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 74/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 75/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 76/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 77/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 78/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 79/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 80/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 81/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 82/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 83/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 84/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 85/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 86/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 87/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 88/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 89/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 90/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 91/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 92/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 93/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 94/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 95/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 96/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 97/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 98/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 99/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 100/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 101/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 102/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 103/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 104/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 105/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 106/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 107/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 108/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 109/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 110/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 111/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 112/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 113/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 114/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 115/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 116/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 117/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 118/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 119/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 120/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 121/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 122/200
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 123/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 124/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 125/200
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 126/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 127/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 128/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 129/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 130/200
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 131/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 132/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 133/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 134/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 135/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 136/200
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 137/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 138/200
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 139/200
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 140/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 141/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 142/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 143/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 144/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 145/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 146/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 147/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 148/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 149/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 150/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 151/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 152/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 153/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 154/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 155/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 156/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 157/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 158/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 159/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 160/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 161/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 162/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 163/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 164/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 165/200
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 166/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 167/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 168/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 169/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 170/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 171/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 172/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 173/200
# 16/16 [==============================] - 0s 12ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 174/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 175/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 176/200
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 177/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 178/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 179/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 180/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 181/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 182/200
# 16/16 [==============================] - 0s 13ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 183/200
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 184/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 185/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 186/200
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 187/200
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 188/200
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 189/200
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 190/200
# 13/16 [=======================>......] - ETA: 0s - loss: 0.0104 - mean_squared_error: 0.0104Restoring model weights from the end of the best epoch: 140.
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 190: early stopping

# %%
# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)

print(train_predict.shape, y_pred.shape)
# Out:
# 31/31 [==============================] - 1s 4ms/step
# 8/8 [==============================] - 0s 4ms/step
# (981, 1) (243, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, y_test.shape)
# Out:
# (981,) (243,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred
train_predict=scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

#in head
print(y_train[:5])
# Out:
# [0.03174603 0.0270775  0.03081232 0.02240896 0.02240896]

# %%
#Chuẩn hóa ngược lại y_test và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
y_test = y_test.reshape(y_test.shape[0],1)
y_train=scaler.inverse_transform(y_train)
y_test=scaler.inverse_transform(y_test)

#in head
print(y_train[:5])
# Out:
# [[39150.]
#  [38900.]
#  [39100.]
#  [38650.]
#  [38650.]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
from sklearn.metrics import mean_absolute_percentage_error,mean_absolute_error, r2_score, mean_squared_error
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
train_rmse = np.sqrt(np.mean((train_predict - y_train)**2))
print('Testing RMSE:', test_rmse)
print('Training RMSE:', train_rmse)
# 8+. Tính MAPE
test_mape = mean_absolute_percentage_error(y_test, y_pred)
print('Testing MAPE:', test_mape)
train_mape = mean_absolute_percentage_error(y_train, train_predict)
print('Training MAPE:', train_mape)
# 8+. Tính MAE
test_mae = mean_absolute_error(y_test, y_pred)
print('Testing MAE:', test_mae)
train_mae = mean_absolute_error(y_train, train_predict)
print('Training MAE:', train_mae)
# Out:
# Testing RMSE: 1734.8506723511837
# Training RMSE: 1767.261500139965
# Testing MAPE: 0.020637109240489195
# Training MAPE: 0.0235520874851115
# Testing MAE: 1377.8408243312758
# Training MAE: 1364.3736182785424

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])


    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (3, 1)
# -----------------
# day  1  have input =  [0.65639589 0.66386555 0.67320261]
# day  1  have output =  0.64348954
# -----------------
# day  2  have input =  [0.66386555 0.67320261 0.64348954]
# day  2  have output =  0.6481943
# -----------------
# day  3  have input =  [0.67320261 0.64348954 0.64819431]
# day  3  have output =  0.6452079
# -----------------
# day  4  have input =  [0.64348954 0.64819431 0.64520788]
# day  4  have output =  0.6272409
# -----------------
# day  5  have input =  [0.64819431 0.64520788 0.6272409 ]
# day  5  have output =  0.6274377
# -----------------
# day  6  have input =  [0.64520788 0.6272409  0.62743771]
# day  6  have output =  0.61982745
# -----------------
# day  7  have input =  [0.6272409  0.62743771 0.61982745]
# day  7  have output =  0.60760814
# -----------------
# day  8  have input =  [0.62743771 0.61982745 0.60760814]
# day  8  have output =  0.6040614
# -----------------
# day  9  have input =  [0.61982745 0.60760814 0.60406142]
# day  9  have output =  0.59500337
# -----------------
# day  10  have input =  [0.60760814 0.60406142 0.59500337]
# day  10  have output =  0.5852137
# -----------------
# day  11  have input =  [0.60406142 0.59500337 0.58521372]
# day  11  have output =  0.57913256
# -----------------
# day  12  have input =  [0.59500337 0.58521372 0.57913256]
# day  12  have output =  0.5697557
# -----------------
# day  13  have input =  [0.58521372 0.57913256 0.56975567]
# day  13  have output =  0.5607737
# -----------------
# day  14  have input =  [0.57913256 0.56975567 0.56077367]
# day  14  have output =  0.5531615
# -----------------
# day  15  have input =  [0.56975567 0.56077367 0.5531615 ]
# day  15  have output =  0.54379183
# -----------------
# day  16  have input =  [0.56077367 0.5531615  0.54379183]
# day  16  have output =  0.5349512
# -----------------
# day  17  have input =  [0.5531615  0.54379183 0.53495121]
# day  17  have output =  0.52651006
# -----------------
# day  18  have input =  [0.54379183 0.53495121 0.52651006]
# day  18  have output =  0.51723105
# -----------------
# day  19  have input =  [0.53495121 0.52651006 0.51723105]
# day  19  have output =  0.5083579
# -----------------
# day  20  have input =  [0.52651006 0.51723105 0.50835788]
# day  20  have output =  0.49955943
# -----------------
# day  21  have input =  [0.51723105 0.50835788 0.49955943]
# day  21  have output =  0.49042904
# -----------------
# day  22  have input =  [0.50835788 0.49955943 0.49042904]
# day  22  have output =  0.4815811
# -----------------
# day  23  have input =  [0.49955943 0.49042904 0.48158109]
# day  23  have output =  0.47275493
# -----------------
# day  24  have input =  [0.49042904 0.48158109 0.47275493]
# day  24  have output =  0.4638661
# -----------------
# day  25  have input =  [0.48158109 0.47275493 0.46386611]
# day  25  have output =  0.4551952
# -----------------
# day  26  have input =  [0.47275493 0.46386611 0.45519519]
# day  26  have output =  0.44658977
# -----------------
# day  27  have input =  [0.46386611 0.45519519 0.44658977]
# day  27  have output =  0.43806747
# -----------------
# day  28  have input =  [0.45519519 0.44658977 0.43806747]
# day  28  have output =  0.42974898
# -----------------
# day  29  have input =  [0.44658977 0.43806747 0.42974898]
# day  29  have output =  0.42156073
# -----------------
# day  30  have input =  [0.43806747 0.42974898 0.42156073]
# day  30  have output =  0.41353947

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='blue', label='Next 30 days')
plt.show()

# %%
#chuẩn hóa ngược lại dữ liệu

train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[40450.]
#  [40000.]
#  [38950.]
#  [39150.]
#  [38900.]]
# [[59700.]
#  [60500.]
#  [59300.]
#  [59500.]
#  [59500.]]
# [[71908.86 ]
#  [72160.805]
#  [72000.88 ]
#  [71038.75 ]
#  [71049.29 ]]

# %%
#vẽ y_train nối với ytest với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=len(df1), step=1)
#val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=len(df1), stop=len(df1)+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
#y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
#plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Predict')
#plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
#plt.xticks(np.arange(0, len(df1), 100), df['Date'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
