# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('/content/drive/MyDrive/StockData/SamSung.csv')
df
# Out:
#             Date     Open     High      Low    Close     Adj Close    Volume
# 0     2018-12-12  40250.0  40700.0  40150.0  40450.0  35281.417969  12024279
# 1     2018-12-13  40650.0  40750.0  40000.0  40000.0  34888.921875  26254646
# 2     2018-12-14  40200.0  40200.0  38700.0  38950.0  33973.089844  19671783
# 3     2018-12-17  38650.0  39600.0  38650.0  39150.0  34147.535156  11532968
# 4     2018-12-18  38300.0  39200.0  38300.0  38900.0  33929.472656  11042101
# ...          ...      ...      ...      ...      ...           ...       ...
# 1227  2023-12-06  71800.0  72100.0  71600.0  71700.0  71700.000000   8123087
# 1228  2023-12-07  71800.0  71900.0  71100.0  71500.0  71500.000000   8862017
# 1229  2023-12-08  72100.0  72800.0  71900.0  72600.0  72600.000000  10859463
# 1230  2023-12-11  72800.0  73000.0  72200.0  73000.0  73000.000000   9861960
# 1231  2023-12-12  73300.0  73500.0  73100.0  73500.0  73500.000000  13758646
#
# [1232 rows x 7 columns]

# %%
df1=df.reset_index()['Close']
df1 = df1.dropna() #clean data
df1
# Out:
# 0       40450.0
# 1       40000.0
# 2       38950.0
# 3       39150.0
# 4       38900.0
#          ...
# 1227    71700.0
# 1228    71500.0
# 1229    72600.0
# 1230    73000.0
# 1231    73500.0
# Name: Close, Length: 1232, dtype: float64

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.3 * len(df1))

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 \n",
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 3
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape)
# Out:
# (858, 3, 1) (366, 3, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, LSTM #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import MeanSquaredError

#import cac metrics nhu mse,mae,rmse
from tensorflow.keras import metrics

#import cac loss function nhu mse,mae,rmse,mape
from tensorflow.keras import losses

# Tạo model
model = Sequential()

input_shape = (time_step, 1)
model.add(LSTM(64, input_shape=input_shape, return_sequences=True))
model.add(LSTM(32, input_shape=input_shape, return_sequences=True))
model.add(LSTM(16))


model.add(Dense(5))
model.add(Dropout(0.2))

model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics
model.compile (loss= "mean_squared_error", optimizer=Adam(learning_rate=0.0001), metrics="mean_squared_error")
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=50, restore_best_weights=True)

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=200,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/200
# 14/14 [==============================] - 16s 169ms/step - loss: 0.2734 - mean_squared_error: 0.2734 - val_loss: 0.2436 - val_mean_squared_error: 0.2436
# Epoch 2/200
# 14/14 [==============================] - 0s 20ms/step - loss: 0.2610 - mean_squared_error: 0.2610 - val_loss: 0.2304 - val_mean_squared_error: 0.2304
# Epoch 3/200
# 14/14 [==============================] - 0s 20ms/step - loss: 0.2471 - mean_squared_error: 0.2471 - val_loss: 0.2167 - val_mean_squared_error: 0.2167
# Epoch 4/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.2344 - mean_squared_error: 0.2344 - val_loss: 0.2024 - val_mean_squared_error: 0.2024
# Epoch 5/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.2195 - mean_squared_error: 0.2195 - val_loss: 0.1870 - val_mean_squared_error: 0.1870
# Epoch 6/200
# 14/14 [==============================] - 0s 20ms/step - loss: 0.2047 - mean_squared_error: 0.2047 - val_loss: 0.1703 - val_mean_squared_error: 0.1703
# Epoch 7/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.1901 - mean_squared_error: 0.1901 - val_loss: 0.1521 - val_mean_squared_error: 0.1521
# Epoch 8/200
# 14/14 [==============================] - 0s 20ms/step - loss: 0.1682 - mean_squared_error: 0.1682 - val_loss: 0.1327 - val_mean_squared_error: 0.1327
# Epoch 9/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.1511 - mean_squared_error: 0.1511 - val_loss: 0.1120 - val_mean_squared_error: 0.1120
# Epoch 10/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1292 - mean_squared_error: 0.1292 - val_loss: 0.0900 - val_mean_squared_error: 0.0900
# Epoch 11/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.1073 - mean_squared_error: 0.1073 - val_loss: 0.0677 - val_mean_squared_error: 0.0677
# Epoch 12/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0836 - mean_squared_error: 0.0836 - val_loss: 0.0467 - val_mean_squared_error: 0.0467
# Epoch 13/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0695 - mean_squared_error: 0.0695 - val_loss: 0.0289 - val_mean_squared_error: 0.0289
# Epoch 14/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0510 - mean_squared_error: 0.0510 - val_loss: 0.0157 - val_mean_squared_error: 0.0157
# Epoch 15/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0444 - mean_squared_error: 0.0444 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 16/200
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0394 - mean_squared_error: 0.0394 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 17/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0340 - mean_squared_error: 0.0340 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 18/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0345 - mean_squared_error: 0.0345 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 19/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0341 - mean_squared_error: 0.0341 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 20/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0331 - mean_squared_error: 0.0331 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 21/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0327 - mean_squared_error: 0.0327 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 22/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 23/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0292 - mean_squared_error: 0.0292 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 24/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0292 - mean_squared_error: 0.0292 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 25/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0269 - mean_squared_error: 0.0269 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 26/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0261 - mean_squared_error: 0.0261 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 27/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0257 - mean_squared_error: 0.0257 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 28/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0256 - mean_squared_error: 0.0256 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 29/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 30/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0221 - mean_squared_error: 0.0221 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 31/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 32/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 33/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 34/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 35/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 36/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 37/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 38/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 39/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 40/200
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 41/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 42/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 43/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 44/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 45/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 46/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 47/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 48/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 49/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 50/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 51/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 52/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 53/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 54/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 55/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 56/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 57/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 58/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 59/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 60/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 61/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 62/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 63/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 64/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 65/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 66/200
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 67/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 68/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 69/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 70/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 71/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 72/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 73/200
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 74/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 75/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 76/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 77/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 78/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 79/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 80/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 81/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 82/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 83/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 84/200
# 12/14 [========================>.....] - ETA: 0s - loss: 0.0143 - mean_squared_error: 0.0143Restoring model weights from the end of the best epoch: 34.
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 84: early stopping

# %%
# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)

print(train_predict.shape, y_pred.shape)
# Out:
# 27/27 [==============================] - 1s 4ms/step
# 12/12 [==============================] - 0s 4ms/step
# (858, 1) (366, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, y_test.shape)
# Out:
# (858,) (366,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred
train_predict=scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

#in head
print(y_train[:5])
# Out:
# [0.03174603 0.0270775  0.03081232 0.02240896 0.02240896]

# %%
#Chuẩn hóa ngược lại y_test và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
y_test = y_test.reshape(y_test.shape[0],1)
y_train=scaler.inverse_transform(y_train)
y_test=scaler.inverse_transform(y_test)

#in head
print(y_train[:5])
# Out:
# [[39150.]
#  [38900.]
#  [39100.]
#  [38650.]
#  [38650.]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
from sklearn.metrics import mean_absolute_percentage_error,mean_absolute_error, r2_score, mean_squared_error
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
train_rmse = np.sqrt(np.mean((train_predict - y_train)**2))
print('Testing RMSE:', test_rmse)
print('Training RMSE:', train_rmse)
# 8+. Tính MAPE
test_mape = mean_absolute_percentage_error(y_test, y_pred)
print('Testing MAPE:', test_mape)
train_mape = mean_absolute_percentage_error(y_train, train_predict)
print('Training MAPE:', train_mape)
# 8+. Tính MAE
test_mae = mean_absolute_error(y_test, y_pred)
print('Testing MAE:', test_mae)
train_mae = mean_absolute_error(y_train, train_predict)
print('Training MAE:', train_mae)
# Out:
# Testing RMSE: 2039.6320780049234
# Training RMSE: 3846.6504487132715
# Testing MAPE: 0.02526568087333146
# Training MAPE: 0.05931398625476443
# Testing MAE: 1662.921512124317
# Training MAE: 3291.950712048368

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])


    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (3, 1)
# -----------------
# day  1  have input =  [0.65639589 0.66386555 0.67320261]
# day  1  have output =  0.6078618
# -----------------
# day  2  have input =  [0.66386555 0.67320261 0.60786182]
# day  2  have output =  0.6079896
# -----------------
# day  3  have input =  [0.67320261 0.60786182 0.60798961]
# day  3  have output =  0.59509236
# -----------------
# day  4  have input =  [0.60786182 0.60798961 0.59509236]
# day  4  have output =  0.56162107
# -----------------
# day  5  have input =  [0.60798961 0.59509236 0.56162107]
# day  5  have output =  0.55529255
# -----------------
# day  6  have input =  [0.59509236 0.56162107 0.55529255]
# day  6  have output =  0.5399025
# -----------------
# day  7  have input =  [0.56162107 0.55529255 0.53990251]
# day  7  have output =  0.52106357
# -----------------
# day  8  have input =  [0.55529255 0.53990251 0.52106357]
# day  8  have output =  0.51261544
# -----------------
# day  9  have input =  [0.53990251 0.52106357 0.51261544]
# day  9  have output =  0.50010204
# -----------------
# day  10  have input =  [0.52106357 0.51261544 0.50010204]
# day  10  have output =  0.4883498
# -----------------
# day  11  have input =  [0.51261544 0.50010204 0.4883498 ]
# day  11  have output =  0.48051253
# -----------------
# day  12  have input =  [0.50010204 0.4883498  0.48051253]
# day  12  have output =  0.47142905
# -----------------
# day  13  have input =  [0.4883498  0.48051253 0.47142905]
# day  13  have output =  0.46359158
# -----------------
# day  14  have input =  [0.48051253 0.47142905 0.46359158]
# day  14  have output =  0.45735562
# -----------------
# day  15  have input =  [0.47142905 0.46359158 0.45735562]
# day  15  have output =  0.45103788
# -----------------
# day  16  have input =  [0.46359158 0.45735562 0.45103788]
# day  16  have output =  0.44566977
# -----------------
# day  17  have input =  [0.45735562 0.45103788 0.44566977]
# day  17  have output =  0.44108456
# -----------------
# day  18  have input =  [0.45103788 0.44566977 0.44108456]
# day  18  have output =  0.43676782
# -----------------
# day  19  have input =  [0.44566977 0.44108456 0.43676782]
# day  19  have output =  0.43307883
# -----------------
# day  20  have input =  [0.44108456 0.43676782 0.43307883]
# day  20  have output =  0.42985034
# -----------------
# day  21  have input =  [0.43676782 0.43307883 0.42985034]
# day  21  have output =  0.42692608
# -----------------
# day  22  have input =  [0.43307883 0.42985034 0.42692608]
# day  22  have output =  0.42440546
# -----------------
# day  23  have input =  [0.42985034 0.42692608 0.42440546]
# day  23  have output =  0.4221869
# -----------------
# day  24  have input =  [0.42692608 0.42440546 0.42218691]
# day  24  have output =  0.42021632
# -----------------
# day  25  have input =  [0.42440546 0.42218691 0.42021632]
# day  25  have output =  0.41850692
# -----------------
# day  26  have input =  [0.42218691 0.42021632 0.41850692]
# day  26  have output =  0.4170034
# -----------------
# day  27  have input =  [0.42021632 0.41850692 0.41700339]
# day  27  have output =  0.4156805
# -----------------
# day  28  have input =  [0.41850692 0.41700339 0.4156805 ]
# day  28  have output =  0.41452873
# -----------------
# day  29  have input =  [0.41700339 0.4156805  0.41452873]
# day  29  have output =  0.4135179
# -----------------
# day  30  have input =  [0.4156805  0.41452873 0.41351789]
# day  30  have output =  0.41263247

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='blue', label='Next 30 days')
plt.show()

# %%
#chuẩn hóa ngược lại dữ liệu

train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[40450.]
#  [40000.]
#  [38950.]
#  [39150.]
#  [38900.]]
# [[60900.]
#  [59800.]
#  [58700.]
#  [58500.]
#  [57600.]]
# [[70001.   ]
#  [70007.84 ]
#  [69317.195]
#  [67524.81 ]
#  [67185.914]]

# %%
#vẽ y_train nối với ytest với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=len(df1), step=1)
#val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=len(df1), stop=len(df1)+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
#y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
#plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Predict')
#plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
#plt.xticks(np.arange(0, len(df1), 100), df['Date'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
