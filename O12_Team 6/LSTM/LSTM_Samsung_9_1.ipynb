# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('/content/drive/MyDrive/StockData/SamSung.csv')
df
# Out:
#             Date     Open     High      Low    Close     Adj Close    Volume
# 0     2018-12-12  40250.0  40700.0  40150.0  40450.0  35281.417969  12024279
# 1     2018-12-13  40650.0  40750.0  40000.0  40000.0  34888.921875  26254646
# 2     2018-12-14  40200.0  40200.0  38700.0  38950.0  33973.089844  19671783
# 3     2018-12-17  38650.0  39600.0  38650.0  39150.0  34147.535156  11532968
# 4     2018-12-18  38300.0  39200.0  38300.0  38900.0  33929.472656  11042101
# ...          ...      ...      ...      ...      ...           ...       ...
# 1227  2023-12-06  71800.0  72100.0  71600.0  71700.0  71700.000000   8123087
# 1228  2023-12-07  71800.0  71900.0  71100.0  71500.0  71500.000000   8862017
# 1229  2023-12-08  72100.0  72800.0  71900.0  72600.0  72600.000000  10859463
# 1230  2023-12-11  72800.0  73000.0  72200.0  73000.0  73000.000000   9861960
# 1231  2023-12-12  73300.0  73500.0  73100.0  73500.0  73500.000000  13758646
#
# [1232 rows x 7 columns]

# %%
df1=df.reset_index()['Close']
df1 = df1.dropna() #clean data
df1
# Out:
# 0       40450.0
# 1       40000.0
# 2       38950.0
# 3       39150.0
# 4       38900.0
#          ...
# 1227    71700.0
# 1228    71500.0
# 1229    72600.0
# 1230    73000.0
# 1231    73500.0
# Name: Close, Length: 1232, dtype: float64

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.9 * len(df1))
test_size = int(0.1 * len(df1))

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 \n",
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 3
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape)
# Out:
# (1104, 3, 1) (120, 3, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, LSTM #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import MeanSquaredError

#import cac metrics nhu mse,mae,rmse
from tensorflow.keras import metrics

#import cac loss function nhu mse,mae,rmse,mape
from tensorflow.keras import losses

# Tạo model
model = Sequential()

input_shape = (time_step, 1)
model.add(LSTM(64, input_shape=input_shape, return_sequences=True))
model.add(LSTM(32, input_shape=input_shape, return_sequences=True))
model.add(LSTM(16))


model.add(Dense(5))
model.add(Dropout(0.2))

model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics
model.compile (loss= "mean_squared_error", optimizer=Adam(learning_rate=0.0001), metrics="mean_squared_error")
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=50, restore_best_weights=True)

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=200,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/200
# 18/18 [==============================] - 17s 92ms/step - loss: 0.2549 - mean_squared_error: 0.2549 - val_loss: 0.3494 - val_mean_squared_error: 0.3494
# Epoch 2/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.2365 - mean_squared_error: 0.2365 - val_loss: 0.3237 - val_mean_squared_error: 0.3237
# Epoch 3/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.2170 - mean_squared_error: 0.2170 - val_loss: 0.2967 - val_mean_squared_error: 0.2967
# Epoch 4/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1989 - mean_squared_error: 0.1989 - val_loss: 0.2681 - val_mean_squared_error: 0.2681
# Epoch 5/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.1781 - mean_squared_error: 0.1781 - val_loss: 0.2369 - val_mean_squared_error: 0.2369
# Epoch 6/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1535 - mean_squared_error: 0.1535 - val_loss: 0.2025 - val_mean_squared_error: 0.2025
# Epoch 7/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1320 - mean_squared_error: 0.1320 - val_loss: 0.1658 - val_mean_squared_error: 0.1658
# Epoch 8/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.1068 - mean_squared_error: 0.1068 - val_loss: 0.1278 - val_mean_squared_error: 0.1278
# Epoch 9/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0834 - mean_squared_error: 0.0834 - val_loss: 0.0902 - val_mean_squared_error: 0.0902
# Epoch 10/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0635 - mean_squared_error: 0.0635 - val_loss: 0.0572 - val_mean_squared_error: 0.0572
# Epoch 11/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0543 - mean_squared_error: 0.0543 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
# Epoch 12/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0433 - mean_squared_error: 0.0433 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# Epoch 13/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0399 - mean_squared_error: 0.0399 - val_loss: 0.0123 - val_mean_squared_error: 0.0123
# Epoch 14/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 0.0100 - val_mean_squared_error: 0.0100
# Epoch 15/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 16/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0329 - mean_squared_error: 0.0329 - val_loss: 0.0090 - val_mean_squared_error: 0.0090
# Epoch 17/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0353 - mean_squared_error: 0.0353 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# Epoch 18/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0346 - mean_squared_error: 0.0346 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 19/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0289 - mean_squared_error: 0.0289 - val_loss: 0.0085 - val_mean_squared_error: 0.0085
# Epoch 20/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0304 - mean_squared_error: 0.0304 - val_loss: 0.0087 - val_mean_squared_error: 0.0087
# Epoch 21/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0291 - mean_squared_error: 0.0291 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 22/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0298 - mean_squared_error: 0.0298 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
# Epoch 23/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0293 - mean_squared_error: 0.0293 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
# Epoch 24/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 25/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0259 - mean_squared_error: 0.0259 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
# Epoch 26/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0265 - mean_squared_error: 0.0265 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 27/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 28/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 29/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 30/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0220 - mean_squared_error: 0.0220 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 31/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0212 - mean_squared_error: 0.0212 - val_loss: 0.0051 - val_mean_squared_error: 0.0051
# Epoch 32/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 33/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 34/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 35/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
# Epoch 36/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 37/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 38/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 39/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 40/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 41/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 42/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 43/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 44/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 45/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 46/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 47/200
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 48/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 49/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 50/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 51/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 52/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 53/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 54/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 55/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 56/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 57/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 58/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 59/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 60/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0137 - mean_squared_error: 0.0137 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 61/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0143 - mean_squared_error: 0.0143 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 62/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 63/200
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0142 - mean_squared_error: 0.0142 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 64/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 65/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 66/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 67/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 68/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 69/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0132 - mean_squared_error: 0.0132 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 70/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 71/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 72/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 73/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 74/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 75/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 76/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 77/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 78/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 79/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0134 - mean_squared_error: 0.0134 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 80/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 81/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 82/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 83/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 84/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 85/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 86/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 87/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 88/200
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 89/200
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 90/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 91/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 92/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 93/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 94/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 95/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 96/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 97/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 98/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 99/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 100/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 101/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 102/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 103/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 104/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 105/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 106/200
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 107/200
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 108/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 109/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 110/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 8.8803e-04 - val_mean_squared_error: 8.8803e-04
# Epoch 111/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 112/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 113/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 114/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 115/200
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 116/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 117/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 118/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 119/200
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 120/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 121/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 122/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 123/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 124/200
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 125/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 126/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 7.2891e-04 - val_mean_squared_error: 7.2891e-04
# Epoch 127/200
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 128/200
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 9.6585e-04 - val_mean_squared_error: 9.6585e-04
# Epoch 129/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 130/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 131/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 132/200
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 133/200
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 134/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 135/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 136/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 137/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 138/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 139/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 140/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 141/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 142/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 143/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 144/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 145/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 146/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 9.8489e-04 - val_mean_squared_error: 9.8489e-04
# Epoch 147/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 148/200
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 149/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 150/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 151/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 152/200
# 18/18 [==============================] - 0s 18ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 153/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 8.5327e-04 - val_mean_squared_error: 8.5327e-04
# Epoch 154/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 155/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 156/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 157/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 158/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 9.2539e-04 - val_mean_squared_error: 9.2539e-04
# Epoch 159/200
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 160/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 8.1216e-04 - val_mean_squared_error: 8.1216e-04
# Epoch 161/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 162/200
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 8.1426e-04 - val_mean_squared_error: 8.1426e-04
# Epoch 163/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 164/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0105 - mean_squared_error: 0.0105 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 165/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 166/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 167/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 8.7151e-04 - val_mean_squared_error: 8.7151e-04
# Epoch 168/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 169/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 170/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 171/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 9.0489e-04 - val_mean_squared_error: 9.0489e-04
# Epoch 172/200
# 18/18 [==============================] - 0s 11ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 173/200
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 174/200
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 175/200
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 8.6286e-04 - val_mean_squared_error: 8.6286e-04
# Epoch 176/200
# 18/18 [==============================] - ETA: 0s - loss: 0.0092 - mean_squared_error: 0.0092Restoring model weights from the end of the best epoch: 126.
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0092 - mean_squared_error: 0.0092 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 176: early stopping

# %%
# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)

print(train_predict.shape, y_pred.shape)
# Out:
# 35/35 [==============================] - 1s 4ms/step
# 4/4 [==============================] - 0s 5ms/step
# (1104, 1) (120, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, y_test.shape)
# Out:
# (1104,) (120,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred
train_predict=scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

#in head
print(y_train[:5])
# Out:
# [0.03174603 0.0270775  0.03081232 0.02240896 0.02240896]

# %%
#Chuẩn hóa ngược lại y_test và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
y_test = y_test.reshape(y_test.shape[0],1)
y_train=scaler.inverse_transform(y_train)
y_test=scaler.inverse_transform(y_test)

#in head
print(y_train[:5])
# Out:
# [[39150.]
#  [38900.]
#  [39100.]
#  [38650.]
#  [38650.]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
from sklearn.metrics import mean_absolute_percentage_error,mean_absolute_error, r2_score, mean_squared_error
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
train_rmse = np.sqrt(np.mean((train_predict - y_train)**2))
print('Testing RMSE:', test_rmse)
print('Training RMSE:', train_rmse)
# 8+. Tính MAPE
test_mape = mean_absolute_percentage_error(y_test, y_pred)
print('Testing MAPE:', test_mape)
train_mape = mean_absolute_percentage_error(y_train, train_predict)
print('Training MAPE:', train_mape)
# 8+. Tính MAE
test_mae = mean_absolute_error(y_test, y_pred)
print('Testing MAE:', test_mae)
train_mae = mean_absolute_error(y_train, train_predict)
print('Training MAE:', train_mae)
# Out:
# Testing RMSE: 1445.76387799954
# Training RMSE: 1703.9604909579052
# Testing MAPE: 0.015367746233246611
# Training MAPE: 0.022568746480517737
# Testing MAE: 1082.83662109375
# Training MAE: 1305.1123400701993

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])


    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (3, 1)
# -----------------
# day  1  have input =  [0.65639589 0.66386555 0.67320261]
# day  1  have output =  0.64948225
# -----------------
# day  2  have input =  [0.66386555 0.67320261 0.64948225]
# day  2  have output =  0.65467757
# -----------------
# day  3  have input =  [0.67320261 0.64948225 0.65467757]
# day  3  have output =  0.65364665
# -----------------
# day  4  have input =  [0.64948225 0.65467757 0.65364665]
# day  4  have output =  0.6403197
# -----------------
# day  5  have input =  [0.65467757 0.65364665 0.64031971]
# day  5  have output =  0.641905
# -----------------
# day  6  have input =  [0.65364665 0.64031971 0.64190501]
# day  6  have output =  0.63726026
# -----------------
# day  7  have input =  [0.64031971 0.64190501 0.63726026]
# day  7  have output =  0.62894195
# -----------------
# day  8  have input =  [0.64190501 0.63726026 0.62894195]
# day  8  have output =  0.6276428
# -----------------
# day  9  have input =  [0.63726026 0.62894195 0.62764281]
# day  9  have output =  0.62200516
# -----------------
# day  10  have input =  [0.62894195 0.62764281 0.62200516]
# day  10  have output =  0.61582047
# -----------------
# day  11  have input =  [0.62764281 0.62200516 0.61582047]
# day  11  have output =  0.6126197
# -----------------
# day  12  have input =  [0.62200516 0.61582047 0.6126197 ]
# day  12  have output =  0.6068349
# -----------------
# day  13  have input =  [0.61582047 0.6126197  0.60683489]
# day  13  have output =  0.60137844
# -----------------
# day  14  have input =  [0.6126197  0.60683489 0.60137844]
# day  14  have output =  0.5970165
# -----------------
# day  15  have input =  [0.60683489 0.60137844 0.59701651]
# day  15  have output =  0.5912534
# -----------------
# day  16  have input =  [0.60137844 0.59701651 0.5912534 ]
# day  16  have output =  0.585897
# -----------------
# day  17  have input =  [0.59701651 0.5912534  0.58589703]
# day  17  have output =  0.58083135
# -----------------
# day  18  have input =  [0.5912534  0.58589703 0.58083135]
# day  18  have output =  0.57504994
# -----------------
# day  19  have input =  [0.58589703 0.58083135 0.57504994]
# day  19  have output =  0.569544
# -----------------
# day  20  have input =  [0.58083135 0.57504994 0.56954402]
# day  20  have output =  0.5640286
# -----------------
# day  21  have input =  [0.57504994 0.56954402 0.56402862]
# day  21  have output =  0.558157
# -----------------
# day  22  have input =  [0.56954402 0.56402862 0.55815703]
# day  22  have output =  0.55242354
# -----------------
# day  23  have input =  [0.56402862 0.55815703 0.55242354]
# day  23  have output =  0.54659367
# -----------------
# day  24  have input =  [0.55815703 0.55242354 0.54659367]
# day  24  have output =  0.5405831
# -----------------
# day  25  have input =  [0.55242354 0.54659367 0.54058307]
# day  25  have output =  0.53461796
# -----------------
# day  26  have input =  [0.54659367 0.54058307 0.53461796]
# day  26  have output =  0.52855074
# -----------------
# day  27  have input =  [0.54058307 0.53461796 0.52855074]
# day  27  have output =  0.5223853
# -----------------
# day  28  have input =  [0.53461796 0.52855074 0.5223853 ]
# day  28  have output =  0.51621735
# -----------------
# day  29  have input =  [0.52855074 0.5223853  0.51621735]
# day  29  have output =  0.5099676
# -----------------
# day  30  have input =  [0.5223853  0.51621735 0.50996763]
# day  30  have output =  0.50366133

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='blue', label='Next 30 days')
plt.show()

# %%
#chuẩn hóa ngược lại dữ liệu

train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[40450.]
#  [40000.]
#  [38950.]
#  [39150.]
#  [38900.]]
# [[71900.]
#  [71500.]
#  [71800.]
#  [71200.]
#  [71400.]]
# [[72229.77 ]
#  [72507.984]
#  [72452.77 ]
#  [71739.125]
#  [71824.01 ]]

# %%
#vẽ y_train nối với ytest với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=len(df1), step=1)
#val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=len(df1), stop=len(df1)+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
#y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
#plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Predict')
#plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
#plt.xticks(np.arange(0, len(df1), 100), df['Date'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
