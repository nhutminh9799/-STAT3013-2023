# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Conv1D, MaxPooling1D, Bidirectional
from keras.optimizers import SGD
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('/content/drive/MyDrive/StockData/NOK.csv')
df
# Out:
#             Date  Open  High   Low  Close  Adj Close    Volume
# 0     2018-12-12  5.95  6.06  5.93   6.04   5.592633  48348500
# 1     2018-12-13  5.98  6.05  5.97   6.03   5.583373  31790800
# 2     2018-12-14  5.91  6.01  5.89   5.94   5.500039  17796500
# 3     2018-12-17  5.94  5.95  5.85   5.87   5.435223  26578100
# 4     2018-12-18  5.88  5.90  5.76   5.78   5.351890  19722400
# ...          ...   ...   ...   ...    ...        ...       ...
# 1253  2023-12-05  2.96  3.04  2.94   3.00   3.000000  44622900
# 1254  2023-12-06  3.05  3.09  3.01   3.01   3.010000  30193200
# 1255  2023-12-07  3.05  3.12  3.02   3.10   3.100000  24122200
# 1256  2023-12-08  3.19  3.22  3.16   3.18   3.180000  14533600
# 1257  2023-12-11  3.14  3.17  3.11   3.12   3.120000  22015800
#
# [1258 rows x 7 columns]

# %%
df1=df.reset_index()['Close']
df1 = df1.dropna() #clean data
df1
# Out:
# 0       6.04
# 1       6.03
# 2       5.94
# 3       5.87
# 4       5.78
#         ...
# 1253    3.00
# 1254    3.01
# 1255    3.10
# 1256    3.18
# 1257    3.12
# Name: Close, Length: 1258, dtype: float64

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = int(0.3 * len(df1))

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100 \n",
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
#6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 3
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

#in shape của từng tập dư liệu
print(X_train.shape, X_test.shape)
# Out:
# (876, 3, 1) (374, 3, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import  Dense, Dropout, LSTM #thêm thư viện Dropout để tránh overfitting
from tensorflow.keras.callbacks import EarlyStopping
#import adam
from tensorflow.keras.optimizers import Adam
#import thư viện mean_squared_error
from tensorflow.keras.losses import MeanSquaredError

#import cac metrics nhu mse,mae,rmse
from tensorflow.keras import metrics

#import cac loss function nhu mse,mae,rmse,mape
from tensorflow.keras import losses

# Tạo model
model = Sequential()

input_shape = (time_step, 1)
model.add(LSTM(64, input_shape=input_shape, return_sequences=True))
model.add(LSTM(32, input_shape=input_shape, return_sequences=True))
model.add(LSTM(16))


model.add(Dense(5))
model.add(Dropout(0.2))

model.add(Dense(1))

# Compile model với các tham số: optimizer, loss, metrics
model.compile (loss= "mean_squared_error", optimizer=Adam(learning_rate=0.0001), metrics="mean_squared_error")
early_stop = EarlyStopping(monitor='val_loss', verbose=1,patience=50, restore_best_weights=True)

# %%
# 9. Fit mô hình với dữ liệu train
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=200,batch_size=64,verbose=1,callbacks=[early_stop])
# Out:
# Epoch 1/200
# 14/14 [==============================] - 9s 187ms/step - loss: 0.3593 - mean_squared_error: 0.3593 - val_loss: 0.2012 - val_mean_squared_error: 0.2012
# Epoch 2/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.3315 - mean_squared_error: 0.3315 - val_loss: 0.1810 - val_mean_squared_error: 0.1810
# Epoch 3/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.3031 - mean_squared_error: 0.3031 - val_loss: 0.1607 - val_mean_squared_error: 0.1607
# Epoch 4/200
# 14/14 [==============================] - 0s 20ms/step - loss: 0.2731 - mean_squared_error: 0.2731 - val_loss: 0.1402 - val_mean_squared_error: 0.1402
# Epoch 5/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.2442 - mean_squared_error: 0.2442 - val_loss: 0.1193 - val_mean_squared_error: 0.1193
# Epoch 6/200
# 14/14 [==============================] - 0s 20ms/step - loss: 0.2164 - mean_squared_error: 0.2164 - val_loss: 0.0984 - val_mean_squared_error: 0.0984
# Epoch 7/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1847 - mean_squared_error: 0.1847 - val_loss: 0.0776 - val_mean_squared_error: 0.0776
# Epoch 8/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.1508 - mean_squared_error: 0.1508 - val_loss: 0.0575 - val_mean_squared_error: 0.0575
# Epoch 9/200
# 14/14 [==============================] - 0s 20ms/step - loss: 0.1224 - mean_squared_error: 0.1224 - val_loss: 0.0391 - val_mean_squared_error: 0.0391
# Epoch 10/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0937 - mean_squared_error: 0.0937 - val_loss: 0.0238 - val_mean_squared_error: 0.0238
# Epoch 11/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0714 - mean_squared_error: 0.0714 - val_loss: 0.0132 - val_mean_squared_error: 0.0132
# Epoch 12/200
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0474 - mean_squared_error: 0.0474 - val_loss: 0.0078 - val_mean_squared_error: 0.0078
# Epoch 13/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0401 - mean_squared_error: 0.0401 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
# Epoch 14/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0336 - mean_squared_error: 0.0336 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 15/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
# Epoch 16/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0331 - mean_squared_error: 0.0331 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
# Epoch 17/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0317 - mean_squared_error: 0.0317 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
# Epoch 18/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0349 - mean_squared_error: 0.0349 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
# Epoch 19/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0325 - mean_squared_error: 0.0325 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 20/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0329 - mean_squared_error: 0.0329 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
# Epoch 21/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0277 - mean_squared_error: 0.0277 - val_loss: 0.0070 - val_mean_squared_error: 0.0070
# Epoch 22/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0317 - mean_squared_error: 0.0317 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 23/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0330 - mean_squared_error: 0.0330 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
# Epoch 24/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0330 - mean_squared_error: 0.0330 - val_loss: 0.0069 - val_mean_squared_error: 0.0069
# Epoch 25/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0314 - mean_squared_error: 0.0314 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 26/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0292 - mean_squared_error: 0.0292 - val_loss: 0.0059 - val_mean_squared_error: 0.0059
# Epoch 27/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0282 - mean_squared_error: 0.0282 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 28/200
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0310 - mean_squared_error: 0.0310 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
# Epoch 29/200
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0256 - mean_squared_error: 0.0256 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 30/200
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0255 - mean_squared_error: 0.0255 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 31/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0306 - mean_squared_error: 0.0306 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
# Epoch 32/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0323 - mean_squared_error: 0.0323 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 33/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0270 - mean_squared_error: 0.0270 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 34/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0268 - mean_squared_error: 0.0268 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
# Epoch 35/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0263 - mean_squared_error: 0.0263 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 36/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
# Epoch 37/200
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 38/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 39/200
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0256 - mean_squared_error: 0.0256 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 40/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 41/200
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 42/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.
200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 178/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 179/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 180/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 181/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 182/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 183/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 184/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 185/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 186/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 187/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 188/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 189/200
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 190/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 191/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 192/200
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 193/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 194/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 195/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 196/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 197/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 198/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 199/200
# 14/14 [==============================] - 0s 22ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 200/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0018 - val_mean_squared_error: 0.0018

# %%
# 10. Dự báo dữ liệu test
train_predict=model.predict(X_train)
y_pred=model.predict(X_test)

print(train_predict.shape, y_pred.shape)
# Out:
# 28/28 [==============================] - 1s 4ms/step
# 12/12 [==============================] - 0s 4ms/step
# (876, 1) (374, 1)

# %%
#in shape của từng tập dư liệu y real
print(y_train.shape, y_test.shape)
# Out:
# (876,) (374,)

# %%
# 11. Chuẩn hóa dữ liệu y_pred
train_predict=scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

#in head
print(y_train[:5])
# Out:
# [0.82535885 0.80382775 0.80143541 0.79904306 0.73444976]

# %%
#Chuẩn hóa ngược lại y_test và y_train sau khi đã reshape
y_train = y_train.reshape(y_train.shape[0],1)
y_test = y_test.reshape(y_test.shape[0],1)
y_train=scaler.inverse_transform(y_train)
y_test=scaler.inverse_transform(y_test)

#in head
print(y_train[:5])
# Out:
# [[5.87]
#  [5.78]
#  [5.77]
#  [5.76]
#  [5.49]]

# %%
# 12. Đánh giá độ chính xác thuật toán bằng RMSE
from sklearn.metrics import mean_absolute_percentage_error,mean_absolute_error, r2_score, mean_squared_error
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
train_rmse = np.sqrt(np.mean((train_predict - y_train)**2))
print('Testing RMSE:', test_rmse)
print('Training RMSE:', train_rmse)
# 8+. Tính MAPE
test_mape = mean_absolute_percentage_error(y_test, y_pred)
print('Testing MAPE:', test_mape)
train_mape = mean_absolute_percentage_error(y_train, train_predict)
print('Training MAPE:', train_mape)
# 8+. Tính MAE
test_mae = mean_absolute_error(y_test, y_pred)
print('Testing MAE:', test_mae)
train_mae = mean_absolute_error(y_train, train_predict)
print('Training MAE:', train_mae)
# Out:
# Testing RMSE: 0.1768791438753737
# Training RMSE: 0.2352029466535874
# Testing MAPE: 0.031829551264781104
# Training MAPE: 0.0361634632962175
# Testing MAE: 0.14033469141485858
# Training MAE: 0.17219106779795257

# %%
# Chuẩn bị dữ liệu cho dự đoán tiếp theo

# Lấy time_step ngày cuối cùng của dữ liệu train để dự đoán 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(-1, 1)   #[-time_step:] lấy time_step phần tử cuối cùng của dữ liệu
print("x_input.shape = ", x_input.shape)

# Dự đoán 30 ngày tiếp theo
lst_output = []

i = 1  #biến đếm để dừng vòng lặp while
while(i <= 30):
    print("-----------------")
    #dua ve mang array 1 chieu
    list_input = x_input.reshape(1, -1)[0]
    #in ra x_input cuar ngày thứ i trong 30 ngày tiếp theo
    print("day ", i, " have input = ", list_input)

    # Dự đoán giá đóng của ngày tiếp theo
    x_input = x_input.reshape(1, time_step, 1) #reshape lại về dạng (1, time_step, 1)
    yhat = model.predict(x_input, verbose=0) #dự đoán giá đóng của ngày tiếp theo

    #in ra giá đóng của ngày thứ i trong 30 ngày tiếp theo
    print("day ",i," have output = ", yhat[0][0])

    #thêm giá đóng của ngày thứ i vào lst_output
    lst_output.append(yhat[0][0])

    #xoa phan tu dau tien cua x_input
    x_input = np.delete(x_input, 0)
    #them yhat vao x_input
    x_input = np.append(x_input, yhat[0][0])


    #tang bien dem len 1
    i = i + 1
# Out:
# x_input.shape =  (3, 1)
# -----------------
# day  1  have input =  [0.16267943 0.18181818 0.16746411]
# day  1  have output =  0.21490264
# -----------------
# day  2  have input =  [0.18181818 0.16746411 0.21490264]
# day  2  have output =  0.22270916
# -----------------
# day  3  have input =  [0.16746411 0.21490264 0.22270916]
# day  3  have output =  0.22742254
# -----------------
# day  4  have input =  [0.21490264 0.22270916 0.22742254]
# day  4  have output =  0.24801883
# -----------------
# day  5  have input =  [0.22270916 0.22742254 0.24801883]
# day  5  have output =  0.25368196
# -----------------
# day  6  have input =  [0.22742254 0.24801883 0.25368196]
# day  6  have output =  0.260414
# -----------------
# day  7  have input =  [0.24801883 0.25368196 0.260414  ]
# day  7  have output =  0.27052623
# -----------------
# day  8  have input =  [0.25368196 0.260414   0.27052623]
# day  8  have output =  0.27510613
# -----------------
# day  9  have input =  [0.260414   0.27052623 0.27510613]
# day  9  have output =  0.28046674
# -----------------
# day  10  have input =  [0.27052623 0.27510613 0.28046674]
# day  10  have output =  0.28610286
# -----------------
# day  11  have input =  [0.27510613 0.28046674 0.28610286]
# day  11  have output =  0.2896583
# -----------------
# day  12  have input =  [0.28046674 0.28610286 0.28965831]
# day  12  have output =  0.29345256
# -----------------
# day  13  have input =  [0.28610286 0.28965831 0.29345256]
# day  13  have output =  0.29693037
# -----------------
# day  14  have input =  [0.28965831 0.29345256 0.29693037]
# day  14  have output =  0.29957086
# -----------------
# day  15  have input =  [0.29345256 0.29693037 0.29957086]
# day  15  have output =  0.30218124
# -----------------
# day  16  have input =  [0.29693037 0.29957086 0.30218124]
# day  16  have output =  0.304472
# -----------------
# day  17  have input =  [0.29957086 0.30218124 0.304472  ]
# day  17  have output =  0.306379
# -----------------
# day  18  have input =  [0.30218124 0.304472   0.30637899]
# day  18  have output =  0.30817294
# -----------------
# day  19  have input =  [0.304472   0.30637899 0.30817294]
# day  19  have output =  0.30973655
# -----------------
# day  20  have input =  [0.30637899 0.30817294 0.30973655]
# day  20  have output =  0.31109366
# -----------------
# day  21  have input =  [0.30817294 0.30973655 0.31109366]
# day  21  have output =  0.31233445
# -----------------
# day  22  have input =  [0.30973655 0.31109366 0.31233445]
# day  22  have output =  0.31342086
# -----------------
# day  23  have input =  [0.31109366 0.31233445 0.31342086]
# day  23  have output =  0.31438023
# -----------------
# day  24  have input =  [0.31233445 0.31342086 0.31438023]
# day  24  have output =  0.31524444
# -----------------
# day  25  have input =  [0.31342086 0.31438023 0.31524444]
# day  25  have output =  0.3160057
# -----------------
# day  26  have input =  [0.31438023 0.31524444 0.31600571]
# day  26  have output =  0.31668234
# -----------------
# day  27  have input =  [0.31524444 0.31600571 0.31668234]
# day  27  have output =  0.31728756
# -----------------
# day  28  have input =  [0.31600571 0.31668234 0.31728756]
# day  28  have output =  0.31782317
# -----------------
# day  29  have input =  [0.31668234 0.31728756 0.31782317]
# day  29  have output =  0.31830028
# -----------------
# day  30  have input =  [0.31728756 0.31782317 0.31830028]
# day  30  have output =  0.31872573

# %%
# Tạo mảng index tương ứng với các ngày
days = np.array(range(len(df), len(df) + len(lst_output)))

#vẽ next 30 days
plt.figure(figsize=(20,10))
plt.plot(days, lst_output, c='blue', label='Next 30 days')
plt.show()

# %%
#chuẩn hóa ngược lại dữ liệu

train_data_inverse=scaler.inverse_transform(np.array(train_data).reshape(-1, 1))
test_data_inverse=scaler.inverse_transform(np.array(test_data).reshape(-1, 1))
next_30_days_inverse=scaler.inverse_transform(np.array(lst_output).reshape(-1, 1))

# in dữ liệu
print(train_data_inverse[:5])
print(test_data_inverse[:5])
print(next_30_days_inverse[:5])
# Out:
# [[6.04]
#  [6.03]
#  [5.94]
#  [5.87]
#  [5.78]]
# [[4.7 ]
#  [4.57]
#  [4.67]
#  [4.76]
#  [4.58]]
# [[3.318293 ]
#  [3.3509243]
#  [3.3706262]
#  [3.456719 ]
#  [3.4803905]]

# %%
#vẽ y_train nối với ytest và y_val với index tương ứng

train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
test_data_index = pd.RangeIndex(start=train_size, stop=len(df1), step=1)
#val_data_index = pd.RangeIndex(start=train_size+test_size, stop=train_size+test_size+val_size, step=1)
predict30_data_index = pd.RangeIndex(start=len(df1), stop=len(df1)+30, step=1)

train_predict_index = pd.RangeIndex(start=0, stop=train_predict.shape[0], step=1)
y_pred_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0], step=1)
#y_pred_val_index = pd.RangeIndex(start=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+(val_size-y_pred_val.shape[0]), stop=train_size+(train_size-train_predict.shape[0])+y_pred.shape[0]+y_pred_val.shape[0]+(val_size-y_pred_val.shape[0]), step=1)

plt.plot(train_data_index, train_data_inverse,  label='Train data')
plt.plot(test_data_index, test_data_inverse, label='Test data')
#plt.plot(val_data_index, val_data_inverse,  label='Val data')
plt.plot(predict30_data_index, next_30_days_inverse, label='Predict 30 days')
plt.plot(y_pred_index, y_pred, label='Predict')
#plt.plot(y_pred_val_index, y_pred_val,  label='Val predict')
# trục x là giá trị của cột Close time của df1
#plt.xticks(np.arange(0, len(df1), 100), df['Date'][0:len(df):100])
#xoay ngang giá trị của trục x
plt.xticks(rotation=60)
plt.legend()
plt.show()
