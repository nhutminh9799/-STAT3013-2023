# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy.polynomial.polynomial as poly
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm

from datetime import datetime
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.utils import column_or_1d

# %%
GRAB = pd.read_csv("/content/drive/MyDrive/GRAB.csv")

# %% [markdown]
# Date: yy-mm-dd
#
# Open: Opening Price of Stock
#
# High: Highest Price of Stock on the particular day
#
# Low: Lowest Price of Stock on the particular day
#
# Close: Closing Price of Stock
#
# Adj Close: Adjusted Closing Price of Stock
#
# Volume: Volume of Shares Traded

# %%
GRAB
# Out:
#            Date    Open    High    Low  Close  Adj Close    Volume
# 0    2021-12-01  13.595  13.630  11.01  11.01      11.01   8964400
# 1    2021-12-02  13.055  13.290   8.13   8.75       8.75  35751200
# 2    2021-12-03   9.160   9.520   8.45   8.99       8.99  29667200
# 3    2021-12-06   8.950   9.100   8.23   9.00       9.00  25416000
# 4    2021-12-07   9.055   9.060   8.32   8.85       8.85  25775900
# ..          ...     ...     ...    ...    ...        ...       ...
# 502  2023-11-30   3.020   3.094   3.00   3.04       3.04  50506600
# 503  2023-12-01   3.040   3.120   3.04   3.07       3.07  23317000
# 504  2023-12-04   3.090   3.185   3.08   3.15       3.15  25401800
# 505  2023-12-05   3.120   3.165   3.10   3.14       3.14  18192800
# 506  2023-12-06   3.150   3.180   3.08   3.09       3.09  25806500
#
# [507 rows x 7 columns]

# %% [markdown]
# # 2. Tiền xử lý dữ liệu
#
#   ##  Loại bỏ một số dữ liệu trống trong dataset

# %%
# Drop missing values
GRAB = GRAB.dropna()
# Reset the index
GRAB = GRAB.reset_index(drop=True)

# %% [markdown]
# ## Chuyển dữ liệu cột Price sang dạng float

# %%
GRAB["Close"]=GRAB["Close"].astype(float)

# %% [markdown]
# # 3. Trực quan hóa tập dữ liệu ban đầu bằng biểu đồ

# %%
plt.figure(figsize=(16,5))
plt.plot(GRAB["Close"])
plt.title('Closing Price of Stock')
plt.grid(True)
plt.show()

# %% [markdown]
# # 4. Chia tập dữ liệu để train-test-validate theo tỉ lệ 7:2:1

# %%
# Split the data into training, testing, and validation sets
train_size = int(0.7 * len(GRAB))
test_size = int(0.2 * len(GRAB))
val_size = len(GRAB) - train_size - test_size

# %%
train_data = GRAB[:train_size]
test_data = GRAB[train_size:train_size+test_size]
val_data = GRAB[train_size+test_size:]

# %% [markdown]
# ## Quá trình training

# %%
#Training data
x_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data['Close'])

# Train the linear regression model
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Quá trình testing

# %%
# Testing data
x_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data['Close'])
y_pred = model.predict(x_test)

# %% [markdown]
# ## Quá trình validate

# %%
#Validate data
x_val= np.array(val_data.index).reshape(-1, 1)
y_val = np.array(val_data['Close'])
y_pred_val =  model.predict(x_val)

# %% [markdown]
# ## Quá trình dự đoán giá open trong 30 ngày tiếp theo

# %%
#Tạo index cho 30 ngày tiếp theo
last_index =  GRAB.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)

#Tạo một mảng gồm 30 số nguyên liên tiếp bắt đầu từ last_index
x_next_30_days = np.array(range(last_index+1, last_index+31)).reshape(-1, 1)

#Dự đoán giá đóng cửa của cổ phiếu trong 30 ngày tiếp theo
y_next_30_days = model.predict(x_next_30_days)

print('Predicted for the next 30 days:')
print(y_next_30_days)
# Out:
# Predicted for the next 30 days:
# [0.76482373 0.75602776 0.74723179 0.73843582 0.72963984 0.72084387
#  0.7120479  0.70325193 0.69445595 0.68565998 0.67686401 0.66806804
#  0.65927206 0.65047609 0.64168012 0.63288415 0.62408817 0.6152922
#  0.60649623 0.59770025 0.58890428 0.58010831 0.57131234 0.56251636
#  0.55372039 0.54492442 0.53612845 0.52733247 0.5185365  0.50974053]

# %% [markdown]
# ## Đánh giá độ chính xác của thuật toán

# %%
#RMSE
valid_rmse = np.sqrt(np.mean((y_pred_val - y_val)**2))
test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
print('Validation RMSE:', valid_rmse)
print('Testing RMSE:', test_rmse)
# Out:
# Validation RMSE: 2.271756497388433
# Testing RMSE: 1.8028323168721117

# %%
#MAE
valid_mae = mean_absolute_error(y_val,y_pred_val)
test_mae = mean_absolute_error(y_test, y_pred)
print('Validation MAE:', valid_mae)
print('Testing MAE:', test_mae)
# Out:
# Validation MAE: 2.269390692363836
# Testing MAE: 1.7356267429902883

# %%
#MAPE
valid_mape = np.mean(np.abs((y_val - y_pred_val) / y_val))*100
test_mape = np.mean(np.abs((y_test - y_pred) / y_test))*100
print('Validation MAPE:', valid_mape)
print('Testing MAPE:', test_mape)
# Out:
# Validation MAPE: 69.53179385485376
# Testing MAPE: 50.178576083743174

# %% [markdown]
# ## Vẽ hình mô tả dự đoán

# %%
#Drawing plot
plt.figure(figsize=(16,5))
plt.title("Dự đoán giá Closing GRAB trong 30 ngày kế tiếp theo tỉ lệ 7-2-1")
plt.grid(True)
plt.plot(train_data.index, train_data['Close'])
plt.plot(test_data.index, test_data['Close'])
plt.plot(val_data.index, val_data['Close'])
plt.plot(test_data.index, y_pred)
plt.plot(val_data.index, y_pred_val)
plt.plot(last_data,y_next_30_days, color ="pink")
plt.legend(['Train', 'Test', 'Validate','Test Predictions','Validate Predictions','Next30Day Predictions'])
plt.show()
