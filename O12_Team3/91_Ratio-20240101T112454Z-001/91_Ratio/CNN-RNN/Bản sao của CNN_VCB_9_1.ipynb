# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

# %%
# 2. Đọc file CSV và thiết lập chỉ số là giá 'Close'
df = pd.read_csv('/content/drive/MyDrive/Final/VCB_Stock_Data.csv')
df1 = df.reset_index()['Close']
df1 = df1[~np.isnan(df1)]
df1
# Out:
# 0       12181.833984
# 8       11925.374023
# 9       11882.630859
# 10      12096.347656
# 11      12096.347656
#             ...
# 2554    85200.000000
# 2555    85000.000000
# 2556    84200.000000
# 2557    84200.000000
# 2558    83700.000000
# Name: Close, Length: 2459, dtype: float64

# %%
# 3. Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# %%
# 4. Chia dữ liệu thành tập huấn luyện và tập kiểm thử ti lệ 90% và 10%
train_size = int(0.9 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]

# %%
# 5. Tạo hàm tạo dataset
import numpy
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# 6. Reshape dữ liệu cho việc huấn luyện
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
 # 7. Reshape input to be [samples, time steps, features] which is required for RNN
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# 8. Định nghĩa mô hình CNN
model_cnn = Sequential()
model_cnn.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(time_step, 1)))
model_cnn.add(MaxPooling1D(pool_size=2))
model_cnn.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model_cnn.add(MaxPooling1D(pool_size=2))
model_cnn.add(Flatten())
model_cnn.add(Dense(50, activation='relu'))
model_cnn.add(Dense(1))
model_cnn.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Huấn luyện mô hình với dữ liệu huấn luyện
model_cnn.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 0s 15ms/step - loss: 3.6714e-04
# Epoch 2/100
# 33/33 [==============================] - 1s 16ms/step - loss: 4.0220e-04
# Epoch 3/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.5264e-04
# Epoch 4/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.6679e-04
# Epoch 5/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.7299e-04
# Epoch 6/100
# 33/33 [==============================] - 1s 41ms/step - loss: 3.4486e-04
# Epoch 7/100
# 33/33 [==============================] - 1s 40ms/step - loss: 3.5263e-04
# Epoch 8/100
# 33/33 [==============================] - 2s 46ms/step - loss: 4.2137e-04
# Epoch 9/100
# 33/33 [==============================] - 1s 32ms/step - loss: 4.7476e-04
# Epoch 10/100
# 33/33 [==============================] - 1s 35ms/step - loss: 3.5392e-04
# Epoch 11/100
# 33/33 [==============================] - 1s 32ms/step - loss: 3.5770e-04
# Epoch 12/100
# 33/33 [==============================] - 1s 27ms/step - loss: 3.3181e-04
# Epoch 13/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.5971e-04
# Epoch 14/100
# 33/33 [==============================] - 1s 15ms/step - loss: 4.6448e-04
# Epoch 15/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.4758e-04
# Epoch 16/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.6538e-04
# Epoch 17/100
# 33/33 [==============================] - 1s 16ms/step - loss: 4.0871e-04
# Epoch 18/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.4413e-04
# Epoch 19/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.4428e-04
# Epoch 20/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.3590e-04
# Epoch 21/100
# 33/33 [==============================] - 1s 17ms/step - loss: 3.4466e-04
# Epoch 22/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.8337e-04
# Epoch 23/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.5935e-04
# Epoch 24/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.4344e-04
# Epoch 25/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.7065e-04
# Epoch 26/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.3850e-04
# Epoch 27/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.8585e-04
# Epoch 28/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.3331e-04
# Epoch 29/100
# 33/33 [==============================] - 1s 19ms/step - loss: 3.8377e-04
# Epoch 30/100
# 33/33 [==============================] - 1s 27ms/step - loss: 3.4913e-04
# Epoch 31/100
# 33/33 [==============================] - 2s 47ms/step - loss: 3.4751e-04
# Epoch 32/100
# 33/33 [==============================] - 1s 30ms/step - loss: 3.2156e-04
# Epoch 33/100
# 33/33 [==============================] - 1s 24ms/step - loss: 3.9914e-04
# Epoch 34/100
# 33/33 [==============================] - 1s 25ms/step - loss: 3.9139e-04
# Epoch 35/100
# 33/33 [==============================] - 1s 24ms/step - loss: 4.4035e-04
# Epoch 36/100
# 33/33 [==============================] - 1s 20ms/step - loss: 3.4216e-04
# Epoch 37/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.7077e-04
# Epoch 38/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.9535e-04
# Epoch 39/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.8708e-04
# Epoch 40/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.5615e-04
# Epoch 41/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.2371e-04
# Epoch 42/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.1564e-04
# Epoch 43/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.6316e-04
# Epoch 44/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.5879e-04
# Epoch 45/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.1069e-04
# Epoch 46/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.3232e-04
# Epoch 47/100
# 33/33 [==============================] - 1s 16ms/step - loss: 4.0909e-04
# Epoch 48/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.4578e-04
# Epoch 49/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.4605e-04
# Epoch 50/100
# 33/33 [==============================] - 0s 15ms/step - loss: 3.4667e-04
# Epoch 51/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.9819e-04
# Epoch 52/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.6822e-04
# Epoch 53/100
# 33/33 [==============================] - 1s 16ms/step - loss: 4.3536e-04
# Epoch 54/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.2403e-04
# Epoch 55/100
# 33/33 [==============================] - 1s 20ms/step - loss: 3.3491e-04
# Epoch 56/100
# 33/33 [==============================] - 1s 25ms/step - loss: 3.5551e-04
# Epoch 57/100
# 33/33 [==============================] - 1s 24ms/step - loss: 3.4405e-04
# Epoch 58/100
# 33/33 [==============================] - 1s 25ms/step - loss: 3.3399e-04
# Epoch 59/100
# 33/33 [==============================] - 1s 24ms/step - loss: 3.2389e-04
# Epoch 60/100
# 33/33 [==============================] - 1s 26ms/step - loss: 3.4942e-04
# Epoch 61/100
# 33/33 [==============================] - 1s 25ms/step - loss: 3.1854e-04
# Epoch 62/100
# 33/33 [==============================] - 1s 26ms/step - loss: 3.8017e-04
# Epoch 63/100
# 33/33 [==============================] - 1s 18ms/step - loss: 3.1968e-04
# Epoch 64/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.0701e-04
# Epoch 65/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.0259e-04
# Epoch 66/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.1488e-04
# Epoch 67/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.5472e-04
# Epoch 68/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.1956e-04
# Epoch 69/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.1789e-04
# Epoch 70/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.1798e-04
# Epoch 71/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.2546e-04
# Epoch 72/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.1109e-04
# Epoch 73/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.4989e-04
# Epoch 74/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.5466e-04
# Epoch 75/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.1183e-04
# Epoch 76/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.0346e-04
# Epoch 77/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.2613e-04
# Epoch 78/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.6781e-04
# Epoch 79/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.6446e-04
# Epoch 80/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.4569e-04
# Epoch 81/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.1251e-04
# Epoch 82/100
# 33/33 [==============================] - 1s 20ms/step - loss: 3.7505e-04
# Epoch 83/100
# 33/33 [==============================] - 1s 25ms/step - loss: 3.3051e-04
# Epoch 84/100
# 33/33 [==============================] - 1s 26ms/step - loss: 3.0905e-04
# Epoch 85/100
# 33/33 [==============================] - 2s 46ms/step - loss: 3.4770e-04
# Epoch 86/100
# 33/33 [==============================] - 1s 26ms/step - loss: 3.9019e-04
# Epoch 87/100
# 33/33 [==============================] - 1s 25ms/step - loss: 3.5931e-04
# Epoch 88/100
# 33/33 [==============================] - 1s 25ms/step - loss: 3.1719e-04
# Epoch 89/100
# 33/33 [==============================] - 1s 20ms/step - loss: 3.1718e-04
# Epoch 90/100
# 33/33 [==============================] - 0s 15ms/step - loss: 2.8657e-04
# Epoch 91/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.8603e-04
# Epoch 92/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.8984e-04
# Epoch 93/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.0642e-04
# Epoch 94/100
# 33/33 [==============================] - 1s 15ms/step - loss: 3.2895e-04
# Epoch 95/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.9879e-04
# Epoch 96/100
# 33/33 [==============================] - 1s 15ms/step - loss: 2.8023e-04
# Epoch 97/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.8506e-04
# Epoch 98/100
# 33/33 [==============================] - 1s 16ms/step - loss: 3.2395e-04
# Epoch 99/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.9522e-04
# Epoch 100/100
# 33/33 [==============================] - 1s 15ms/step - loss: 2.9832e-04

# %%
# 10. Dự đoán dữ liệu kiểm thử
train_predict = model_cnn.predict(X_train)
y_pred = model_cnn.predict(X_test)
# Out:
# 66/66 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 4ms/step

# %%
# 11. Đảo ngược chuẩn hóa cho dữ liệu dự đoán
train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

# %%
# 12. Đánh giá độ chính xác của thuật toán bằng RMSE
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_log_error
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
print('Testing RMSE:', test_rmse)
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_log_error
# MAPE
test_mape = mean_absolute_percentage_error(ytest,y_pred)
print('Testing MAPE:', test_mape)
# MSLE
test_msle = mean_squared_log_error(ytest,y_pred)
print('Testing MSLE:', test_msle)
# Out:
# Testing RMSE: 84873.14994864858
# Testing MAPE: 92780.505799252
# Testing MSLE: 114.45541129159558

# %%
# 13. Dự đoán cho 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output = []
n_steps = time_step
i = 0
while(i < 30):

    if(len(temp_input) > n_steps):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model_cnn.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model_cnn.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        i = i + 1

# %%
# 14. Vẽ hình
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index, y_pred)
predict_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+28, step=1)  # Giả sử chiều dài là 29
plt.plot(predict_data_index, scaler.inverse_transform(lst_output))
plt.legend(['Train', 'Test', 'Predict', 'Next30days'])
plt.title('CNN 9:1 (VCB stock price)')
plt.show()
