# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

# %%
# 2. Đọc file CSV và thiết lập chỉ số là giá 'Close'
df = pd.read_csv('/content/drive/MyDrive/Final/VCB_Stock_Data.csv')
df1 = df.reset_index()['Close']
df1 = df1[~np.isnan(df1)]
df1
# Out:
# 0       12181.833984
# 8       11925.374023
# 9       11882.630859
# 10      12096.347656
# 11      12096.347656
#             ...
# 2554    85200.000000
# 2555    85000.000000
# 2556    84200.000000
# 2557    84200.000000
# 2558    83700.000000
# Name: Close, Length: 2459, dtype: float64

# %%
# 3. Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# %%
# 4. Chia dữ liệu thành tập huấn luyện và tập kiểm thử ti lệ 90% và 10%
train_size = int(0.9 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]

# %%
# 5. Tạo hàm tạo dataset
import numpy
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# 6. Reshape dữ liệu cho việc huấn luyện
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
 # 7. Reshape input to be [samples, time steps, features] which is required for RNN
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# 8. Định nghĩa mô hình RNN
model = Sequential()
model.add(SimpleRNN(50, input_shape=(time_step, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Huấn luyện mô hình với dữ liệu huấn luyện
model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 33/33 [==============================] - 4s 31ms/step - loss: 0.0060
# Epoch 2/100
# 33/33 [==============================] - 1s 31ms/step - loss: 4.6849e-04
# Epoch 3/100
# 33/33 [==============================] - 1s 30ms/step - loss: 3.2444e-04
# Epoch 4/100
# 33/33 [==============================] - 1s 27ms/step - loss: 3.1226e-04
# Epoch 5/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.8967e-04
# Epoch 6/100
# 33/33 [==============================] - 1s 17ms/step - loss: 2.7678e-04
# Epoch 7/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.7199e-04
# Epoch 8/100
# 33/33 [==============================] - 1s 17ms/step - loss: 2.6972e-04
# Epoch 9/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.5269e-04
# Epoch 10/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.5253e-04
# Epoch 11/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.4391e-04
# Epoch 12/100
# 33/33 [==============================] - 1s 17ms/step - loss: 2.6750e-04
# Epoch 13/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.6470e-04
# Epoch 14/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.4984e-04
# Epoch 15/100
# 33/33 [==============================] - 1s 17ms/step - loss: 2.2681e-04
# Epoch 16/100
# 33/33 [==============================] - 1s 17ms/step - loss: 2.1458e-04
# Epoch 17/100
# 33/33 [==============================] - 1s 17ms/step - loss: 2.1953e-04
# Epoch 18/100
# 33/33 [==============================] - 1s 16ms/step - loss: 2.0890e-04
# Epoch 19/100
# 33/33 [==============================] - 1s 17ms/step - loss: 2.0799e-04
# Epoch 20/100
# 33/33 [==============================] - 1s 17ms/step - loss: 2.0013e-04
# Epoch 21/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.8942e-04
# Epoch 22/100
# 33/33 [==============================] - 1s 21ms/step - loss: 1.9199e-04
# Epoch 23/100
# 33/33 [==============================] - 1s 31ms/step - loss: 1.8944e-04
# Epoch 24/100
# 33/33 [==============================] - 1s 30ms/step - loss: 1.8808e-04
# Epoch 25/100
# 33/33 [==============================] - 1s 31ms/step - loss: 1.9311e-04
# Epoch 26/100
# 33/33 [==============================] - 1s 30ms/step - loss: 2.0502e-04
# Epoch 27/100
# 33/33 [==============================] - 1s 31ms/step - loss: 1.7573e-04
# Epoch 28/100
# 33/33 [==============================] - 1s 31ms/step - loss: 1.7783e-04
# Epoch 29/100
# 33/33 [==============================] - 1s 21ms/step - loss: 1.8126e-04
# Epoch 30/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.6749e-04
# Epoch 31/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.7893e-04
# Epoch 32/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.6351e-04
# Epoch 33/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.7158e-04
# Epoch 34/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.6577e-04
# Epoch 35/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.6180e-04
# Epoch 36/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.9298e-04
# Epoch 37/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.7978e-04
# Epoch 38/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.5187e-04
# Epoch 39/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.4791e-04
# Epoch 40/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.4947e-04
# Epoch 41/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.6590e-04
# Epoch 42/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.5385e-04
# Epoch 43/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.4287e-04
# Epoch 44/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.4741e-04
# Epoch 45/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.4800e-04
# Epoch 46/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.4845e-04
# Epoch 47/100
# 33/33 [==============================] - 1s 26ms/step - loss: 1.4179e-04
# Epoch 48/100
# 33/33 [==============================] - 1s 31ms/step - loss: 1.4346e-04
# Epoch 49/100
# 33/33 [==============================] - 1s 31ms/step - loss: 1.3617e-04
# Epoch 50/100
# 33/33 [==============================] - 1s 30ms/step - loss: 1.5101e-04
# Epoch 51/100
# 33/33 [==============================] - 1s 30ms/step - loss: 1.4478e-04
# Epoch 52/100
# 33/33 [==============================] - 1s 31ms/step - loss: 1.3762e-04
# Epoch 53/100
# 33/33 [==============================] - 1s 27ms/step - loss: 1.4655e-04
# Epoch 54/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.4974e-04
# Epoch 55/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.5380e-04
# Epoch 56/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.5443e-04
# Epoch 57/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.4281e-04
# Epoch 58/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.3650e-04
# Epoch 59/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.3752e-04
# Epoch 60/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.2991e-04
# Epoch 61/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.2815e-04
# Epoch 62/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.3146e-04
# Epoch 63/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.2658e-04
# Epoch 64/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.2270e-04
# Epoch 65/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.2731e-04
# Epoch 66/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.3639e-04
# Epoch 67/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.3560e-04
# Epoch 68/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.3163e-04
# Epoch 69/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.4684e-04
# Epoch 70/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.4111e-04
# Epoch 71/100
# 33/33 [==============================] - 1s 20ms/step - loss: 1.2671e-04
# Epoch 72/100
# 33/33 [==============================] - 1s 31ms/step - loss: 1.2373e-04
# Epoch 73/100
# 33/33 [==============================] - 1s 31ms/step - loss: 1.3180e-04
# Epoch 74/100
# 33/33 [==============================] - 1s 30ms/step - loss: 1.2056e-04
# Epoch 75/100
# 33/33 [==============================] - 1s 33ms/step - loss: 1.3276e-04
# Epoch 76/100
# 33/33 [==============================] - 1s 31ms/step - loss: 1.2812e-04
# Epoch 77/100
# 33/33 [==============================] - 1s 31ms/step - loss: 1.1985e-04
# Epoch 78/100
# 33/33 [==============================] - 1s 19ms/step - loss: 1.2804e-04
# Epoch 79/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.1499e-04
# Epoch 80/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.1313e-04
# Epoch 81/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.2155e-04
# Epoch 82/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.3663e-04
# Epoch 83/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.1208e-04
# Epoch 84/100
# 33/33 [==============================] - 1s 19ms/step - loss: 1.1256e-04
# Epoch 85/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.1505e-04
# Epoch 86/100
# 33/33 [==============================] - 1s 18ms/step - loss: 1.1211e-04
# Epoch 87/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.2591e-04
# Epoch 88/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.1823e-04
# Epoch 89/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.3016e-04
# Epoch 90/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.1083e-04
# Epoch 91/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.1897e-04
# Epoch 92/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.2139e-04
# Epoch 93/100
# 33/33 [==============================] - 1s 17ms/step - loss: 1.1700e-04
# Epoch 94/100
# 33/33 [==============================] - 1s 16ms/step - loss: 1.1063e-04
# Epoch 95/100
# 33/33 [==============================] - 1s 21ms/step - loss: 1.1279e-04
# Epoch 96/100
# 33/33 [==============================] - 1s 30ms/step - loss: 1.1055e-04
# Epoch 97/100
# 33/33 [==============================] - 1s 31ms/step - loss: 1.1156e-04
# Epoch 98/100
# 33/33 [==============================] - 1s 30ms/step - loss: 1.1109e-04
# Epoch 99/100
# 33/33 [==============================] - 1s 31ms/step - loss: 1.2151e-04
# Epoch 100/100
# 33/33 [==============================] - 1s 32ms/step - loss: 1.1109e-04

# %%
# 10. Dự đoán dữ liệu kiểm thử
train_predict = model.predict(X_train)
y_pred = model.predict(X_test)
# Out:
# 66/66 [==============================] - 1s 10ms/step
# 5/5 [==============================] - 0s 7ms/step

# %%
# 11. Đảo ngược chuẩn hóa cho dữ liệu dự đoán
train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

# %%
# 12. Đánh giá độ chính xác của thuật toán bằng RMSE
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_log_error
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
print('Testing RMSE:', test_rmse)
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_log_error
# MAPE
test_mape = mean_absolute_percentage_error(ytest,y_pred)
print('Testing MAPE:', test_mape)
# MSLE
test_msle = mean_squared_log_error(ytest,y_pred)
print('Testing MSLE:', test_msle)
# Out:
# Testing RMSE: 85371.53785802935
# Testing MAPE: 93309.63549864001
# Testing MSLE: 114.57971367868129

# %%
# 13. Dự đoán cho 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output = []
n_steps = time_step
i = 0
while(i < 30):

    if(len(temp_input) > n_steps):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        i = i + 1

# %%
# 14. Vẽ hình
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index, y_pred)
predict_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+28, step=1)  # Giả sử chiều dài là 29
plt.plot(predict_data_index, scaler.inverse_transform(lst_output))
plt.legend(['Train', 'Test', 'Predict', 'Next30days'])
plt.title('RNN 9:1 (VCB stock price)')
plt.show()
