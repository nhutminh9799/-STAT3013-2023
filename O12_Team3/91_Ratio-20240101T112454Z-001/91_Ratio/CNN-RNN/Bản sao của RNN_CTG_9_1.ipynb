# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

# %%
# 2. Đọc file CSV và thiết lập chỉ số là giá 'Close'
df = pd.read_csv('/content/drive/MyDrive/Final/CTG_Stock_Data.csv')
df1 = df.reset_index()['Close']
df1 = df1[~np.isnan(df1)]
df1
# Out:
# 0       11717.867188
# 8       11648.531250
# 9       11579.194336
# 10      11509.858398
# 11      11509.858398
#             ...
# 2555    26900.000000
# 2556    26850.000000
# 2557    27000.000000
# 2558    26750.000000
# 2559    26750.000000
# Name: Close, Length: 2465, dtype: float64

# %%
# 3. Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# %%
# 4. Chia dữ liệu thành tập huấn luyện và tập kiểm thử ti lệ 90% và 10%
train_size = int(0.9 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]

# %%
# 5. Tạo hàm tạo dataset
import numpy
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# 6. Reshape dữ liệu cho việc huấn luyện
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
 # 7. Reshape input to be [samples, time steps, features] which is required for RNN
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# 8. Định nghĩa mô hình RNN
model = Sequential()
model.add(SimpleRNN(50, input_shape=(time_step, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Huấn luyện mô hình với dữ liệu huấn luyện
model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4467e-04
# Epoch 2/100
# 34/34 [==============================] - 1s 20ms/step - loss: 2.5413e-04
# Epoch 3/100
# 34/34 [==============================] - 2s 49ms/step - loss: 2.4115e-04
# Epoch 4/100
# 34/34 [==============================] - 1s 41ms/step - loss: 2.6152e-04
# Epoch 5/100
# 34/34 [==============================] - 2s 45ms/step - loss: 2.6570e-04
# Epoch 6/100
# 34/34 [==============================] - 2s 51ms/step - loss: 2.5550e-04
# Epoch 7/100
# 34/34 [==============================] - 2s 46ms/step - loss: 2.5446e-04
# Epoch 8/100
# 34/34 [==============================] - 1s 34ms/step - loss: 2.5490e-04
# Epoch 9/100
# 34/34 [==============================] - 1s 32ms/step - loss: 2.5095e-04
# Epoch 10/100
# 34/34 [==============================] - 1s 34ms/step - loss: 2.5808e-04
# Epoch 11/100
# 34/34 [==============================] - 1s 30ms/step - loss: 2.6464e-04
# Epoch 12/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.9577e-04
# Epoch 13/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4804e-04
# Epoch 14/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4465e-04
# Epoch 15/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.6209e-04
# Epoch 16/100
# 34/34 [==============================] - 1s 19ms/step - loss: 3.0880e-04
# Epoch 17/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.5818e-04
# Epoch 18/100
# 34/34 [==============================] - 1s 18ms/step - loss: 2.6770e-04
# Epoch 19/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.5582e-04
# Epoch 20/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.7975e-04
# Epoch 21/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.5042e-04
# Epoch 22/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4729e-04
# Epoch 23/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4789e-04
# Epoch 24/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.5084e-04
# Epoch 25/100
# 34/34 [==============================] - 1s 20ms/step - loss: 2.6493e-04
# Epoch 26/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4722e-04
# Epoch 27/100
# 34/34 [==============================] - 1s 34ms/step - loss: 2.4803e-04
# Epoch 28/100
# 34/34 [==============================] - 1s 36ms/step - loss: 2.4409e-04
# Epoch 29/100
# 34/34 [==============================] - 1s 34ms/step - loss: 2.9671e-04
# Epoch 30/100
# 34/34 [==============================] - 1s 32ms/step - loss: 2.5632e-04
# Epoch 31/100
# 34/34 [==============================] - 1s 32ms/step - loss: 2.5345e-04
# Epoch 32/100
# 34/34 [==============================] - 1s 22ms/step - loss: 2.4728e-04
# Epoch 33/100
# 34/34 [==============================] - 1s 20ms/step - loss: 2.4800e-04
# Epoch 34/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.6233e-04
# Epoch 35/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4613e-04
# Epoch 36/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.6198e-04
# Epoch 37/100
# 34/34 [==============================] - 1s 20ms/step - loss: 2.5313e-04
# Epoch 38/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4335e-04
# Epoch 39/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4523e-04
# Epoch 40/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4230e-04
# Epoch 41/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.5950e-04
# Epoch 42/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.5985e-04
# Epoch 43/100
# 34/34 [==============================] - 1s 19ms/step - loss: 3.7007e-04
# Epoch 44/100
# 34/34 [==============================] - 1s 21ms/step - loss: 3.9505e-04
# Epoch 45/100
# 34/34 [==============================] - 1s 20ms/step - loss: 2.4570e-04
# Epoch 46/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4848e-04
# Epoch 47/100
# 34/34 [==============================] - 1s 31ms/step - loss: 2.5282e-04
# Epoch 48/100
# 34/34 [==============================] - 1s 34ms/step - loss: 2.9636e-04
# Epoch 49/100
# 34/34 [==============================] - 1s 34ms/step - loss: 2.4109e-04
# Epoch 50/100
# 34/34 [==============================] - 1s 34ms/step - loss: 2.6938e-04
# Epoch 51/100
# 34/34 [==============================] - 1s 33ms/step - loss: 2.9141e-04
# Epoch 52/100
# 34/34 [==============================] - 1s 25ms/step - loss: 2.4506e-04
# Epoch 53/100
# 34/34 [==============================] - 1s 18ms/step - loss: 2.4920e-04
# Epoch 54/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4338e-04
# Epoch 55/100
# 34/34 [==============================] - 1s 18ms/step - loss: 2.4053e-04
# Epoch 56/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.8246e-04
# Epoch 57/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.6876e-04
# Epoch 58/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4980e-04
# Epoch 59/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.8063e-04
# Epoch 60/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.6686e-04
# Epoch 61/100
# 34/34 [==============================] - 1s 18ms/step - loss: 2.6271e-04
# Epoch 62/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.6073e-04
# Epoch 63/100
# 34/34 [==============================] - 1s 18ms/step - loss: 2.4623e-04
# Epoch 64/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4559e-04
# Epoch 65/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.5370e-04
# Epoch 66/100
# 34/34 [==============================] - 1s 18ms/step - loss: 2.8099e-04
# Epoch 67/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4235e-04
# Epoch 68/100
# 34/34 [==============================] - 1s 34ms/step - loss: 2.3944e-04
# Epoch 69/100
# 34/34 [==============================] - 1s 33ms/step - loss: 2.5724e-04
# Epoch 70/100
# 34/34 [==============================] - 1s 34ms/step - loss: 2.5013e-04
# Epoch 71/100
# 34/34 [==============================] - 1s 35ms/step - loss: 2.6326e-04
# Epoch 72/100
# 34/34 [==============================] - 1s 33ms/step - loss: 2.5244e-04
# Epoch 73/100
# 34/34 [==============================] - 1s 20ms/step - loss: 3.3506e-04
# Epoch 74/100
# 34/34 [==============================] - 1s 20ms/step - loss: 2.4627e-04
# Epoch 75/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.3966e-04
# Epoch 76/100
# 34/34 [==============================] - 1s 20ms/step - loss: 2.4354e-04
# Epoch 77/100
# 34/34 [==============================] - 1s 20ms/step - loss: 2.4768e-04
# Epoch 78/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4249e-04
# Epoch 79/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4804e-04
# Epoch 80/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.6103e-04
# Epoch 81/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4752e-04
# Epoch 82/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4076e-04
# Epoch 83/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4805e-04
# Epoch 84/100
# 34/34 [==============================] - 1s 18ms/step - loss: 2.8240e-04
# Epoch 85/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4912e-04
# Epoch 86/100
# 34/34 [==============================] - 1s 18ms/step - loss: 2.4746e-04
# Epoch 87/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.5853e-04
# Epoch 88/100
# 34/34 [==============================] - 1s 31ms/step - loss: 2.5614e-04
# Epoch 89/100
# 34/34 [==============================] - 1s 35ms/step - loss: 2.5007e-04
# Epoch 90/100
# 34/34 [==============================] - 1s 35ms/step - loss: 2.4394e-04
# Epoch 91/100
# 34/34 [==============================] - 1s 32ms/step - loss: 2.4819e-04
# Epoch 92/100
# 34/34 [==============================] - 1s 35ms/step - loss: 2.7869e-04
# Epoch 93/100
# 34/34 [==============================] - 1s 25ms/step - loss: 2.5057e-04
# Epoch 94/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.5494e-04
# Epoch 95/100
# 34/34 [==============================] - 1s 20ms/step - loss: 2.4995e-04
# Epoch 96/100
# 34/34 [==============================] - 1s 18ms/step - loss: 2.4145e-04
# Epoch 97/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4617e-04
# Epoch 98/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.6322e-04
# Epoch 99/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4485e-04
# Epoch 100/100
# 34/34 [==============================] - 1s 19ms/step - loss: 2.4379e-04

# %%
# 10. Dự đoán dữ liệu kiểm thử
train_predict = model.predict(X_train)
y_pred = model.predict(X_test)
# Out:
# 67/67 [==============================] - 1s 11ms/step
# 5/5 [==============================] - 0s 14ms/step

# %%
# 11. Đảo ngược chuẩn hóa cho dữ liệu dự đoán
train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

# %%
# 12. Đánh giá độ chính xác của thuật toán bằng RMSE
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_log_error
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
print('Testing RMSE:', test_rmse)
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_log_error
# MAPE
test_mape = mean_absolute_percentage_error(ytest,y_pred)
print('Testing MAPE:', test_mape)
# MSLE
test_msle = mean_squared_log_error(ytest,y_pred)
print('Testing MSLE:', test_msle)
# Out:
# Testing RMSE: 26595.889706451962
# Testing MAPE: 43534.36434090349
# Testing MSLE: 94.27746203950525

# %%
# 13. Dự đoán cho 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output = []
n_steps = time_step
i = 0
while(i < 30):

    if(len(temp_input) > n_steps):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        i = i + 1

# %%
# 14. Vẽ hình
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index, y_pred)
predict_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+28, step=1)  # Giả sử chiều dài là 29
plt.plot(predict_data_index, scaler.inverse_transform(lst_output))
plt.legend(['Train', 'Test', 'Predict', 'Next30days'])
plt.title('RNN 9:1 (CTG stock price)')
plt.show()
