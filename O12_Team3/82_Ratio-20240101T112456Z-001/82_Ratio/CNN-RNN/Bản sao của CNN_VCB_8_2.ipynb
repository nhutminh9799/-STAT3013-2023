# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

# %%
# 2. Đọc file CSV và thiết lập chỉ số là giá 'Close'
df = pd.read_csv('/content/drive/MyDrive/Final/VCB_Stock_Data.csv')
df1 = df.reset_index()['Close']
df1 = df1[~np.isnan(df1)]
df1
# Out:
# 0       12181.833984
# 8       11925.374023
# 9       11882.630859
# 10      12096.347656
# 11      12096.347656
#             ...
# 2554    85200.000000
# 2555    85000.000000
# 2556    84200.000000
# 2557    84200.000000
# 2558    83700.000000
# Name: Close, Length: 2459, dtype: float64

# %%
# 3. Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# %%
# 4. Chia dữ liệu thành tập huấn luyện và tập kiểm thử ti lệ 80% và 20%
train_size = int(0.8 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]

# %%
# 5. Tạo hàm tạo dataset
import numpy
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# 6. Reshape dữ liệu cho việc huấn luyện
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
 # 7. Reshape input to be [samples, time steps, features] which is required for RNN
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# 8. Định nghĩa mô hình CNN
model_cnn = Sequential()
model_cnn.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(time_step, 1)))
model_cnn.add(MaxPooling1D(pool_size=2))
model_cnn.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model_cnn.add(MaxPooling1D(pool_size=2))
model_cnn.add(Flatten())
model_cnn.add(Dense(50, activation='relu'))
model_cnn.add(Dense(1))
model_cnn.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Huấn luyện mô hình với dữ liệu huấn luyện
model_cnn.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 2s 19ms/step - loss: 0.0157
# Epoch 2/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0025
# Epoch 3/100
# 30/30 [==============================] - 0s 16ms/step - loss: 0.0021
# Epoch 4/100
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0018
# Epoch 5/100
# 30/30 [==============================] - 1s 17ms/step - loss: 0.0016
# Epoch 6/100
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0014
# Epoch 7/100
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0013
# Epoch 8/100
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0011
# Epoch 9/100
# 30/30 [==============================] - 1s 18ms/step - loss: 9.6055e-04
# Epoch 10/100
# 30/30 [==============================] - 1s 18ms/step - loss: 9.8147e-04
# Epoch 11/100
# 30/30 [==============================] - 1s 17ms/step - loss: 9.2003e-04
# Epoch 12/100
# 30/30 [==============================] - 1s 17ms/step - loss: 8.6522e-04
# Epoch 13/100
# 30/30 [==============================] - 1s 27ms/step - loss: 7.9416e-04
# Epoch 14/100
# 30/30 [==============================] - 1s 28ms/step - loss: 7.6866e-04
# Epoch 15/100
# 30/30 [==============================] - 1s 29ms/step - loss: 7.9176e-04
# Epoch 16/100
# 30/30 [==============================] - 1s 27ms/step - loss: 9.6346e-04
# Epoch 17/100
# 30/30 [==============================] - 1s 26ms/step - loss: 9.9635e-04
# Epoch 18/100
# 30/30 [==============================] - 1s 27ms/step - loss: 7.8110e-04
# Epoch 19/100
# 30/30 [==============================] - 1s 28ms/step - loss: 7.3441e-04
# Epoch 20/100
# 30/30 [==============================] - 1s 27ms/step - loss: 6.9351e-04
# Epoch 21/100
# 30/30 [==============================] - 1s 18ms/step - loss: 6.1639e-04
# Epoch 22/100
# 30/30 [==============================] - 1s 17ms/step - loss: 6.2522e-04
# Epoch 23/100
# 30/30 [==============================] - 1s 18ms/step - loss: 6.0280e-04
# Epoch 24/100
# 30/30 [==============================] - 1s 17ms/step - loss: 6.7757e-04
# Epoch 25/100
# 30/30 [==============================] - 1s 17ms/step - loss: 6.5273e-04
# Epoch 26/100
# 30/30 [==============================] - 1s 17ms/step - loss: 9.3232e-04
# Epoch 27/100
# 30/30 [==============================] - 1s 18ms/step - loss: 6.5018e-04
# Epoch 28/100
# 30/30 [==============================] - 1s 17ms/step - loss: 5.4619e-04
# Epoch 29/100
# 30/30 [==============================] - 1s 17ms/step - loss: 5.2705e-04
# Epoch 30/100
# 30/30 [==============================] - 1s 17ms/step - loss: 5.6024e-04
# Epoch 31/100
# 30/30 [==============================] - 1s 18ms/step - loss: 5.6558e-04
# Epoch 32/100
# 30/30 [==============================] - 1s 17ms/step - loss: 4.9814e-04
# Epoch 33/100
# 30/30 [==============================] - 0s 16ms/step - loss: 5.0446e-04
# Epoch 34/100
# 30/30 [==============================] - 0s 16ms/step - loss: 5.6144e-04
# Epoch 35/100
# 30/30 [==============================] - 1s 18ms/step - loss: 5.0202e-04
# Epoch 36/100
# 30/30 [==============================] - 1s 17ms/step - loss: 4.7916e-04
# Epoch 37/100
# 30/30 [==============================] - 1s 18ms/step - loss: 4.7834e-04
# Epoch 38/100
# 30/30 [==============================] - 1s 17ms/step - loss: 4.4691e-04
# Epoch 39/100
# 30/30 [==============================] - 1s 19ms/step - loss: 4.5683e-04
# Epoch 40/100
# 30/30 [==============================] - 1s 28ms/step - loss: 4.7177e-04
# Epoch 41/100
# 30/30 [==============================] - 1s 28ms/step - loss: 4.7307e-04
# Epoch 42/100
# 30/30 [==============================] - 1s 29ms/step - loss: 4.5214e-04
# Epoch 43/100
# 30/30 [==============================] - 1s 28ms/step - loss: 6.0456e-04
# Epoch 44/100
# 30/30 [==============================] - 1s 27ms/step - loss: 5.3818e-04
# Epoch 45/100
# 30/30 [==============================] - 1s 28ms/step - loss: 4.4747e-04
# Epoch 46/100
# 30/30 [==============================] - 1s 28ms/step - loss: 6.0416e-04
# Epoch 47/100
# 30/30 [==============================] - 1s 22ms/step - loss: 4.7692e-04
# Epoch 48/100
# 30/30 [==============================] - 0s 16ms/step - loss: 4.1894e-04
# Epoch 49/100
# 30/30 [==============================] - 0s 16ms/step - loss: 4.5637e-04
# Epoch 50/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.8987e-04
# Epoch 51/100
# 30/30 [==============================] - 1s 17ms/step - loss: 4.4928e-04
# Epoch 52/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.9381e-04
# Epoch 53/100
# 30/30 [==============================] - 0s 16ms/step - loss: 3.7861e-04
# Epoch 54/100
# 30/30 [==============================] - 0s 16ms/step - loss: 4.0673e-04
# Epoch 55/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.8691e-04
# Epoch 56/100
# 30/30 [==============================] - 1s 18ms/step - loss: 6.4018e-04
# Epoch 57/100
# 30/30 [==============================] - 1s 18ms/step - loss: 3.9389e-04
# Epoch 58/100
# 30/30 [==============================] - 1s 18ms/step - loss: 3.6904e-04
# Epoch 59/100
# 30/30 [==============================] - 1s 17ms/step - loss: 4.1923e-04
# Epoch 60/100
# 30/30 [==============================] - 0s 16ms/step - loss: 4.3971e-04
# Epoch 61/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.8534e-04
# Epoch 62/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.5294e-04
# Epoch 63/100
# 30/30 [==============================] - 1s 17ms/step - loss: 4.1993e-04
# Epoch 64/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.3896e-04
# Epoch 65/100
# 30/30 [==============================] - 1s 18ms/step - loss: 3.8883e-04
# Epoch 66/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.8308e-04
# Epoch 67/100
# 30/30 [==============================] - 1s 28ms/step - loss: 3.5450e-04
# Epoch 68/100
# 30/30 [==============================] - 1s 26ms/step - loss: 3.5160e-04
# Epoch 69/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.3622e-04
# Epoch 70/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.3833e-04
# Epoch 71/100
# 30/30 [==============================] - 1s 26ms/step - loss: 5.0568e-04
# Epoch 72/100
# 30/30 [==============================] - 1s 28ms/step - loss: 3.9796e-04
# Epoch 73/100
# 30/30 [==============================] - 1s 29ms/step - loss: 3.3152e-04
# Epoch 74/100
# 30/30 [==============================] - 1s 26ms/step - loss: 3.7607e-04
# Epoch 75/100
# 30/30 [==============================] - 1s 21ms/step - loss: 3.4453e-04
# Epoch 76/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.3748e-04
# Epoch 77/100
# 30/30 [==============================] - 1s 18ms/step - loss: 4.6501e-04
# Epoch 78/100
# 30/30 [==============================] - 1s 18ms/step - loss: 3.3953e-04
# Epoch 79/100
# 30/30 [==============================] - 1s 18ms/step - loss: 3.0594e-04
# Epoch 80/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.2760e-04
# Epoch 81/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.5755e-04
# Epoch 82/100
# 30/30 [==============================] - 1s 18ms/step - loss: 3.7046e-04
# Epoch 83/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.5829e-04
# Epoch 84/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.2225e-04
# Epoch 85/100
# 30/30 [==============================] - 0s 16ms/step - loss: 3.1762e-04
# Epoch 86/100
# 30/30 [==============================] - 1s 18ms/step - loss: 4.5492e-04
# Epoch 87/100
# 30/30 [==============================] - 1s 17ms/step - loss: 3.4998e-04
# Epoch 88/100
# 30/30 [==============================] - 1s 18ms/step - loss: 3.1936e-04
# Epoch 89/100
# 30/30 [==============================] - 1s 18ms/step - loss: 3.3656e-04
# Epoch 90/100
# 30/30 [==============================] - 1s 18ms/step - loss: 3.9904e-04
# Epoch 91/100
# 30/30 [==============================] - 1s 18ms/step - loss: 3.3123e-04
# Epoch 92/100
# 30/30 [==============================] - 1s 18ms/step - loss: 3.6926e-04
# Epoch 93/100
# 30/30 [==============================] - 1s 18ms/step - loss: 3.6338e-04
# Epoch 94/100
# 30/30 [==============================] - 1s 45ms/step - loss: 3.5162e-04
# Epoch 95/100
# 30/30 [==============================] - 1s 49ms/step - loss: 3.3090e-04
# Epoch 96/100
# 30/30 [==============================] - 1s 29ms/step - loss: 3.2611e-04
# Epoch 97/100
# 30/30 [==============================] - 1s 28ms/step - loss: 3.1343e-04
# Epoch 98/100
# 30/30 [==============================] - 1s 29ms/step - loss: 3.1645e-04
# Epoch 99/100
# 30/30 [==============================] - 1s 28ms/step - loss: 4.7138e-04
# Epoch 100/100
# 30/30 [==============================] - 1s 25ms/step - loss: 3.4855e-04

# %%
# 10. Dự đoán dữ liệu kiểm thử
train_predict = model_cnn.predict(X_train)
y_pred = model_cnn.predict(X_test)
# Out:
# 59/59 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 5ms/step

# %%
# 11. Đảo ngược chuẩn hóa cho dữ liệu dự đoán
train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

# %%
# 12. Đánh giá độ chính xác của thuật toán bằng RMSE
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_log_error
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
print('Testing RMSE:', test_rmse)
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_log_error
# MAPE
test_mape = mean_absolute_percentage_error(ytest,y_pred)
print('Testing MAPE:', test_mape)
# MSLE
test_msle = mean_squared_log_error(ytest,y_pred)
print('Testing MSLE:', test_msle)
# Out:
# Testing RMSE: 72217.28533606768
# Testing MAPE: 92489.72213817066
# Testing MSLE: 112.34881162411173

# %%
# 13. Dự đoán cho 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output = []
n_steps = time_step
i = 0
while(i < 30):

    if(len(temp_input) > n_steps):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model_cnn.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model_cnn.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        i = i + 1

# %%
# 14. Vẽ hình
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index, y_pred)
predict_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+28, step=1)  # Giả sử chiều dài là 29
plt.plot(predict_data_index, scaler.inverse_transform(lst_output))
plt.legend(['Train', 'Test', 'Predict', 'Next30days'])
plt.title('CNN 8:2 (VCB stock price)')
plt.show()
