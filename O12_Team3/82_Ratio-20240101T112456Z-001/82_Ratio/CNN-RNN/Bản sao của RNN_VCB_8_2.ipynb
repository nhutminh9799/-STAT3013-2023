# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN

# %%
# 2. Đọc file CSV và thiết lập chỉ số là giá 'Close'
df = pd.read_csv('/content/drive/MyDrive/Final/VCB_Stock_Data.csv')
df1 = df.reset_index()['Close']
df1 = df1[~np.isnan(df1)]
df1
# Out:
# 0       12181.833984
# 8       11925.374023
# 9       11882.630859
# 10      12096.347656
# 11      12096.347656
#             ...
# 2554    85200.000000
# 2555    85000.000000
# 2556    84200.000000
# 2557    84200.000000
# 2558    83700.000000
# Name: Close, Length: 2459, dtype: float64

# %%
# 3. Chuẩn hóa dữ liệu
scaler = MinMaxScaler(feature_range=(0, 1))
df1 = scaler.fit_transform(np.array(df1).reshape(-1, 1))

# %%
# 4. Chia dữ liệu thành tập huấn luyện và tập kiểm thử ti lệ 80% và 20%
train_size = int(0.8 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]

# %%
# 5. Tạo hàm tạo dataset
import numpy
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, X=0,1,2,3-----99   Y=100
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# 6. Reshape dữ liệu cho việc huấn luyện
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
 # 7. Reshape input to be [samples, time steps, features] which is required for RNN
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
# 8. Định nghĩa mô hình RNN
model = Sequential()
model.add(SimpleRNN(50, input_shape=(time_step, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 9. Huấn luyện mô hình với dữ liệu huấn luyện
model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 5s 49ms/step - loss: 0.0399
# Epoch 2/100
# 30/30 [==============================] - 1s 45ms/step - loss: 0.0012
# Epoch 3/100
# 30/30 [==============================] - 2s 56ms/step - loss: 3.9169e-04
# Epoch 4/100
# 30/30 [==============================] - 2s 51ms/step - loss: 3.0554e-04
# Epoch 5/100
# 30/30 [==============================] - 1s 24ms/step - loss: 2.8124e-04
# Epoch 6/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.5712e-04
# Epoch 7/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.6841e-04
# Epoch 8/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.5296e-04
# Epoch 9/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.2443e-04
# Epoch 10/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.2047e-04
# Epoch 11/100
# 30/30 [==============================] - 1s 28ms/step - loss: 2.3017e-04
# Epoch 12/100
# 30/30 [==============================] - 1s 32ms/step - loss: 2.1623e-04
# Epoch 13/100
# 30/30 [==============================] - 1s 35ms/step - loss: 2.2263e-04
# Epoch 14/100
# 30/30 [==============================] - 1s 34ms/step - loss: 1.9794e-04
# Epoch 15/100
# 30/30 [==============================] - 1s 34ms/step - loss: 2.0833e-04
# Epoch 16/100
# 30/30 [==============================] - 1s 35ms/step - loss: 1.8833e-04
# Epoch 17/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.8776e-04
# Epoch 18/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.8947e-04
# Epoch 19/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.0907e-04
# Epoch 20/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.8958e-04
# Epoch 21/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7772e-04
# Epoch 22/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.6723e-04
# Epoch 23/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.8841e-04
# Epoch 24/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.6535e-04
# Epoch 25/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.6868e-04
# Epoch 26/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7356e-04
# Epoch 27/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.6568e-04
# Epoch 28/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.7902e-04
# Epoch 29/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.6857e-04
# Epoch 30/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.5706e-04
# Epoch 31/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.5329e-04
# Epoch 32/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.7613e-04
# Epoch 33/100
# 30/30 [==============================] - 1s 32ms/step - loss: 1.8706e-04
# Epoch 34/100
# 30/30 [==============================] - 1s 36ms/step - loss: 1.5598e-04
# Epoch 35/100
# 30/30 [==============================] - 1s 35ms/step - loss: 1.3860e-04
# Epoch 36/100
# 30/30 [==============================] - 1s 34ms/step - loss: 1.6467e-04
# Epoch 37/100
# 30/30 [==============================] - 1s 34ms/step - loss: 1.6618e-04
# Epoch 38/100
# 30/30 [==============================] - 1s 26ms/step - loss: 1.3551e-04
# Epoch 39/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.4367e-04
# Epoch 40/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.9558e-04
# Epoch 41/100
# 30/30 [==============================] - 1s 20ms/step - loss: 2.0704e-04
# Epoch 42/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.8958e-04
# Epoch 43/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.5859e-04
# Epoch 44/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.4520e-04
# Epoch 45/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.4160e-04
# Epoch 46/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.4486e-04
# Epoch 47/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.3005e-04
# Epoch 48/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.2879e-04
# Epoch 49/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.3137e-04
# Epoch 50/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.2697e-04
# Epoch 51/100
# 30/30 [==============================] - 1s 22ms/step - loss: 1.2379e-04
# Epoch 52/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.2948e-04
# Epoch 53/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.2285e-04
# Epoch 54/100
# 30/30 [==============================] - 1s 25ms/step - loss: 1.3010e-04
# Epoch 55/100
# 30/30 [==============================] - 1s 34ms/step - loss: 1.3409e-04
# Epoch 56/100
# 30/30 [==============================] - 1s 34ms/step - loss: 1.5595e-04
# Epoch 57/100
# 30/30 [==============================] - 1s 35ms/step - loss: 1.5632e-04
# Epoch 58/100
# 30/30 [==============================] - 1s 35ms/step - loss: 1.3035e-04
# Epoch 59/100
# 30/30 [==============================] - 1s 34ms/step - loss: 1.1565e-04
# Epoch 60/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.2129e-04
# Epoch 61/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.2392e-04
# Epoch 62/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.5956e-04
# Epoch 63/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.6154e-04
# Epoch 64/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.1563e-04
# Epoch 65/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.2120e-04
# Epoch 66/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.1661e-04
# Epoch 67/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.1988e-04
# Epoch 68/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.1704e-04
# Epoch 69/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.3309e-04
# Epoch 70/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.1204e-04
# Epoch 71/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.2868e-04
# Epoch 72/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.1835e-04
# Epoch 73/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.1373e-04
# Epoch 74/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.1700e-04
# Epoch 75/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.1395e-04
# Epoch 76/100
# 30/30 [==============================] - 1s 30ms/step - loss: 1.1336e-04
# Epoch 77/100
# 30/30 [==============================] - 1s 35ms/step - loss: 1.1127e-04
# Epoch 78/100
# 30/30 [==============================] - 1s 34ms/step - loss: 1.4367e-04
# Epoch 79/100
# 30/30 [==============================] - 1s 36ms/step - loss: 1.1810e-04
# Epoch 80/100
# 30/30 [==============================] - 1s 34ms/step - loss: 1.0770e-04
# Epoch 81/100
# 30/30 [==============================] - 1s 29ms/step - loss: 1.0875e-04
# Epoch 82/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.1809e-04
# Epoch 83/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.2691e-04
# Epoch 84/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.0356e-04
# Epoch 85/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.2103e-04
# Epoch 86/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.1544e-04
# Epoch 87/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.0061e-04
# Epoch 88/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.2180e-04
# Epoch 89/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.2234e-04
# Epoch 90/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.0860e-04
# Epoch 91/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.0537e-04
# Epoch 92/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.0566e-04
# Epoch 93/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.1726e-04
# Epoch 94/100
# 30/30 [==============================] - 1s 20ms/step - loss: 1.0285e-04
# Epoch 95/100
# 30/30 [==============================] - 1s 21ms/step - loss: 1.1143e-04
# Epoch 96/100
# 30/30 [==============================] - 1s 20ms/step - loss: 9.9763e-05
# Epoch 97/100
# 30/30 [==============================] - 1s 27ms/step - loss: 9.9896e-05
# Epoch 98/100
# 30/30 [==============================] - 1s 34ms/step - loss: 1.0349e-04
# Epoch 99/100
# 30/30 [==============================] - 1s 37ms/step - loss: 1.0326e-04
# Epoch 100/100
# 30/30 [==============================] - 1s 34ms/step - loss: 1.0320e-04

# %%
# 10. Dự đoán dữ liệu kiểm thử
train_predict = model.predict(X_train)
y_pred = model.predict(X_test)
# Out:
# 59/59 [==============================] - 1s 7ms/step
# 13/13 [==============================] - 0s 7ms/step

# %%
# 11. Đảo ngược chuẩn hóa cho dữ liệu dự đoán
train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

# %%
# 12. Đánh giá độ chính xác của thuật toán bằng RMSE
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_log_error
test_rmse = np.sqrt(np.mean((y_pred - ytest)**2))
print('Testing RMSE:', test_rmse)
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_log_error
# MAPE
test_mape = mean_absolute_percentage_error(ytest,y_pred)
print('Testing MAPE:', test_mape)
# MSLE
test_msle = mean_squared_log_error(ytest,y_pred)
print('Testing MSLE:', test_msle)
# Out:
# Testing RMSE: 75354.98892376723
# Testing MAPE: 96018.0860041697
# Testing MSLE: 113.16735135856536

# %%
# 13. Dự đoán cho 30 ngày tiếp theo
x_input = test_data[-time_step:].reshape(1, -1)
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

from numpy import array

lst_output = []
n_steps = time_step
i = 0
while(i < 30):

    if(len(temp_input) > n_steps):
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape(1, -1)
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i = i + 1
    else:
        x_input = x_input.reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        i = i + 1

# %%
# 14. Vẽ hình
train_data_index = pd.RangeIndex(start=0, stop=train_size, step=1)
plt.plot(scaler.inverse_transform(train_data))
test_data_index = pd.RangeIndex(start=train_size, stop=train_size+test_size, step=1)
plt.plot(test_data_index, scaler.inverse_transform(test_data))
test_data_index = pd.RangeIndex(start=train_size+101, stop=train_size+test_size, step=1)
plt.plot(test_data_index, y_pred)
predict_data_index = pd.RangeIndex(start=len(df1)-1, stop=len(df1)+28, step=1)  # Giả sử chiều dài là 29
plt.plot(predict_data_index, scaler.inverse_transform(lst_output))
plt.legend(['Train', 'Test', 'Predict', 'Next30days'])
plt.title('RNN 8:2 (VCB stock price)')
plt.show()
