# %%
#1. Add library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_log_error as msle
from keras.models import Sequential
from keras.layers import Dense, LSTM
# Out:
# WARNING:tensorflow:From E:\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
data = pd.read_csv('agr.csv')
data
# Out:
#             Date    Price     Open     High      Low     Mass  Change
# 0     02/01/2018   6062.9   5964.5   6200.7   5964.5  930.28K   1.65%
# 1     03/01/2018   5885.7   6102.2   6161.3   5757.8  889.20K  -2.92%
# 2     04/01/2018   5895.6   5807.0   6053.0   5797.1    1.08M   0.17%
# 3     05/01/2018   5807.0   6072.7   6072.7   5807.0  943.35K  -1.50%
# 4     08/01/2018   5698.7   5905.4   5915.2   5659.3  790.88K  -1.86%
# ...          ...      ...      ...      ...      ...      ...     ...
# 1483  11/12/2023  16050.0  16150.0  16150.0  15750.0    1.52M   0.00%
# 1484  12/12/2023  15950.0  16050.0  16250.0  15950.0  706.20K  -0.62%
# 1485  13/12/2023  15800.0  16000.0  16300.0  15700.0    1.54M  -0.94%
# 1486  14/12/2023  15850.0  16100.0  16100.0  15700.0    1.06M   0.32%
# 1487  15/12/2023  15900.0  15850.0  16200.0  15800.0    1.31M   0.32%
#
# [1488 rows x 7 columns]

# %%
# Xử lý dữ liệu
prices = data['Price']

# %%
# Chuẩn hóa dữ liệu
scaler = MinMaxScaler()
scaled_prices = scaler.fit_transform(prices.values.reshape(-1, 1))

# %%
# Chia dữ liệu thành tập train test
np.random.seed(42)

train_size = int(len(scaled_prices) * 0.8)
test_size = int(len(scaled_prices) * 0.2)

train_data = scaled_prices[:train_size]
test_data = scaled_prices[train_size:train_size+test_size]

# %%
# Chia dữ liệu thành các mẫu chuỗi thời gian
def create_time_series(data, time_steps):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i+time_steps])
        y.append(data[i+time_steps])
    return np.array(X), np.array(y)

# %%
time_steps = 30  # Số ngày quan sát trước để dự đoán ngày tiếp theo
X_train, y_train = create_time_series(train_data, time_steps)
X_test, y_test = create_time_series(test_data, time_steps)

# %%
X_train.shape
# Out:
# (1160, 30, 1)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# 8. Define LSTM Model
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(time_steps,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
# Out:
# WARNING:tensorflow:From E:\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From E:\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# Biên dịch mô hình
model.compile(optimizer='adam', loss='mean_squared_error')

# Huấn luyện mô hình
model.fit(X_train, y_train, epochs=100, batch_size=64)

# Đánh giá mô hình trên tập kiểm tra
loss = model.evaluate(X_test, y_test)
print('Loss trên tập kiểm tra:', loss)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From E:\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 19/19 [==============================] - 4s 18ms/step - loss: 0.0278
# Epoch 2/100
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0031
# Epoch 3/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0023
# Epoch 4/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0022
# Epoch 5/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0021
# Epoch 6/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0019
# Epoch 7/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0019
# Epoch 8/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0017
# Epoch 9/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0018
# Epoch 10/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0015
# Epoch 11/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0015
# Epoch 12/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0015
# Epoch 13/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0014
# Epoch 14/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 15/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0012
# Epoch 16/100
# 19/19 [==============================] - 0s 18ms/step - loss: 0.0011
# Epoch 17/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0013
# Epoch 18/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0011
# Epoch 19/100
# 19/19 [==============================] - 0s 15ms/step - loss: 9.6901e-04
# Epoch 20/100
# 19/19 [==============================] - 0s 16ms/step - loss: 0.0010
# Epoch 21/100
# 19/19 [==============================] - 0s 15ms/step - loss: 8.8755e-04
# Epoch 22/100
# 19/19 [==============================] - 0s 15ms/step - loss: 8.5840e-04
# Epoch 23/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 24/100
# 19/19 [==============================] - 0s 16ms/step - loss: 8.8740e-04
# Epoch 25/100
# 19/19 [==============================] - 0s 15ms/step - loss: 8.0127e-04
# Epoch 26/100
# 19/19 [==============================] - 0s 15ms/step - loss: 7.6551e-04
# Epoch 27/100
# 19/19 [==============================] - 0s 15ms/step - loss: 9.7843e-04
# Epoch 28/100
# 19/19 [==============================] - 0s 15ms/step - loss: 7.9314e-04
# Epoch 29/100
# 19/19 [==============================] - 0s 15ms/step - loss: 7.9168e-04
# Epoch 30/100
# 19/19 [==============================] - 0s 15ms/step - loss: 8.0041e-04
# Epoch 31/100
# 19/19 [==============================] - 0s 15ms/step - loss: 9.5599e-04
# Epoch 32/100
# 19/19 [==============================] - 0s 15ms/step - loss: 8.2608e-04
# Epoch 33/100
# 19/19 [==============================] - 0s 15ms/step - loss: 8.0044e-04
# Epoch 34/100
# 19/19 [==============================] - 0s 15ms/step - loss: 6.4113e-04
# Epoch 35/100
# 19/19 [==============================] - 0s 15ms/step - loss: 6.1091e-04
# Epoch 36/100
# 19/19 [==============================] - 0s 15ms/step - loss: 6.1442e-04
# Epoch 37/100
# 19/19 [==============================] - 0s 15ms/step - loss: 6.1467e-04
# Epoch 38/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.9967e-04
# Epoch 39/100
# 19/19 [==============================] - 0s 15ms/step - loss: 6.0770e-04
# Epoch 40/100
# 19/19 [==============================] - 0s 15ms/step - loss: 6.3551e-04
# Epoch 41/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.8400e-04
# Epoch 42/100
# 19/19 [==============================] - 0s 15ms/step - loss: 6.6732e-04
# Epoch 43/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.6561e-04
# Epoch 44/100
# 19/19 [==============================] - 0s 15ms/step - loss: 6.6345e-04
# Epoch 45/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.6045e-04
# Epoch 46/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.8114e-04
# Epoch 47/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.2252e-04
# Epoch 48/100
# 19/19 [==============================] - 0s 15ms/step - loss: 6.2451e-04
# Epoch 49/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.5333e-04
# Epoch 50/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.2017e-04
# Epoch 51/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.3055e-04
# Epoch 52/100
# 19/19 [==============================] - 0s 15ms/step - loss: 6.0134e-04
# Epoch 53/100
# 19/19 [==============================] - 0s 15ms/step - loss: 4.7852e-04
# Epoch 54/100
# 19/19 [==============================] - 0s 15ms/step - loss: 4.8966e-04
# Epoch 55/100
# 19/19 [==============================] - 0s 15ms/step - loss: 4.6048e-04
# Epoch 56/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.5440e-04
# Epoch 57/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.0340e-04
# Epoch 58/100
# 19/19 [==============================] - 0s 15ms/step - loss: 4.4627e-04
# Epoch 59/100
# 19/19 [==============================] - 0s 15ms/step - loss: 4.3806e-04
# Epoch 60/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.6795e-04
# Epoch 61/100
# 19/19 [==============================] - 0s 15ms/step - loss: 4.5751e-04
# Epoch 62/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.1554e-04
# Epoch 63/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.9559e-04
# Epoch 64/100
# 19/19 [==============================] - 0s 15ms/step - loss: 4.1115e-04
# Epoch 65/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.9878e-04
# Epoch 66/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.5846e-04
# Epoch 67/100
# 19/19 [==============================] - 0s 15ms/step - loss: 4.9179e-04
# Epoch 68/100
# 19/19 [==============================] - 0s 15ms/step - loss: 4.2983e-04
# Epoch 69/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.7785e-04
# Epoch 70/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.6334e-04
# Epoch 71/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.4282e-04
# Epoch 72/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.2479e-04
# Epoch 73/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.2384e-04
# Epoch 74/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.0058e-04
# Epoch 75/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.1788e-04
# Epoch 76/100
# 19/19 [==============================] - 0s 15ms/step - loss: 5.2164e-04
# Epoch 77/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.9387e-04
# Epoch 78/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.1746e-04
# Epoch 79/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.2308e-04
# Epoch 80/100
# 19/19 [==============================] - 0s 15ms/step - loss: 4.0984e-04
# Epoch 81/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.9945e-04
# Epoch 82/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.8106e-04
# Epoch 83/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.6361e-04
# Epoch 84/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.7269e-04
# Epoch 85/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.1750e-04
# Epoch 86/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.4583e-04
# Epoch 87/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.4225e-04
# Epoch 88/100
# 19/19 [==============================] - 0s 15ms/step - loss: 3.6566e-04
# Epoch 89/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.6755e-04
# Epoch 90/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.6763e-04
# Epoch 91/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.4989e-04
# Epoch 92/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.3295e-04
# Epoch 93/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.2257e-04
# Epoch 94/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.3382e-04
# Epoch 95/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.2854e-04
# Epoch 96/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.5046e-04
# Epoch 97/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.7233e-04
# Epoch 98/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.3726e-04
# Epoch 99/100
# 19/19 [==============================] - 0s 16ms/step - loss: 2.3374e-04
# Epoch 100/100
# 19/19 [==============================] - 0s 15ms/step - loss: 2.1627e-04
# 9/9 [==============================] - 1s 5ms/step - loss: 2.8839e-04
# Loss trên tập kiểm tra: 0.00028839471633546054

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

# Tạo biến train, test
train = prices[:train_size]
test = prices[train_size:train_size+test_size]

y_test_pred = model.predict(X_test)
y_test_pred = scaler.inverse_transform(y_test_pred)

n_past = 1
n_days_for_prediction= 30

#create an array of 30 integers starting from last index
predict_period_dates = np.array(range(len(data) + 1,len(data) + 31)).reshape(-1, 1)

print(predict_period_dates)

#Make prediction
prediction1 = model.predict(X_test[-n_days_for_prediction:])

prediction_copies1 = np.repeat(prediction1, prices.shape[0], axis=-1)
predicted_prices = scaler.inverse_transform(prediction_copies1)[:,0]
print(predicted_prices)
# Out:
# 9/9 [==============================] - 1s 5ms/step
# [[1489]
#  [1490]
#  [1491]
#  [1492]
#  [1493]
#  [1494]
#  [1495]
#  [1496]
#  [1497]
#  [1498]
#  [1499]
#  [1500]
#  [1501]
#  [1502]
#  [1503]
#  [1504]
#  [1505]
#  [1506]
#  [1507]
#  [1508]
#  [1509]
#  [1510]
#  [1511]
#  [1512]
#  [1513]
#  [1514]
#  [1515]
#  [1516]
#  [1517]
#  [1518]]
# 1/1 [==============================] - 0s 18ms/step
# [12955.659 13419.594 13640.307 13559.748 14083.912 14768.555 14975.647
#  14853.914 14878.932 14974.487 15359.783 15174.386 15388.598 15644.561
#  15896.346 15083.392 15250.433 15220.23  15348.795 15557.961 15452.066
#  15559.319 16419.75  16701.373 16794.664 16420.07  16043.211 15998.649
#  15968.419 15828.029]

# %%
# Tạo biểu đồ train, test và dự đoán 30 ngày tiếp theo
plt.figure(figsize=(10, 6))
plt.plot(train, label='Train')
plt.plot(range(train_size, train_size + len(test)), test, label='Test')

plt.plot(range(train_size + 30,train_size + test_size), y_test_pred, 'g', label='Test Predicted')

plt.plot(predict_period_dates, predicted_prices, 'r', label='Predict in 30')

plt.xlabel('Ngày')
plt.ylabel('Giá cổ phiếu')
plt.title('Biểu đồ train, test và dự đoán 30 ngày tiếp theo')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, mean_squared_log_error

# Dự đoán giá trong quá trình testing
y_test_predicted = model.predict(X_test)

# Đưa các dự đoán về lại tỷ lệ ban đầu
y_test_predicted = scaler.inverse_transform(y_test_predicted)

y_test1 = scaler.inverse_transform(y_test)


# Tính MAE cho testing
mae_test = mean_absolute_error(y_test1, y_test_predicted)

# Tính MAPE cho testing
mape_test = mean_absolute_percentage_error(y_test1, y_test_predicted)

# Tính RMSE cho testing
rmse_test = mean_squared_error(y_test1, y_test_predicted, squared=False)

# Tính MSLE cho testing
msle_test = mean_squared_log_error(y_test1, y_test_predicted, squared=False)
# Out:
# 9/9 [==============================] - 0s 5ms/step

# %%
mape_test *= 100


print('---------TEST----------')
print("MAPE:", round(mape_test,3))
print("MAE:", round(mae_test,3))
print("RMSE:", round(rmse_test,3))
print("MSLE:", round(msle_test,3))
print('-------------------')
# Out:
# ---------TEST----------
# MAPE: 2.592
# MAE: 313.147
# RMSE: 426.219
# MSLE: 0.035
# -------------------
